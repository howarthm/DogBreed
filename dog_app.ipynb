# %% [markdown]
# # Data Scientist Nanodegree
#
# ## Convolutional Neural Networks
#
# ## Project: Write an Algorithm for a Dog Identification App
#
#
# This notebook walks you through one of the most popular Udacity projects across machine learning and artificial intellegence nanodegree programs.  The goal is to classify images of dogs according to their breed.
#
# If you are looking for a more guided capstone project related to deep learning and convolutional neural networks, this might be just it.  Notice that even if you follow the notebook to creating your classifier, you must still create a blog post or deploy an application to fulfill the requirements of the capstone project.
#
# Also notice, you may be able to use only parts of this notebook (for example certain coding portions or the data) without completing all parts and still meet all requirements of the capstone project.
#
# ---
#
# In this notebook, some template code has already been provided for you, and you will need to implement additional functionality to successfully complete this project. You will not need to modify the included code beyond what is requested. Sections that begin with **'(IMPLEMENTATION)'** in the header indicate that the following block of code will require additional functionality which you must provide. Instructions will be provided for each section, and the specifics of the implementation are marked in the code block with a 'TODO' statement. Please be sure to read the instructions carefully!
#
# In addition to implementing code, there will be questions that you must answer which relate to the project and your implementation. Each section where you will answer a question is preceded by a **'Question X'** header. Carefully read each question and provide thorough answers in the following text boxes that begin with **'Answer:'**. Your project submission will be evaluated based on your answers to each of the questions and the implementation you provide.
#
# >**Note:** Code and Markdown cells can be executed using the **Shift + Enter** keyboard shortcut.  Markdown cells can be edited by double-clicking the cell to enter edit mode.
#
# The rubric contains _optional_ "Stand Out Suggestions" for enhancing the project beyond the minimum requirements. If you decide to pursue the "Stand Out Suggestions", you should include the code in this IPython notebook.
#
#
#
# ---
# ### Why We're Here
#
# In this notebook, you will make the first steps towards developing an algorithm that could be used as part of a mobile or web app.  At the end of this project, your code will accept any user-supplied image as input.  If a dog is detected in the image, it will provide an estimate of the dog's breed.  If a human is detected, it will provide an estimate of the dog breed that is most resembling.  The image below displays potential sample output of your finished project (... but we expect that each student's algorithm will behave differently!).
#
# ![Sample Dog Output](images/sample_dog_output.png)
#
# In this real-world setting, you will need to piece together a series of models to perform different tasks; for instance, the algorithm that detects humans in an image will be different from the CNN that infers dog breed.  There are many points of possible failure, and no perfect algorithm exists.  Your imperfect solution will nonetheless create a fun user experience!
#
# ### The Road Ahead
#
# We break the notebook into separate steps.  Feel free to use the links below to navigate the notebook.
#
# * [Step 0](#step0): Import Datasets
# * [Step 1](#step1): Detect Humans
# * [Step 2](#step2): Detect Dogs
# * [Step 3](#step3): Create a CNN to Classify Dog Breeds (from Scratch)
# * [Step 4](#step4): Use a CNN to Classify Dog Breeds (using Transfer Learning)
# * [Step 5](#step5): Create a CNN to Classify Dog Breeds (using Transfer Learning)
# * [Step 6](#step6): Write your Algorithm
# * [Step 7](#step7): Test Your Algorithm
#
# ---
# <a id='step0'></a>
# ## Step 0: Import Datasets
#
# ### Import Dog Dataset
#
# In the code cell below, we import a dataset of dog images.  We populate a few variables through the use of the `load_files` function from the scikit-learn library:
# - `train_files`, `valid_files`, `test_files` - numpy arrays containing file paths to images
# - `train_targets`, `valid_targets`, `test_targets` - numpy arrays containing onehot-encoded classification labels
# - `dog_names` - list of string-valued dog breed names for translating labels

# %%
from sklearn.datasets import load_files       
from keras.utils import np_utils
#from keras.utils import to_categorical
import numpy as np
from glob import glob

# define function to load train, test, and validation datasets
def load_dataset(path):
    data = load_files(path)
    dog_files = np.array(data['filenames'])
    dog_targets = np_utils.to_categorical(np.array(data['target']), 133)
    return dog_files, dog_targets

# load train, test, and validation datasets
train_files, train_targets = load_dataset('data/dog_images/train')
valid_files, valid_targets = load_dataset('data/dog_images/valid')
test_files, test_targets = load_dataset('data/dog_images/test')

# load list of dog names
dog_names = [item[20:-1] for item in sorted(glob("data/dog_images/train/*/"))]

# print statistics about the dataset
print('There are %d total dog categories.' % len(dog_names))
print('There are %s total dog images.\n' % len(np.hstack([train_files, valid_files, test_files])))
print('There are %d training dog images.' % len(train_files))
print('There are %d validation dog images.' % len(valid_files))
print('There are %d test dog images.'% len(test_files))
# Out:
# Using TensorFlow backend.
# There are 133 total dog categories.
# There are 8351 total dog images.
#
# There are 6680 training dog images.
# There are 835 validation dog images.
# There are 836 test dog images.

# %% [markdown]
# ### Import Human Dataset
#
# In the code cell below, we import a dataset of human images, where the file paths are stored in the numpy array `human_files`.

# %%
import random
random.seed(8675309)

# load filenames in shuffled human dataset
human_files = np.array(glob("data/lfw/*/*"))
random.shuffle(human_files)

# print statistics about the dataset
print('There are %d total human images.' % len(human_files))
# Out:
# There are 13233 total human images.

# %% [markdown]
# ---
# <a id='step1'></a>
# ## Step 1: Detect Humans
#
# We use OpenCV's implementation of [Haar feature-based cascade classifiers](http://docs.opencv.org/trunk/d7/d8b/tutorial_py_face_detection.html) to detect human faces in images.  OpenCV provides many pre-trained face detectors, stored as XML files on [github](https://github.com/opencv/opencv/tree/master/data/haarcascades).  We have downloaded one of these detectors and stored it in the `haarcascades` directory.
#
# In the next code cell, we demonstrate how to use this detector to find human faces in a sample image.

# %%
import cv2                
import matplotlib.pyplot as plt                        
# %matplotlib inline                               

# extract pre-trained face detector
face_cascade = cv2.CascadeClassifier('haarcascades/haarcascade_frontalface_alt.xml')

# load color (BGR) image
img = cv2.imread(human_files[3])
# convert BGR image to grayscale
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# find faces in image
faces = face_cascade.detectMultiScale(gray)

# print number of faces detected in the image
print('Number of faces detected:', len(faces))

# get bounding box for each detected face
for (x,y,w,h) in faces:
    # add bounding box to color image
    cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
    
# convert BGR image to RGB for plotting
cv_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# display the image, along with bounding box
plt.imshow(cv_rgb)
plt.show()
# Out:
# Number of faces detected: 1

# %% [markdown]
# Before using any of the face detectors, it is standard procedure to convert the images to grayscale.  The `detectMultiScale` function executes the classifier stored in `face_cascade` and takes the grayscale image as a parameter.
#
# In the above code, `faces` is a numpy array of detected faces, where each row corresponds to a detected face.  Each detected face is a 1D array with four entries that specifies the bounding box of the detected face.  The first two entries in the array (extracted in the above code as `x` and `y`) specify the horizontal and vertical positions of the top left corner of the bounding box.  The last two entries in the array (extracted here as `w` and `h`) specify the width and height of the box.
#
# ### Write a Human Face Detector
#
# We can use this procedure to write a function that returns `True` if a human face is detected in an image and `False` otherwise.  This function, aptly named `face_detector`, takes a string-valued file path to an image as input and appears in the code block below.

# %%
# returns "True" if face is detected in image stored at img_path
def face_detector(img_path):
    img = cv2.imread(img_path)
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    faces = face_cascade.detectMultiScale(gray)
    return len(faces) > 0

# %% [markdown]
# ### (IMPLEMENTATION) Assess the Human Face Detector
#
# __Question 1:__ Use the code cell below to test the performance of the `face_detector` function.
# - What percentage of the first 100 images in `human_files` have a detected human face?
# - What percentage of the first 100 images in `dog_files` have a detected human face?
#
# Ideally, we would like 100% of human images with a detected face and 0% of dog images with a detected face.  You will see that our algorithm falls short of this goal, but still gives acceptable performance.  We extract the file paths for the first 100 images from each of the datasets and store them in the numpy arrays `human_files_short` and `dog_files_short`.
#
# __Answer:__
#
# 99% correct on human images, but 12% detected human faces in the dog images.

# %%
human_files_short = human_files[:100]
dog_files_short = train_files[:100]
# Do NOT modify the code above this line.

## TODO: Test the performance of the face_detector algorithm 
## on the images in human_files_short and dog_files_short.
detected_humans = 0
for human in human_files_short:
    if face_detector(human) == True:
        detected_humans = detected_humans + 1
print('Percentage of human faces detected:', detected_humans * 100 / len(human_files_short))
        
detected_dogs = 0
for dog in dog_files_short:
    if face_detector(dog) == True:
        detected_dogs = detected_dogs + 1

print('Percentage of human faces detected in dog images:', detected_dogs * 100 / len(dog_files_short))
# Out:
# Percentage of human faces detected: 99.0
# Percentage of human faces detected in dog images: 12.0

# %% [markdown]
# __Question 2:__ This algorithmic choice necessitates that we communicate to the user that we accept human images only when they provide a clear view of a face (otherwise, we risk having unneccessarily frustrated users!). In your opinion, is this a reasonable expectation to pose on the user? If not, can you think of a way to detect humans in images that does not necessitate an image with a clearly presented face?
#
# __Answer:__
#
# We could train with smaller faces, rotated faces, or look for human features look ears and noses that are distinctive.
#
# We suggest the face detector from OpenCV as a potential way to detect human images in your algorithm, but you are free to explore other approaches, especially approaches that make use of deep learning :).  Please use the code cell below to design and test your own face detection algorithm.  If you decide to pursue this _optional_ task, report performance on each of the datasets.

# %%
## (Optional) TODO: Report the performance of another  
## face detection algorithm on the LFW dataset
### Feel free to use as many code cells as needed.

# found this code here to show a different face detection library
# you may have to run pip install -U scikit-image and restart you notebook
# https://scikit-image.org/docs/dev/auto_examples/applications/plot_face_detection.html

from skimage import data
from skimage.feature import Cascade
import skimage
import skimage.feature

import matplotlib.pyplot as plt
from matplotlib import patches

# Load the trained file from the module root.
trained_file = data.lbp_frontal_face_cascade_filename()

# Initialize the detector cascade.
detector = Cascade(trained_file)

img = data.astronaut()

detected = detector.detect_multi_scale(img=img,
                                       scale_factor=1.2,
                                       step_ratio=1,
                                       min_size=(60, 60),
                                       max_size=(123, 123))

plt.imshow(img)
img_desc = plt.gca()
plt.set_cmap('gray')

for patch in detected:

    img_desc.add_patch(
        patches.Rectangle(
            (patch['c'], patch['r']),
            patch['width'],
            patch['height'],
            fill=False,
            color='r',
            linewidth=2
        )
    )

plt.show()

# %%
def optional_face_detector(img_path):
    img = cv2.imread(img_path)
    detected = detector.detect_multi_scale(img=img,
                                       scale_factor=1.2,
                                       step_ratio=1,
                                       min_size=(60, 60),
                                       max_size=(123, 123))
    
    return len(detected) > 0

# %%
human_files_short = human_files[:100]
dog_files_short = train_files[:100]
# Do NOT modify the code above this line.

## TODO: Test the performance of the face_detector algorithm 
## on the images in human_files_short and dog_files_short.
detected_humans = 0
for human in human_files_short:
    if optional_face_detector(human) == True:
        detected_humans = detected_humans + 1
print('Optional:  Percentage of human faces detected:', detected_humans * 100 / len(human_files_short))
# Out:
# Optional:  Percentage of human faces detected: 81.0

# %% [markdown]
# ---
# <a id='step2'></a>
# ## Step 2: Detect Dogs
#
# In this section, we use a pre-trained [ResNet-50](http://ethereon.github.io/netscope/#/gist/db945b393d40bfa26006) model to detect dogs in images.  Our first line of code downloads the ResNet-50 model, along with weights that have been trained on [ImageNet](http://www.image-net.org/), a very large, very popular dataset used for image classification and other vision tasks.  ImageNet contains over 10 million URLs, each linking to an image containing an object from one of [1000 categories](https://gist.github.com/yrevar/942d3a0ac09ec9e5eb3a).  Given an image, this pre-trained ResNet-50 model returns a prediction (derived from the available categories in ImageNet) for the object that is contained in the image.

# %%
from keras.applications.resnet50 import ResNet50

# define ResNet50 model
ResNet50_model = ResNet50(weights='imagenet')
# Out:
# WARNING:tensorflow:From C:\Users\mark.howarth\AppData\Local\Continuum\anaconda3\envs\PythonGPU37\lib\site-packages\tensorflow\python\framework\op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.

# %% [markdown]
# ### Pre-process the Data
#
# When using TensorFlow as backend, Keras CNNs require a 4D array (which we'll also refer to as a 4D tensor) as input, with shape
#
# $$
# (\text{nb_samples}, \text{rows}, \text{columns}, \text{channels}),
# $$
#
# where `nb_samples` corresponds to the total number of images (or samples), and `rows`, `columns`, and `channels` correspond to the number of rows, columns, and channels for each image, respectively.
#
# The `path_to_tensor` function below takes a string-valued file path to a color image as input and returns a 4D tensor suitable for supplying to a Keras CNN.  The function first loads the image and resizes it to a square image that is $224 \times 224$ pixels.  Next, the image is converted to an array, which is then resized to a 4D tensor.  In this case, since we are working with color images, each image has three channels.  Likewise, since we are processing a single image (or sample), the returned tensor will always have shape
#
# $$
# (1, 224, 224, 3).
# $$
#
# The `paths_to_tensor` function takes a numpy array of string-valued image paths as input and returns a 4D tensor with shape
#
# $$
# (\text{nb_samples}, 224, 224, 3).
# $$
#
# Here, `nb_samples` is the number of samples, or number of images, in the supplied array of image paths.  It is best to think of `nb_samples` as the number of 3D tensors (where each 3D tensor corresponds to a different image) in your dataset!

# %%
from keras.preprocessing import image                  
from tqdm import tqdm

def path_to_tensor(img_path):
    # loads RGB image as PIL.Image.Image type
    img = image.load_img(img_path, target_size=(224, 224))
    # convert PIL.Image.Image type to 3D tensor with shape (224, 224, 3)
    x = image.img_to_array(img)
    # convert 3D tensor to 4D tensor with shape (1, 224, 224, 3) and return 4D tensor
    return np.expand_dims(x, axis=0)

def paths_to_tensor(img_paths):
    list_of_tensors = [path_to_tensor(img_path) for img_path in tqdm(img_paths)]
    return np.vstack(list_of_tensors)

# %% [markdown]
# ### Making Predictions with ResNet-50
#
# Getting the 4D tensor ready for ResNet-50, and for any other pre-trained model in Keras, requires some additional processing.  First, the RGB image is converted to BGR by reordering the channels.  All pre-trained models have the additional normalization step that the mean pixel (expressed in RGB as $[103.939, 116.779, 123.68]$ and calculated from all pixels in all images in ImageNet) must be subtracted from every pixel in each image.  This is implemented in the imported function `preprocess_input`.  If you're curious, you can check the code for `preprocess_input` [here](https://github.com/fchollet/keras/blob/master/keras/applications/imagenet_utils.py).
#
# Now that we have a way to format our image for supplying to ResNet-50, we are now ready to use the model to extract the predictions.  This is accomplished with the `predict` method, which returns an array whose $i$-th entry is the model's predicted probability that the image belongs to the $i$-th ImageNet category.  This is implemented in the `ResNet50_predict_labels` function below.
#
# By taking the argmax of the predicted probability vector, we obtain an integer corresponding to the model's predicted object class, which we can identify with an object category through the use of this [dictionary](https://gist.github.com/yrevar/942d3a0ac09ec9e5eb3a).

# %%
from keras.applications.resnet50 import preprocess_input, decode_predictions

def ResNet50_predict_labels(img_path):
    # returns prediction vector for image located at img_path
    img = preprocess_input(path_to_tensor(img_path))
    return np.argmax(ResNet50_model.predict(img))

# %% [markdown]
# ### Write a Dog Detector
#
# While looking at the [dictionary](https://gist.github.com/yrevar/942d3a0ac09ec9e5eb3a), you will notice that the categories corresponding to dogs appear in an uninterrupted sequence and correspond to dictionary keys 151-268, inclusive, to include all categories from `'Chihuahua'` to `'Mexican hairless'`.  Thus, in order to check to see if an image is predicted to contain a dog by the pre-trained ResNet-50 model, we need only check if the `ResNet50_predict_labels` function above returns a value between 151 and 268 (inclusive).
#
# We use these ideas to complete the `dog_detector` function below, which returns `True` if a dog is detected in an image (and `False` if not).

# %%
### returns "True" if a dog is detected in the image stored at img_path
def dog_detector(img_path):
    prediction = ResNet50_predict_labels(img_path)
    return ((prediction <= 268) & (prediction >= 151))

# %% [markdown]
# # (IMPLEMENTATION) Assess the Dog Detector
#
# __Question 3:__ Use the code cell below to test the performance of your `dog_detector` function.
# - What percentage of the images in `human_files_short` have a detected dog?
# - What percentage of the images in `dog_files_short` have a detected dog?
#
# __Answer:__
#
# 1% of human images are recognized as dogs
# 100% of dog images are recognized as dogs

# %%
### TODO: Test the performance of the dog_detector function
### on the images in human_files_short and dog_files_short.

detected_dogs_in_human_images = 0
for human in human_files_short:
    if dog_detector(human) == True:
        detected_dogs_in_human_images = detected_dogs_in_human_images + 1
print('Percentage of dogs detected in human images:', detected_dogs_in_human_images * 100 / len(human_files_short))
        
detected_dogs_in_dog_images = 0
for dog in dog_files_short:
    if dog_detector(dog) == True:
        detected_dogs_in_dog_images = detected_dogs_in_dog_images + 1

print('Percentage of dogs detected in dog images:', detected_dogs_in_dog_images * 100 / len(dog_files_short))
# Out:
# Percentage of dogs detected in human images: 1.0
# Percentage of dogs detected in dog images: 100.0

# %% [markdown]
# ---
# <a id='step3'></a>
# ## Step 3: Create a CNN to Classify Dog Breeds (from Scratch)
#
# Now that we have functions for detecting humans and dogs in images, we need a way to predict breed from images.  In this step, you will create a CNN that classifies dog breeds.  You must create your CNN _from scratch_ (so, you can't use transfer learning _yet_!), and you must attain a test accuracy of at least 1%.  In Step 5 of this notebook, you will have the opportunity to use transfer learning to create a CNN that attains greatly improved accuracy.
#
# Be careful with adding too many trainable layers!  More parameters means longer training, which means you are more likely to need a GPU to accelerate the training process.  Thankfully, Keras provides a handy estimate of the time that each epoch is likely to take; you can extrapolate this estimate to figure out how long it will take for your algorithm to train.
#
# We mention that the task of assigning breed to dogs from images is considered exceptionally challenging.  To see why, consider that *even a human* would have great difficulty in distinguishing between a Brittany and a Welsh Springer Spaniel.
#
# Brittany | Welsh Springer Spaniel
# - | -
# <img src="images/Brittany_02625.jpg" width="100"> | <img src="images/Welsh_springer_spaniel_08203.jpg" width="200">
#
# It is not difficult to find other dog breed pairs with minimal inter-class variation (for instance, Curly-Coated Retrievers and American Water Spaniels).
#
# Curly-Coated Retriever | American Water Spaniel
# - | -
# <img src="images/Curly-coated_retriever_03896.jpg" width="200"> | <img src="images/American_water_spaniel_00648.jpg" width="200">
#
#
# Likewise, recall that labradors come in yellow, chocolate, and black.  Your vision-based algorithm will have to conquer this high intra-class variation to determine how to classify all of these different shades as the same breed.
#
# Yellow Labrador | Chocolate Labrador | Black Labrador
# - | -
# <img src="images/Labrador_retriever_06457.jpg" width="150"> | <img src="images/Labrador_retriever_06455.jpg" width="240"> | <img src="images/Labrador_retriever_06449.jpg" width="220">
#
# We also mention that random chance presents an exceptionally low bar: setting aside the fact that the classes are slightly imabalanced, a random guess will provide a correct answer roughly 1 in 133 times, which corresponds to an accuracy of less than 1%.
#
# Remember that the practice is far ahead of the theory in deep learning.  Experiment with many different architectures, and trust your intuition.  And, of course, have fun!
#
# ### Pre-process the Data
#
# We rescale the images by dividing every pixel in every image by 255.

# %%
from PIL import ImageFile                            
ImageFile.LOAD_TRUNCATED_IMAGES = True                 

# pre-process the data for Keras
train_tensors = paths_to_tensor(train_files).astype('float32')/255
valid_tensors = paths_to_tensor(valid_files).astype('float32')/255
test_tensors = paths_to_tensor(test_files).astype('float32')/255
# Out:
# 100%|██████████| 6680/6680 [02:04<00:00, 53.66it/s]
# 100%|██████████| 835/835 [00:14<00:00, 59.22it/s]
# 100%|██████████| 836/836 [00:15<00:00, 55.18it/s]

# %%
train_tensors.shape
# Out:
# (6680, 224, 224, 3)

# %% [markdown]
# ### (IMPLEMENTATION) Model Architecture
#
# Create a CNN to classify dog breed.  At the end of your code cell block, summarize the layers of your model by executing the line:
#
#         model.summary()
#
# We have imported some Python modules to get you started, but feel free to import as many modules as you need.  If you end up getting stuck, here's a hint that specifies a model that trains relatively fast on CPU and attains >1% test accuracy in 5 epochs:
#
# ![Sample CNN](images/sample_cnn.png)
#
# __Question 4:__ Outline the steps you took to get to your final CNN architecture and your reasoning at each step.  If you chose to use the hinted architecture above, describe why you think that CNN architecture should work well for the image classification task.
#
# __Answer:__

# %%
from keras.layers import Conv2D, MaxPooling2D, GlobalAveragePooling2D
from keras.layers import Dropout, Flatten, Dense
from keras.models import Sequential

model = Sequential()

### TODO: Define your architecture.

#https://keras.io/getting-started/sequential-model-guide/

#total_params = (filter_height * filter_width * input_image_channels + 1) * number_of_filters
model.add(Conv2D(16, (2, 2), input_shape=(224,224,3), activation='relu'))
model.add(MaxPooling2D(pool_size = (2,2), strides=2))
model.add(Conv2D(32, (2, 2), input_shape=(111,111,16), activation='relu'))
model.add(MaxPooling2D(pool_size = (2,2), strides=2))
model.add(Conv2D(64, (2, 2), input_shape=(54,54,64), activation='relu'))
model.add(MaxPooling2D(pool_size = (2,2), strides=2))
model.add(GlobalAveragePooling2D(input_shape=(27,27,64)))
model.add(Dense(133, input_dim=64, activation='softmax'))

model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_1 (Conv2D)            (None, 223, 223, 16)      208
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 111, 111, 16)      0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 110, 110, 32)      2080
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 55, 55, 32)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 54, 54, 64)        8256
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 27, 27, 64)        0
# _________________________________________________________________
# global_average_pooling2d_1 ( (None, 64)                0
# _________________________________________________________________
# dense_1 (Dense)              (None, 133)               8645
# =================================================================
# Total params: 19,189
# Trainable params: 19,189
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Compile the Model

# %%
model.compile(optimizer='rmsprop', loss='categorical_crossentropy', metrics=['accuracy'])

# %% [markdown]
# ### (IMPLEMENTATION) Train the Model
#
# Train your model in the code cell below.  Use model checkpointing to save the model that attains the best validation loss.
#
# You are welcome to [augment the training data](https://blog.keras.io/building-powerful-image-classification-models-using-very-little-data.html), but this is not a requirement.

# %%
from keras.callbacks import ModelCheckpoint  

### TODO: specify the number of epochs that you would like to use to train the model.

epochs = 5

### Do NOT modify the code below this line.

checkpointer = ModelCheckpoint(filepath='saved_models/weights.best.from_scratch.hdf5', 
                               verbose=1, save_best_only=True)

model.fit(train_tensors, train_targets, 
          validation_data=(valid_tensors, valid_targets),
          epochs=epochs, batch_size=20, callbacks=[checkpointer], verbose=1)
# Out:
# WARNING:tensorflow:From C:\Users\mark.howarth\AppData\Local\Continuum\anaconda3\envs\PythonGPU37\lib\site-packages\tensorflow\python\ops\math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Train on 6680 samples, validate on 835 samples
# Epoch 1/5
# 4280/6680 [==================>...........] - ETA: 11:19 - loss: 4.9008 - acc: 0.0000e+ - ETA: 5:49 - loss: 4.8881 - acc: 0.0000e+00 - ETA: 4:00 - loss: 4.8899 - acc: 0.0167    - ETA: 3:05 - loss: 4.8895 - acc: 0.012 - ETA: 2:32 - loss: 4.8896 - acc: 0.020 - ETA: 2:10 - loss: 4.8962 - acc: 0.016 - ETA: 1:54 - loss: 4.8968 - acc: 0.014 - ETA: 1:43 - loss: 4.8977 - acc: 0.012 - ETA: 1:34 - loss: 4.8975 - acc: 0.011 - ETA: 1:26 - loss: 4.8948 - acc: 0.010 - ETA: 1:20 - loss: 4.8947 - acc: 0.009 - ETA: 1:15 - loss: 4.8921 - acc: 0.008 - ETA: 1:11 - loss: 4.8934 - acc: 0.007 - ETA: 1:07 - loss: 4.8946 - acc: 0.007 - ETA: 1:04 - loss: 4.8964 - acc: 0.006 - ETA: 1:01 - loss: 4.8962 - acc: 0.006 - ETA: 59s - loss: 4.8962 - acc: 0.008 - ETA: 57s - loss: 4.8959 - acc: 0.00 - ETA: 55s - loss: 4.8957 - acc: 0.01 - ETA: 53s - loss: 4.8956 - acc: 0.01 - ETA: 51s - loss: 4.8955 - acc: 0.00 - ETA: 50s - loss: 4.8955 - acc: 0.01 - ETA: 48s - loss: 4.8948 - acc: 0.01 - ETA: 47s - loss: 4.8945 - acc: 0.01 - ETA: 46s - loss: 4.8948 - acc: 0.01 - ETA: 45s - loss: 4.8948 - acc: 0.00 - ETA: 44s - loss: 4.8939 - acc: 0.00 - ETA: 43s - loss: 4.8935 - acc: 0.00 - ETA: 42s - loss: 4.8934 - acc: 0.00 - ETA: 41s - loss: 4.8927 - acc: 0.01 - ETA: 40s - loss: 4.8926 - acc: 0.01 - ETA: 40s - loss: 4.8926 - acc: 0.01 - ETA: 39s - loss: 4.8929 - acc: 0.01 - ETA: 38s - loss: 4.8933 - acc: 0.01 - ETA: 38s - loss: 4.8932 - acc: 0.01 - ETA: 37s - loss: 4.8937 - acc: 0.01 - ETA: 37s - loss: 4.8936 - acc: 0.01 - ETA: 36s - loss: 4.8935 - acc: 0.01 - ETA: 35s - loss: 4.8934 - acc: 0.01 - ETA: 35s - loss: 4.8931 - acc: 0.01 - ETA: 34s - loss: 4.8927 - acc: 0.01 - ETA: 34s - loss: 4.8928 - acc: 0.01 - ETA: 34s - loss: 4.8931 - acc: 0.01 - ETA: 33s - loss: 4.8932 - acc: 0.01 - ETA: 33s - loss: 4.8935 - acc: 0.01 - ETA: 32s - loss: 4.8934 - acc: 0.00 - ETA: 32s - loss: 4.8932 - acc: 0.00 - ETA: 32s - loss: 4.8938 - acc: 0.00 - ETA: 31s - loss: 4.8939 - acc: 0.00 - ETA: 31s - loss: 4.8939 - acc: 0.00 - ETA: 31s - loss: 4.8935 - acc: 0.00 - ETA: 30s - loss: 4.8930 - acc: 0.01 - ETA: 30s - loss: 4.8934 - acc: 0.01 - ETA: 30s - loss: 4.8935 - acc: 0.01 - ETA: 29s - loss: 4.8934 - acc: 0.01 - ETA: 29s - loss: 4.8933 - acc: 0.01 - ETA: 29s - loss: 4.8932 - acc: 0.01 - ETA: 29s - loss: 4.8934 - acc: 0.01 - ETA: 28s - loss: 4.8936 - acc: 0.01 - ETA: 28s - loss: 4.8934 - acc: 0.01 - ETA: 28s - loss: 4.8935 - acc: 0.00 - ETA: 27s - loss: 4.8937 - acc: 0.00 - ETA: 27s - loss: 4.8934 - acc: 0.00 - ETA: 27s - loss: 4.8935 - acc: 0.00 - ETA: 27s - loss: 4.8935 - acc: 0.00 - ETA: 27s - loss: 4.8933 - acc: 0.00 - ETA: 26s - loss: 4.8930 - acc: 0.00 - ETA: 26s - loss: 4.8930 - acc: 0.00 - ETA: 26s - loss: 4.8928 - acc: 0.00 - ETA: 26s - loss: 4.8926 - acc: 0.00 - ETA: 25s - loss: 4.8921 - acc: 0.00 - ETA: 25s - loss: 4.8923 - acc: 0.00 - ETA: 25s - loss: 4.8922 - acc: 0.00 - ETA: 25s - loss: 4.8920 - acc: 0.00 - ETA: 25s - loss: 4.8917 - acc: 0.01 - ETA: 24s - loss: 4.8915 - acc: 0.01 - ETA: 24s - loss: 4.8916 - acc: 0.01 - ETA: 24s - loss: 4.8917 - acc: 0.01 - ETA: 24s - loss: 4.8919 - acc: 0.01 - ETA: 24s - loss: 4.8918 - acc: 0.01 - ETA: 24s - loss: 4.8918 - acc: 0.00 - ETA: 23s - loss: 4.8916 - acc: 0.00 - ETA: 23s - loss: 4.8917 - acc: 0.00 - ETA: 23s - loss: 4.8917 - acc: 0.00 - ETA: 23s - loss: 4.8916 - acc: 0.00 - ETA: 23s - loss: 4.8917 - acc: 0.00 - ETA: 23s - loss: 4.8914 - acc: 0.00 - ETA: 23s - loss: 4.8915 - acc: 0.00 - ETA: 22s - loss: 4.8914 - acc: 0.00 - ETA: 22s - loss: 4.8912 - acc: 0.00 - ETA: 22s - loss: 4.8909 - acc: 0.01 - ETA: 22s - loss: 4.8910 - acc: 0.01 - ETA: 22s - loss: 4.8909 - acc: 0.01 - ETA: 22s - loss: 4.8907 - acc: 0.01 - ETA: 21s - loss: 4.8907 - acc: 0.01 - ETA: 21s - loss: 4.8906 - acc: 0.00 - ETA: 21s - loss: 4.8901 - acc: 0.00 - ETA: 21s - loss: 4.8904 - acc: 0.00 - ETA: 21s - loss: 4.8904 - acc: 0.00 - ETA: 21s - loss: 4.8900 - acc: 0.00 - ETA: 21s - loss: 4.8902 - acc: 0.00 - ETA: 20s - loss: 4.8904 - acc: 0.00 - ETA: 20s - loss: 4.8901 - acc: 0. ...
# 6680/6680 [==============================] - ETA: 9s - loss: 4.8874 - acc: 0.008 - ETA: 9s - loss: 4.8874 - acc: 0.008 - ETA: 9s - loss: 4.8876 - acc: 0.008 - ETA: 9s - loss: 4.8877 - acc: 0.008 - ETA: 9s - loss: 4.8876 - acc: 0.008 - ETA: 8s - loss: 4.8876 - acc: 0.008 - ETA: 8s - loss: 4.8877 - acc: 0.008 - ETA: 8s - loss: 4.8876 - acc: 0.008 - ETA: 8s - loss: 4.8874 - acc: 0.008 - ETA: 8s - loss: 4.8873 - acc: 0.008 - ETA: 8s - loss: 4.8873 - acc: 0.008 - ETA: 8s - loss: 4.8872 - acc: 0.008 - ETA: 8s - loss: 4.8872 - acc: 0.008 - ETA: 8s - loss: 4.8872 - acc: 0.008 - ETA: 8s - loss: 4.8870 - acc: 0.008 - ETA: 8s - loss: 4.8869 - acc: 0.008 - ETA: 8s - loss: 4.8868 - acc: 0.008 - ETA: 7s - loss: 4.8869 - acc: 0.008 - ETA: 7s - loss: 4.8869 - acc: 0.008 - ETA: 7s - loss: 4.8869 - acc: 0.008 - ETA: 7s - loss: 4.8870 - acc: 0.008 - ETA: 7s - loss: 4.8870 - acc: 0.008 - ETA: 7s - loss: 4.8869 - acc: 0.008 - ETA: 7s - loss: 4.8868 - acc: 0.008 - ETA: 7s - loss: 4.8865 - acc: 0.008 - ETA: 7s - loss: 4.8867 - acc: 0.008 - ETA: 7s - loss: 4.8868 - acc: 0.008 - ETA: 7s - loss: 4.8866 - acc: 0.008 - ETA: 7s - loss: 4.8867 - acc: 0.008 - ETA: 6s - loss: 4.8868 - acc: 0.008 - ETA: 6s - loss: 4.8866 - acc: 0.008 - ETA: 6s - loss: 4.8866 - acc: 0.008 - ETA: 6s - loss: 4.8866 - acc: 0.008 - ETA: 6s - loss: 4.8863 - acc: 0.008 - ETA: 6s - loss: 4.8862 - acc: 0.008 - ETA: 6s - loss: 4.8864 - acc: 0.008 - ETA: 6s - loss: 4.8866 - acc: 0.008 - ETA: 6s - loss: 4.8865 - acc: 0.008 - ETA: 6s - loss: 4.8867 - acc: 0.008 - ETA: 6s - loss: 4.8867 - acc: 0.008 - ETA: 6s - loss: 4.8867 - acc: 0.008 - ETA: 6s - loss: 4.8868 - acc: 0.008 - ETA: 5s - loss: 4.8868 - acc: 0.008 - ETA: 5s - loss: 4.8867 - acc: 0.008 - ETA: 5s - loss: 4.8869 - acc: 0.008 - ETA: 5s - loss: 4.8869 - acc: 0.008 - ETA: 5s - loss: 4.8868 - acc: 0.008 - ETA: 5s - loss: 4.8869 - acc: 0.008 - ETA: 5s - loss: 4.8867 - acc: 0.008 - ETA: 5s - loss: 4.8866 - acc: 0.008 - ETA: 5s - loss: 4.8867 - acc: 0.007 - ETA: 5s - loss: 4.8865 - acc: 0.007 - ETA: 5s - loss: 4.8864 - acc: 0.007 - ETA: 5s - loss: 4.8863 - acc: 0.007 - ETA: 5s - loss: 4.8862 - acc: 0.008 - ETA: 4s - loss: 4.8860 - acc: 0.008 - ETA: 4s - loss: 4.8860 - acc: 0.008 - ETA: 4s - loss: 4.8859 - acc: 0.008 - ETA: 4s - loss: 4.8860 - acc: 0.008 - ETA: 4s - loss: 4.8860 - acc: 0.008 - ETA: 4s - loss: 4.8860 - acc: 0.008 - ETA: 4s - loss: 4.8859 - acc: 0.008 - ETA: 4s - loss: 4.8858 - acc: 0.008 - ETA: 4s - loss: 4.8859 - acc: 0.008 - ETA: 4s - loss: 4.8859 - acc: 0.008 - ETA: 4s - loss: 4.8858 - acc: 0.008 - ETA: 4s - loss: 4.8856 - acc: 0.008 - ETA: 3s - loss: 4.8857 - acc: 0.008 - ETA: 3s - loss: 4.8856 - acc: 0.008 - ETA: 3s - loss: 4.8855 - acc: 0.008 - ETA: 3s - loss: 4.8854 - acc: 0.008 - ETA: 3s - loss: 4.8853 - acc: 0.008 - ETA: 3s - loss: 4.8854 - acc: 0.008 - ETA: 3s - loss: 4.8854 - acc: 0.008 - ETA: 3s - loss: 4.8853 - acc: 0.008 - ETA: 3s - loss: 4.8852 - acc: 0.008 - ETA: 3s - loss: 4.8852 - acc: 0.008 - ETA: 3s - loss: 4.8851 - acc: 0.008 - ETA: 3s - loss: 4.8850 - acc: 0.008 - ETA: 3s - loss: 4.8849 - acc: 0.008 - ETA: 2s - loss: 4.8848 - acc: 0.008 - ETA: 2s - loss: 4.8848 - acc: 0.008 - ETA: 2s - loss: 4.8848 - acc: 0.008 - ETA: 2s - loss: 4.8846 - acc: 0.008 - ETA: 2s - loss: 4.8845 - acc: 0.008 - ETA: 2s - loss: 4.8846 - acc: 0.008 - ETA: 2s - loss: 4.8846 - acc: 0.008 - ETA: 2s - loss: 4.8845 - acc: 0.008 - ETA: 2s - loss: 4.8844 - acc: 0.008 - ETA: 2s - loss: 4.8844 - acc: 0.008 - ETA: 2s - loss: 4.8849 - acc: 0.008 - ETA: 2s - loss: 4.8849 - acc: 0.008 - ETA: 2s - loss: 4.8852 - acc: 0.008 - ETA: 1s - loss: 4.8852 - acc: 0.008 - ETA: 1s - loss: 4.8852 - acc: 0.008 - ETA: 1s - loss: 4.8853 - acc: 0.008 - ETA: 1s - loss: 4.8853 - acc: 0.008 - ETA: 1s - loss: 4.8851 - acc: 0.008 - ETA: 1s - loss: 4.8851 - acc: 0.008 - ETA: 1s - loss: 4.8850 - acc: 0.008 - ETA: 1s - loss: 4.8851 - acc: 0.008 - ETA: 1s - loss: 4.8849 - acc: 0.008 - ETA: 1s - loss: 4.8849 - acc: 0.008 - ETA: 1s - loss: 4.8850 - acc: 0.008 - ETA ...
#
# Epoch 00001: val_loss improved from inf to 4.86495, saving model to saved_models/weights.best.from_scratch.hdf5
# Epoch 2/5
# 4300/6680 [==================>...........] - ETA: 18s - loss: 4.8503 - acc: 0.0000e+ - ETA: 18s - loss: 4.8673 - acc: 0.0000e+ - ETA: 20s - loss: 4.8711 - acc: 0.0000e+ - ETA: 20s - loss: 4.8523 - acc: 0.0125   - ETA: 21s - loss: 4.8565 - acc: 0.02 - ETA: 22s - loss: 4.8555 - acc: 0.01 - ETA: 21s - loss: 4.8662 - acc: 0.01 - ETA: 21s - loss: 4.8621 - acc: 0.01 - ETA: 21s - loss: 4.8655 - acc: 0.01 - ETA: 21s - loss: 4.8614 - acc: 0.01 - ETA: 21s - loss: 4.8621 - acc: 0.00 - ETA: 21s - loss: 4.8555 - acc: 0.00 - ETA: 21s - loss: 4.8654 - acc: 0.00 - ETA: 21s - loss: 4.8665 - acc: 0.00 - ETA: 21s - loss: 4.8682 - acc: 0.00 - ETA: 21s - loss: 4.8692 - acc: 0.00 - ETA: 21s - loss: 4.8703 - acc: 0.01 - ETA: 21s - loss: 4.8713 - acc: 0.01 - ETA: 21s - loss: 4.8676 - acc: 0.01 - ETA: 21s - loss: 4.8664 - acc: 0.01 - ETA: 21s - loss: 4.8657 - acc: 0.01 - ETA: 21s - loss: 4.8649 - acc: 0.01 - ETA: 21s - loss: 4.8679 - acc: 0.01 - ETA: 21s - loss: 4.8628 - acc: 0.01 - ETA: 21s - loss: 4.8647 - acc: 0.01 - ETA: 21s - loss: 4.8652 - acc: 0.01 - ETA: 21s - loss: 4.8652 - acc: 0.01 - ETA: 21s - loss: 4.8646 - acc: 0.01 - ETA: 20s - loss: 4.8665 - acc: 0.01 - ETA: 20s - loss: 4.8659 - acc: 0.01 - ETA: 20s - loss: 4.8665 - acc: 0.01 - ETA: 21s - loss: 4.8648 - acc: 0.01 - ETA: 21s - loss: 4.8653 - acc: 0.01 - ETA: 22s - loss: 4.8649 - acc: 0.01 - ETA: 23s - loss: 4.8664 - acc: 0.01 - ETA: 23s - loss: 4.8671 - acc: 0.01 - ETA: 24s - loss: 4.8661 - acc: 0.01 - ETA: 24s - loss: 4.8660 - acc: 0.01 - ETA: 24s - loss: 4.8648 - acc: 0.01 - ETA: 24s - loss: 4.8637 - acc: 0.01 - ETA: 24s - loss: 4.8636 - acc: 0.01 - ETA: 23s - loss: 4.8642 - acc: 0.01 - ETA: 23s - loss: 4.8626 - acc: 0.01 - ETA: 23s - loss: 4.8638 - acc: 0.01 - ETA: 23s - loss: 4.8646 - acc: 0.01 - ETA: 23s - loss: 4.8655 - acc: 0.01 - ETA: 23s - loss: 4.8643 - acc: 0.01 - ETA: 23s - loss: 4.8656 - acc: 0.01 - ETA: 22s - loss: 4.8647 - acc: 0.01 - ETA: 22s - loss: 4.8647 - acc: 0.01 - ETA: 22s - loss: 4.8641 - acc: 0.01 - ETA: 22s - loss: 4.8629 - acc: 0.01 - ETA: 22s - loss: 4.8627 - acc: 0.01 - ETA: 22s - loss: 4.8630 - acc: 0.01 - ETA: 22s - loss: 4.8638 - acc: 0.01 - ETA: 22s - loss: 4.8624 - acc: 0.01 - ETA: 21s - loss: 4.8640 - acc: 0.01 - ETA: 21s - loss: 4.8639 - acc: 0.01 - ETA: 21s - loss: 4.8637 - acc: 0.01 - ETA: 21s - loss: 4.8633 - acc: 0.01 - ETA: 21s - loss: 4.8643 - acc: 0.01 - ETA: 21s - loss: 4.8626 - acc: 0.01 - ETA: 21s - loss: 4.8616 - acc: 0.01 - ETA: 21s - loss: 4.8607 - acc: 0.01 - ETA: 21s - loss: 4.8610 - acc: 0.01 - ETA: 20s - loss: 4.8609 - acc: 0.01 - ETA: 20s - loss: 4.8618 - acc: 0.01 - ETA: 20s - loss: 4.8615 - acc: 0.01 - ETA: 20s - loss: 4.8607 - acc: 0.01 - ETA: 20s - loss: 4.8604 - acc: 0.01 - ETA: 20s - loss: 4.8593 - acc: 0.01 - ETA: 20s - loss: 4.8585 - acc: 0.01 - ETA: 20s - loss: 4.8598 - acc: 0.01 - ETA: 20s - loss: 4.8607 - acc: 0.01 - ETA: 19s - loss: 4.8610 - acc: 0.01 - ETA: 19s - loss: 4.8612 - acc: 0.01 - ETA: 19s - loss: 4.8623 - acc: 0.01 - ETA: 19s - loss: 4.8611 - acc: 0.01 - ETA: 19s - loss: 4.8617 - acc: 0.01 - ETA: 19s - loss: 4.8616 - acc: 0.01 - ETA: 19s - loss: 4.8612 - acc: 0.01 - ETA: 19s - loss: 4.8612 - acc: 0.01 - ETA: 19s - loss: 4.8605 - acc: 0.01 - ETA: 19s - loss: 4.8595 - acc: 0.01 - ETA: 19s - loss: 4.8593 - acc: 0.01 - ETA: 18s - loss: 4.8584 - acc: 0.01 - ETA: 18s - loss: 4.8597 - acc: 0.01 - ETA: 18s - loss: 4.8594 - acc: 0.01 - ETA: 18s - loss: 4.8584 - acc: 0.01 - ETA: 18s - loss: 4.8581 - acc: 0.01 - ETA: 18s - loss: 4.8590 - acc: 0.01 - ETA: 18s - loss: 4.8601 - acc: 0.01 - ETA: 18s - loss: 4.8592 - acc: 0.01 - ETA: 18s - loss: 4.8591 - acc: 0.01 - ETA: 18s - loss: 4.8583 - acc: 0.01 - ETA: 18s - loss: 4.8575 - acc: 0.01 - ETA: 17s - loss: 4.8564 - acc: 0.01 - ETA: 17s - loss: 4.8573 - acc: 0.01 - ETA: 17s - loss: 4.8568 - acc: 0.01 - ETA: 17s - loss: 4.8567 - acc: 0.01 - ETA: 17s - loss: 4.8578 - acc: 0.01 - ETA: 17s - loss: 4.8578 - acc: 0.01 - ETA: 17s - loss: 4.8583 - acc: 0.01 - ETA: 17s - loss: 4.8589 - ...
# 6680/6680 [==============================] - ETA: 10s - loss: 4.8604 - acc: 0.01 - ETA: 10s - loss: 4.8606 - acc: 0.01 - ETA: 9s - loss: 4.8607 - acc: 0.0147 - ETA: 9s - loss: 4.8608 - acc: 0.014 - ETA: 9s - loss: 4.8605 - acc: 0.014 - ETA: 9s - loss: 4.8604 - acc: 0.014 - ETA: 9s - loss: 4.8598 - acc: 0.014 - ETA: 9s - loss: 4.8598 - acc: 0.014 - ETA: 9s - loss: 4.8595 - acc: 0.014 - ETA: 9s - loss: 4.8594 - acc: 0.014 - ETA: 9s - loss: 4.8596 - acc: 0.014 - ETA: 9s - loss: 4.8596 - acc: 0.014 - ETA: 9s - loss: 4.8596 - acc: 0.014 - ETA: 8s - loss: 4.8596 - acc: 0.014 - ETA: 8s - loss: 4.8596 - acc: 0.014 - ETA: 8s - loss: 4.8601 - acc: 0.014 - ETA: 8s - loss: 4.8602 - acc: 0.014 - ETA: 8s - loss: 4.8600 - acc: 0.014 - ETA: 8s - loss: 4.8600 - acc: 0.014 - ETA: 8s - loss: 4.8600 - acc: 0.014 - ETA: 8s - loss: 4.8601 - acc: 0.014 - ETA: 8s - loss: 4.8599 - acc: 0.014 - ETA: 8s - loss: 4.8601 - acc: 0.014 - ETA: 8s - loss: 4.8603 - acc: 0.014 - ETA: 7s - loss: 4.8603 - acc: 0.014 - ETA: 7s - loss: 4.8605 - acc: 0.014 - ETA: 7s - loss: 4.8608 - acc: 0.014 - ETA: 7s - loss: 4.8613 - acc: 0.014 - ETA: 7s - loss: 4.8611 - acc: 0.014 - ETA: 7s - loss: 4.8608 - acc: 0.014 - ETA: 7s - loss: 4.8607 - acc: 0.014 - ETA: 7s - loss: 4.8607 - acc: 0.014 - ETA: 7s - loss: 4.8606 - acc: 0.013 - ETA: 7s - loss: 4.8607 - acc: 0.013 - ETA: 7s - loss: 4.8607 - acc: 0.013 - ETA: 6s - loss: 4.8607 - acc: 0.013 - ETA: 6s - loss: 4.8607 - acc: 0.013 - ETA: 6s - loss: 4.8605 - acc: 0.013 - ETA: 6s - loss: 4.8603 - acc: 0.013 - ETA: 6s - loss: 4.8600 - acc: 0.013 - ETA: 6s - loss: 4.8601 - acc: 0.013 - ETA: 6s - loss: 4.8600 - acc: 0.013 - ETA: 6s - loss: 4.8601 - acc: 0.013 - ETA: 6s - loss: 4.8602 - acc: 0.013 - ETA: 6s - loss: 4.8601 - acc: 0.013 - ETA: 6s - loss: 4.8601 - acc: 0.013 - ETA: 5s - loss: 4.8598 - acc: 0.013 - ETA: 5s - loss: 4.8597 - acc: 0.013 - ETA: 5s - loss: 4.8593 - acc: 0.013 - ETA: 5s - loss: 4.8595 - acc: 0.013 - ETA: 5s - loss: 4.8599 - acc: 0.013 - ETA: 5s - loss: 4.8598 - acc: 0.013 - ETA: 5s - loss: 4.8597 - acc: 0.013 - ETA: 5s - loss: 4.8598 - acc: 0.013 - ETA: 5s - loss: 4.8597 - acc: 0.013 - ETA: 5s - loss: 4.8595 - acc: 0.013 - ETA: 5s - loss: 4.8595 - acc: 0.013 - ETA: 5s - loss: 4.8595 - acc: 0.013 - ETA: 4s - loss: 4.8592 - acc: 0.013 - ETA: 4s - loss: 4.8593 - acc: 0.013 - ETA: 4s - loss: 4.8592 - acc: 0.013 - ETA: 4s - loss: 4.8591 - acc: 0.013 - ETA: 4s - loss: 4.8591 - acc: 0.013 - ETA: 4s - loss: 4.8593 - acc: 0.013 - ETA: 4s - loss: 4.8592 - acc: 0.013 - ETA: 4s - loss: 4.8590 - acc: 0.013 - ETA: 4s - loss: 4.8590 - acc: 0.012 - ETA: 4s - loss: 4.8586 - acc: 0.012 - ETA: 4s - loss: 4.8590 - acc: 0.012 - ETA: 4s - loss: 4.8588 - acc: 0.013 - ETA: 3s - loss: 4.8588 - acc: 0.012 - ETA: 3s - loss: 4.8587 - acc: 0.012 - ETA: 3s - loss: 4.8584 - acc: 0.013 - ETA: 3s - loss: 4.8580 - acc: 0.013 - ETA: 3s - loss: 4.8577 - acc: 0.013 - ETA: 3s - loss: 4.8576 - acc: 0.013 - ETA: 3s - loss: 4.8572 - acc: 0.013 - ETA: 3s - loss: 4.8569 - acc: 0.013 - ETA: 3s - loss: 4.8566 - acc: 0.013 - ETA: 3s - loss: 4.8564 - acc: 0.013 - ETA: 3s - loss: 4.8565 - acc: 0.013 - ETA: 3s - loss: 4.8560 - acc: 0.013 - ETA: 2s - loss: 4.8558 - acc: 0.013 - ETA: 2s - loss: 4.8559 - acc: 0.013 - ETA: 2s - loss: 4.8555 - acc: 0.013 - ETA: 2s - loss: 4.8555 - acc: 0.013 - ETA: 2s - loss: 4.8554 - acc: 0.013 - ETA: 2s - loss: 4.8550 - acc: 0.013 - ETA: 2s - loss: 4.8550 - acc: 0.013 - ETA: 2s - loss: 4.8547 - acc: 0.013 - ETA: 2s - loss: 4.8546 - acc: 0.013 - ETA: 2s - loss: 4.8551 - acc: 0.013 - ETA: 2s - loss: 4.8552 - acc: 0.013 - ETA: 2s - loss: 4.8551 - acc: 0.013 - ETA: 1s - loss: 4.8550 - acc: 0.013 - ETA: 1s - loss: 4.8552 - acc: 0.013 - ETA: 1s - loss: 4.8550 - acc: 0.013 - ETA: 1s - loss: 4.8551 - acc: 0.013 - ETA: 1s - loss: 4.8552 - acc: 0.013 - ETA: 1s - loss: 4.8550 - acc: 0.013 - ETA: 1s - loss: 4.8552 - acc: 0.013 - ETA: 1s - loss: 4.8554 - acc: 0.013 - ETA: 1s - loss: 4.8557 - acc: 0.013 - ETA: 1s - loss: 4.8558 - acc: 0.013 - ET ...
#
# Epoch 00002: val_loss improved from 4.86495 to 4.83560, saving model to saved_models/weights.best.from_scratch.hdf5
# Epoch 3/5
# 4300/6680 [==================>...........] - ETA: 19s - loss: 4.8373 - acc: 0.0000e+ - ETA: 23s - loss: 4.8567 - acc: 0.0000e+ - ETA: 23s - loss: 4.8356 - acc: 0.0000e+ - ETA: 23s - loss: 4.8101 - acc: 0.0250   - ETA: 23s - loss: 4.8057 - acc: 0.02 - ETA: 23s - loss: 4.8121 - acc: 0.02 - ETA: 23s - loss: 4.8136 - acc: 0.02 - ETA: 22s - loss: 4.8272 - acc: 0.02 - ETA: 22s - loss: 4.8256 - acc: 0.02 - ETA: 22s - loss: 4.8260 - acc: 0.02 - ETA: 22s - loss: 4.8179 - acc: 0.02 - ETA: 22s - loss: 4.8158 - acc: 0.02 - ETA: 22s - loss: 4.8211 - acc: 0.01 - ETA: 22s - loss: 4.8216 - acc: 0.01 - ETA: 22s - loss: 4.8329 - acc: 0.01 - ETA: 24s - loss: 4.8360 - acc: 0.01 - ETA: 25s - loss: 4.8331 - acc: 0.01 - ETA: 26s - loss: 4.8279 - acc: 0.01 - ETA: 27s - loss: 4.8262 - acc: 0.01 - ETA: 28s - loss: 4.8254 - acc: 0.01 - ETA: 29s - loss: 4.8217 - acc: 0.01 - ETA: 29s - loss: 4.8243 - acc: 0.01 - ETA: 28s - loss: 4.8211 - acc: 0.01 - ETA: 28s - loss: 4.8217 - acc: 0.01 - ETA: 28s - loss: 4.8242 - acc: 0.01 - ETA: 27s - loss: 4.8217 - acc: 0.01 - ETA: 27s - loss: 4.8208 - acc: 0.01 - ETA: 27s - loss: 4.8160 - acc: 0.01 - ETA: 26s - loss: 4.8176 - acc: 0.01 - ETA: 26s - loss: 4.8212 - acc: 0.01 - ETA: 26s - loss: 4.8195 - acc: 0.01 - ETA: 25s - loss: 4.8184 - acc: 0.01 - ETA: 25s - loss: 4.8215 - acc: 0.01 - ETA: 25s - loss: 4.8188 - acc: 0.01 - ETA: 25s - loss: 4.8151 - acc: 0.01 - ETA: 25s - loss: 4.8153 - acc: 0.01 - ETA: 25s - loss: 4.8150 - acc: 0.01 - ETA: 24s - loss: 4.8183 - acc: 0.01 - ETA: 24s - loss: 4.8162 - acc: 0.01 - ETA: 24s - loss: 4.8168 - acc: 0.01 - ETA: 24s - loss: 4.8169 - acc: 0.01 - ETA: 24s - loss: 4.8173 - acc: 0.01 - ETA: 24s - loss: 4.8162 - acc: 0.01 - ETA: 23s - loss: 4.8161 - acc: 0.02 - ETA: 23s - loss: 4.8134 - acc: 0.02 - ETA: 23s - loss: 4.8130 - acc: 0.02 - ETA: 23s - loss: 4.8149 - acc: 0.02 - ETA: 23s - loss: 4.8159 - acc: 0.01 - ETA: 23s - loss: 4.8175 - acc: 0.01 - ETA: 23s - loss: 4.8142 - acc: 0.02 - ETA: 22s - loss: 4.8133 - acc: 0.02 - ETA: 22s - loss: 4.8129 - acc: 0.02 - ETA: 22s - loss: 4.8101 - acc: 0.02 - ETA: 22s - loss: 4.8092 - acc: 0.02 - ETA: 22s - loss: 4.8073 - acc: 0.02 - ETA: 22s - loss: 4.8088 - acc: 0.02 - ETA: 22s - loss: 4.8082 - acc: 0.02 - ETA: 22s - loss: 4.8077 - acc: 0.02 - ETA: 21s - loss: 4.8076 - acc: 0.02 - ETA: 21s - loss: 4.8091 - acc: 0.02 - ETA: 21s - loss: 4.8062 - acc: 0.02 - ETA: 21s - loss: 4.8037 - acc: 0.02 - ETA: 21s - loss: 4.8052 - acc: 0.02 - ETA: 21s - loss: 4.8072 - acc: 0.02 - ETA: 21s - loss: 4.8083 - acc: 0.02 - ETA: 21s - loss: 4.8090 - acc: 0.02 - ETA: 21s - loss: 4.8107 - acc: 0.02 - ETA: 20s - loss: 4.8116 - acc: 0.02 - ETA: 20s - loss: 4.8121 - acc: 0.02 - ETA: 20s - loss: 4.8133 - acc: 0.02 - ETA: 20s - loss: 4.8129 - acc: 0.02 - ETA: 20s - loss: 4.8145 - acc: 0.02 - ETA: 20s - loss: 4.8146 - acc: 0.02 - ETA: 20s - loss: 4.8158 - acc: 0.02 - ETA: 20s - loss: 4.8161 - acc: 0.02 - ETA: 20s - loss: 4.8163 - acc: 0.01 - ETA: 20s - loss: 4.8181 - acc: 0.02 - ETA: 19s - loss: 4.8190 - acc: 0.01 - ETA: 19s - loss: 4.8181 - acc: 0.02 - ETA: 19s - loss: 4.8183 - acc: 0.02 - ETA: 19s - loss: 4.8180 - acc: 0.02 - ETA: 19s - loss: 4.8179 - acc: 0.02 - ETA: 19s - loss: 4.8177 - acc: 0.02 - ETA: 19s - loss: 4.8166 - acc: 0.02 - ETA: 19s - loss: 4.8167 - acc: 0.02 - ETA: 19s - loss: 4.8159 - acc: 0.02 - ETA: 19s - loss: 4.8154 - acc: 0.02 - ETA: 18s - loss: 4.8146 - acc: 0.02 - ETA: 18s - loss: 4.8150 - acc: 0.02 - ETA: 18s - loss: 4.8144 - acc: 0.02 - ETA: 18s - loss: 4.8144 - acc: 0.02 - ETA: 18s - loss: 4.8141 - acc: 0.02 - ETA: 18s - loss: 4.8142 - acc: 0.02 - ETA: 18s - loss: 4.8140 - acc: 0.02 - ETA: 18s - loss: 4.8136 - acc: 0.02 - ETA: 18s - loss: 4.8148 - acc: 0.02 - ETA: 18s - loss: 4.8142 - acc: 0.02 - ETA: 18s - loss: 4.8143 - acc: 0.02 - ETA: 17s - loss: 4.8155 - acc: 0.02 - ETA: 17s - loss: 4.8156 - acc: 0.02 - ETA: 17s - loss: 4.8158 - acc: 0.02 - ETA: 17s - loss: 4.8167 - acc: 0.02 - ETA: 17s - loss: 4.8165 - acc: 0.02 - ETA: 17s - loss: 4.8167 - ...
# 6680/6680 [==============================] - ETA: 8s - loss: 4.8195 - acc: 0.018 - ETA: 8s - loss: 4.8195 - acc: 0.018 - ETA: 8s - loss: 4.8195 - acc: 0.017 - ETA: 8s - loss: 4.8185 - acc: 0.017 - ETA: 8s - loss: 4.8175 - acc: 0.017 - ETA: 8s - loss: 4.8178 - acc: 0.017 - ETA: 8s - loss: 4.8179 - acc: 0.017 - ETA: 8s - loss: 4.8176 - acc: 0.017 - ETA: 8s - loss: 4.8168 - acc: 0.017 - ETA: 8s - loss: 4.8166 - acc: 0.018 - ETA: 8s - loss: 4.8158 - acc: 0.017 - ETA: 7s - loss: 4.8163 - acc: 0.017 - ETA: 7s - loss: 4.8167 - acc: 0.017 - ETA: 7s - loss: 4.8167 - acc: 0.017 - ETA: 7s - loss: 4.8168 - acc: 0.018 - ETA: 7s - loss: 4.8162 - acc: 0.018 - ETA: 7s - loss: 4.8160 - acc: 0.018 - ETA: 7s - loss: 4.8159 - acc: 0.018 - ETA: 7s - loss: 4.8157 - acc: 0.017 - ETA: 7s - loss: 4.8154 - acc: 0.017 - ETA: 7s - loss: 4.8151 - acc: 0.017 - ETA: 7s - loss: 4.8150 - acc: 0.017 - ETA: 7s - loss: 4.8149 - acc: 0.017 - ETA: 7s - loss: 4.8152 - acc: 0.017 - ETA: 6s - loss: 4.8151 - acc: 0.017 - ETA: 6s - loss: 4.8157 - acc: 0.017 - ETA: 6s - loss: 4.8159 - acc: 0.017 - ETA: 6s - loss: 4.8164 - acc: 0.017 - ETA: 6s - loss: 4.8158 - acc: 0.017 - ETA: 6s - loss: 4.8157 - acc: 0.017 - ETA: 6s - loss: 4.8163 - acc: 0.017 - ETA: 6s - loss: 4.8164 - acc: 0.017 - ETA: 6s - loss: 4.8161 - acc: 0.017 - ETA: 6s - loss: 4.8158 - acc: 0.017 - ETA: 6s - loss: 4.8159 - acc: 0.017 - ETA: 6s - loss: 4.8157 - acc: 0.017 - ETA: 6s - loss: 4.8164 - acc: 0.017 - ETA: 5s - loss: 4.8160 - acc: 0.017 - ETA: 5s - loss: 4.8160 - acc: 0.017 - ETA: 5s - loss: 4.8159 - acc: 0.017 - ETA: 5s - loss: 4.8153 - acc: 0.018 - ETA: 5s - loss: 4.8154 - acc: 0.017 - ETA: 5s - loss: 4.8145 - acc: 0.018 - ETA: 5s - loss: 4.8146 - acc: 0.018 - ETA: 5s - loss: 4.8144 - acc: 0.017 - ETA: 5s - loss: 4.8149 - acc: 0.017 - ETA: 5s - loss: 4.8148 - acc: 0.017 - ETA: 5s - loss: 4.8150 - acc: 0.017 - ETA: 5s - loss: 4.8153 - acc: 0.017 - ETA: 5s - loss: 4.8149 - acc: 0.017 - ETA: 5s - loss: 4.8144 - acc: 0.018 - ETA: 4s - loss: 4.8143 - acc: 0.018 - ETA: 4s - loss: 4.8141 - acc: 0.018 - ETA: 4s - loss: 4.8138 - acc: 0.018 - ETA: 4s - loss: 4.8137 - acc: 0.018 - ETA: 4s - loss: 4.8136 - acc: 0.018 - ETA: 4s - loss: 4.8141 - acc: 0.018 - ETA: 4s - loss: 4.8145 - acc: 0.017 - ETA: 4s - loss: 4.8144 - acc: 0.017 - ETA: 4s - loss: 4.8143 - acc: 0.017 - ETA: 4s - loss: 4.8139 - acc: 0.017 - ETA: 4s - loss: 4.8140 - acc: 0.017 - ETA: 4s - loss: 4.8137 - acc: 0.018 - ETA: 4s - loss: 4.8135 - acc: 0.017 - ETA: 3s - loss: 4.8132 - acc: 0.017 - ETA: 3s - loss: 4.8129 - acc: 0.018 - ETA: 3s - loss: 4.8130 - acc: 0.017 - ETA: 3s - loss: 4.8130 - acc: 0.017 - ETA: 3s - loss: 4.8133 - acc: 0.017 - ETA: 3s - loss: 4.8136 - acc: 0.017 - ETA: 3s - loss: 4.8133 - acc: 0.017 - ETA: 3s - loss: 4.8141 - acc: 0.017 - ETA: 3s - loss: 4.8136 - acc: 0.017 - ETA: 3s - loss: 4.8133 - acc: 0.018 - ETA: 3s - loss: 4.8130 - acc: 0.018 - ETA: 3s - loss: 4.8127 - acc: 0.018 - ETA: 3s - loss: 4.8130 - acc: 0.018 - ETA: 3s - loss: 4.8133 - acc: 0.017 - ETA: 2s - loss: 4.8136 - acc: 0.017 - ETA: 2s - loss: 4.8136 - acc: 0.017 - ETA: 2s - loss: 4.8134 - acc: 0.017 - ETA: 2s - loss: 4.8130 - acc: 0.017 - ETA: 2s - loss: 4.8130 - acc: 0.017 - ETA: 2s - loss: 4.8125 - acc: 0.017 - ETA: 2s - loss: 4.8123 - acc: 0.017 - ETA: 2s - loss: 4.8122 - acc: 0.017 - ETA: 2s - loss: 4.8118 - acc: 0.018 - ETA: 2s - loss: 4.8125 - acc: 0.018 - ETA: 2s - loss: 4.8121 - acc: 0.017 - ETA: 2s - loss: 4.8120 - acc: 0.017 - ETA: 2s - loss: 4.8123 - acc: 0.017 - ETA: 1s - loss: 4.8117 - acc: 0.018 - ETA: 1s - loss: 4.8120 - acc: 0.018 - ETA: 1s - loss: 4.8120 - acc: 0.018 - ETA: 1s - loss: 4.8120 - acc: 0.017 - ETA: 1s - loss: 4.8123 - acc: 0.017 - ETA: 1s - loss: 4.8126 - acc: 0.017 - ETA: 1s - loss: 4.8123 - acc: 0.017 - ETA: 1s - loss: 4.8121 - acc: 0.017 - ETA: 1s - loss: 4.8119 - acc: 0.017 - ETA: 1s - loss: 4.8122 - acc: 0.017 - ETA: 1s - loss: 4.8120 - acc: 0.017 - ETA: 1s - loss: 4.8118 - acc: 0.017 - ETA: 1s - loss: 4.8114 - acc: 0.017 - ETA ...
#
# Epoch 00003: val_loss improved from 4.83560 to 4.80003, saving model to saved_models/weights.best.from_scratch.hdf5
# Epoch 4/5
# 4280/6680 [==================>...........] - ETA: 20s - loss: 5.0125 - acc: 0.0000e+ - ETA: 22s - loss: 4.9217 - acc: 0.0000e+ - ETA: 23s - loss: 4.9038 - acc: 0.0000e+ - ETA: 24s - loss: 4.8573 - acc: 0.0000e+ - ETA: 24s - loss: 4.8498 - acc: 0.0000e+ - ETA: 24s - loss: 4.8605 - acc: 0.0000e+ - ETA: 24s - loss: 4.8470 - acc: 0.0000e+ - ETA: 24s - loss: 4.8416 - acc: 0.0063   - ETA: 23s - loss: 4.8376 - acc: 0.00 - ETA: 23s - loss: 4.8208 - acc: 0.00 - ETA: 23s - loss: 4.8237 - acc: 0.00 - ETA: 23s - loss: 4.8104 - acc: 0.01 - ETA: 23s - loss: 4.8014 - acc: 0.01 - ETA: 23s - loss: 4.8008 - acc: 0.01 - ETA: 23s - loss: 4.7983 - acc: 0.01 - ETA: 23s - loss: 4.7906 - acc: 0.00 - ETA: 23s - loss: 4.8042 - acc: 0.00 - ETA: 22s - loss: 4.8027 - acc: 0.00 - ETA: 22s - loss: 4.8012 - acc: 0.00 - ETA: 22s - loss: 4.7976 - acc: 0.01 - ETA: 22s - loss: 4.7912 - acc: 0.01 - ETA: 22s - loss: 4.7963 - acc: 0.01 - ETA: 22s - loss: 4.7977 - acc: 0.01 - ETA: 22s - loss: 4.7981 - acc: 0.01 - ETA: 22s - loss: 4.8012 - acc: 0.01 - ETA: 22s - loss: 4.7958 - acc: 0.01 - ETA: 22s - loss: 4.7933 - acc: 0.01 - ETA: 22s - loss: 4.7929 - acc: 0.01 - ETA: 21s - loss: 4.7946 - acc: 0.01 - ETA: 21s - loss: 4.7956 - acc: 0.01 - ETA: 21s - loss: 4.7931 - acc: 0.02 - ETA: 21s - loss: 4.7899 - acc: 0.02 - ETA: 21s - loss: 4.7903 - acc: 0.01 - ETA: 21s - loss: 4.7921 - acc: 0.01 - ETA: 21s - loss: 4.7886 - acc: 0.01 - ETA: 21s - loss: 4.7983 - acc: 0.01 - ETA: 21s - loss: 4.8026 - acc: 0.01 - ETA: 21s - loss: 4.8004 - acc: 0.01 - ETA: 21s - loss: 4.8007 - acc: 0.02 - ETA: 21s - loss: 4.8007 - acc: 0.02 - ETA: 21s - loss: 4.7977 - acc: 0.02 - ETA: 21s - loss: 4.7964 - acc: 0.02 - ETA: 20s - loss: 4.7971 - acc: 0.02 - ETA: 20s - loss: 4.7971 - acc: 0.02 - ETA: 20s - loss: 4.7947 - acc: 0.02 - ETA: 20s - loss: 4.7978 - acc: 0.02 - ETA: 20s - loss: 4.7968 - acc: 0.02 - ETA: 20s - loss: 4.7939 - acc: 0.02 - ETA: 20s - loss: 4.7926 - acc: 0.02 - ETA: 20s - loss: 4.7912 - acc: 0.02 - ETA: 20s - loss: 4.7893 - acc: 0.02 - ETA: 20s - loss: 4.7877 - acc: 0.02 - ETA: 20s - loss: 4.7868 - acc: 0.02 - ETA: 20s - loss: 4.7854 - acc: 0.02 - ETA: 20s - loss: 4.7836 - acc: 0.02 - ETA: 20s - loss: 4.7867 - acc: 0.02 - ETA: 20s - loss: 4.7866 - acc: 0.02 - ETA: 20s - loss: 4.7881 - acc: 0.01 - ETA: 19s - loss: 4.7868 - acc: 0.01 - ETA: 19s - loss: 4.7864 - acc: 0.01 - ETA: 19s - loss: 4.7824 - acc: 0.01 - ETA: 19s - loss: 4.7854 - acc: 0.01 - ETA: 19s - loss: 4.7870 - acc: 0.01 - ETA: 19s - loss: 4.7852 - acc: 0.01 - ETA: 19s - loss: 4.7841 - acc: 0.01 - ETA: 19s - loss: 4.7832 - acc: 0.01 - ETA: 19s - loss: 4.7831 - acc: 0.01 - ETA: 19s - loss: 4.7808 - acc: 0.01 - ETA: 19s - loss: 4.7796 - acc: 0.01 - ETA: 19s - loss: 4.7817 - acc: 0.01 - ETA: 19s - loss: 4.7847 - acc: 0.01 - ETA: 19s - loss: 4.7839 - acc: 0.01 - ETA: 18s - loss: 4.7850 - acc: 0.01 - ETA: 18s - loss: 4.7861 - acc: 0.01 - ETA: 18s - loss: 4.7841 - acc: 0.01 - ETA: 18s - loss: 4.7845 - acc: 0.01 - ETA: 18s - loss: 4.7852 - acc: 0.01 - ETA: 18s - loss: 4.7865 - acc: 0.01 - ETA: 18s - loss: 4.7858 - acc: 0.01 - ETA: 18s - loss: 4.7869 - acc: 0.01 - ETA: 18s - loss: 4.7858 - acc: 0.01 - ETA: 18s - loss: 4.7855 - acc: 0.01 - ETA: 18s - loss: 4.7850 - acc: 0.01 - ETA: 18s - loss: 4.7865 - acc: 0.01 - ETA: 18s - loss: 4.7857 - acc: 0.01 - ETA: 18s - loss: 4.7853 - acc: 0.01 - ETA: 17s - loss: 4.7874 - acc: 0.01 - ETA: 17s - loss: 4.7868 - acc: 0.01 - ETA: 17s - loss: 4.7870 - acc: 0.01 - ETA: 17s - loss: 4.7837 - acc: 0.02 - ETA: 17s - loss: 4.7837 - acc: 0.01 - ETA: 17s - loss: 4.7838 - acc: 0.01 - ETA: 17s - loss: 4.7796 - acc: 0.02 - ETA: 17s - loss: 4.7807 - acc: 0.02 - ETA: 17s - loss: 4.7811 - acc: 0.02 - ETA: 17s - loss: 4.7813 - acc: 0.02 - ETA: 17s - loss: 4.7819 - acc: 0.02 - ETA: 17s - loss: 4.7809 - acc: 0.02 - ETA: 17s - loss: 4.7814 - acc: 0.02 - ETA: 16s - loss: 4.7798 - acc: 0.02 - ETA: 16s - loss: 4.7781 - acc: 0.02 - ETA: 16s - loss: 4.7779 - acc: 0.02 - ETA: 16s - loss: 4.7761 - acc: 0.02 - ETA: 16s  ...
# 6680/6680 [==============================] - ETA: 8s - loss: 4.7778 - acc: 0.023 - ETA: 8s - loss: 4.7791 - acc: 0.023 - ETA: 8s - loss: 4.7788 - acc: 0.023 - ETA: 8s - loss: 4.7789 - acc: 0.023 - ETA: 8s - loss: 4.7783 - acc: 0.023 - ETA: 8s - loss: 4.7785 - acc: 0.023 - ETA: 8s - loss: 4.7791 - acc: 0.023 - ETA: 8s - loss: 4.7789 - acc: 0.023 - ETA: 8s - loss: 4.7786 - acc: 0.023 - ETA: 8s - loss: 4.7786 - acc: 0.023 - ETA: 7s - loss: 4.7779 - acc: 0.023 - ETA: 7s - loss: 4.7776 - acc: 0.023 - ETA: 7s - loss: 4.7771 - acc: 0.023 - ETA: 7s - loss: 4.7768 - acc: 0.023 - ETA: 7s - loss: 4.7769 - acc: 0.023 - ETA: 7s - loss: 4.7766 - acc: 0.023 - ETA: 7s - loss: 4.7771 - acc: 0.023 - ETA: 7s - loss: 4.7770 - acc: 0.023 - ETA: 7s - loss: 4.7764 - acc: 0.023 - ETA: 7s - loss: 4.7766 - acc: 0.023 - ETA: 7s - loss: 4.7760 - acc: 0.023 - ETA: 7s - loss: 4.7754 - acc: 0.023 - ETA: 7s - loss: 4.7750 - acc: 0.023 - ETA: 7s - loss: 4.7754 - acc: 0.023 - ETA: 6s - loss: 4.7749 - acc: 0.023 - ETA: 6s - loss: 4.7751 - acc: 0.024 - ETA: 6s - loss: 4.7752 - acc: 0.024 - ETA: 6s - loss: 4.7754 - acc: 0.024 - ETA: 6s - loss: 4.7752 - acc: 0.024 - ETA: 6s - loss: 4.7751 - acc: 0.024 - ETA: 6s - loss: 4.7752 - acc: 0.023 - ETA: 6s - loss: 4.7752 - acc: 0.024 - ETA: 6s - loss: 4.7747 - acc: 0.023 - ETA: 6s - loss: 4.7741 - acc: 0.023 - ETA: 6s - loss: 4.7732 - acc: 0.024 - ETA: 6s - loss: 4.7736 - acc: 0.024 - ETA: 6s - loss: 4.7727 - acc: 0.023 - ETA: 6s - loss: 4.7736 - acc: 0.023 - ETA: 5s - loss: 4.7728 - acc: 0.023 - ETA: 5s - loss: 4.7726 - acc: 0.023 - ETA: 5s - loss: 4.7721 - acc: 0.023 - ETA: 5s - loss: 4.7714 - acc: 0.023 - ETA: 5s - loss: 4.7720 - acc: 0.023 - ETA: 5s - loss: 4.7716 - acc: 0.023 - ETA: 5s - loss: 4.7717 - acc: 0.023 - ETA: 5s - loss: 4.7718 - acc: 0.023 - ETA: 5s - loss: 4.7711 - acc: 0.023 - ETA: 5s - loss: 4.7710 - acc: 0.023 - ETA: 5s - loss: 4.7705 - acc: 0.023 - ETA: 5s - loss: 4.7707 - acc: 0.023 - ETA: 5s - loss: 4.7713 - acc: 0.023 - ETA: 4s - loss: 4.7718 - acc: 0.023 - ETA: 4s - loss: 4.7718 - acc: 0.023 - ETA: 4s - loss: 4.7714 - acc: 0.023 - ETA: 4s - loss: 4.7713 - acc: 0.023 - ETA: 4s - loss: 4.7714 - acc: 0.023 - ETA: 4s - loss: 4.7713 - acc: 0.023 - ETA: 4s - loss: 4.7710 - acc: 0.023 - ETA: 4s - loss: 4.7704 - acc: 0.023 - ETA: 4s - loss: 4.7707 - acc: 0.023 - ETA: 4s - loss: 4.7707 - acc: 0.023 - ETA: 4s - loss: 4.7707 - acc: 0.023 - ETA: 4s - loss: 4.7708 - acc: 0.023 - ETA: 4s - loss: 4.7713 - acc: 0.023 - ETA: 4s - loss: 4.7712 - acc: 0.023 - ETA: 3s - loss: 4.7711 - acc: 0.023 - ETA: 3s - loss: 4.7714 - acc: 0.023 - ETA: 3s - loss: 4.7709 - acc: 0.023 - ETA: 3s - loss: 4.7705 - acc: 0.023 - ETA: 3s - loss: 4.7698 - acc: 0.023 - ETA: 3s - loss: 4.7696 - acc: 0.023 - ETA: 3s - loss: 4.7689 - acc: 0.023 - ETA: 3s - loss: 4.7687 - acc: 0.023 - ETA: 3s - loss: 4.7693 - acc: 0.023 - ETA: 3s - loss: 4.7688 - acc: 0.023 - ETA: 3s - loss: 4.7681 - acc: 0.023 - ETA: 3s - loss: 4.7683 - acc: 0.023 - ETA: 3s - loss: 4.7682 - acc: 0.022 - ETA: 2s - loss: 4.7682 - acc: 0.023 - ETA: 2s - loss: 4.7687 - acc: 0.023 - ETA: 2s - loss: 4.7687 - acc: 0.022 - ETA: 2s - loss: 4.7684 - acc: 0.023 - ETA: 2s - loss: 4.7688 - acc: 0.022 - ETA: 2s - loss: 4.7690 - acc: 0.022 - ETA: 2s - loss: 4.7689 - acc: 0.022 - ETA: 2s - loss: 4.7696 - acc: 0.022 - ETA: 2s - loss: 4.7700 - acc: 0.022 - ETA: 2s - loss: 4.7704 - acc: 0.022 - ETA: 2s - loss: 4.7716 - acc: 0.022 - ETA: 2s - loss: 4.7715 - acc: 0.022 - ETA: 2s - loss: 4.7711 - acc: 0.022 - ETA: 2s - loss: 4.7712 - acc: 0.022 - ETA: 1s - loss: 4.7715 - acc: 0.022 - ETA: 1s - loss: 4.7710 - acc: 0.022 - ETA: 1s - loss: 4.7714 - acc: 0.022 - ETA: 1s - loss: 4.7713 - acc: 0.022 - ETA: 1s - loss: 4.7716 - acc: 0.022 - ETA: 1s - loss: 4.7714 - acc: 0.022 - ETA: 1s - loss: 4.7711 - acc: 0.022 - ETA: 1s - loss: 4.7715 - acc: 0.023 - ETA: 1s - loss: 4.7715 - acc: 0.023 - ETA: 1s - loss: 4.7721 - acc: 0.023 - ETA: 1s - loss: 4.7719 - acc: 0.023 - ETA: 1s - loss: 4.7719 - acc: 0.023 - ETA ...
#
# Epoch 00004: val_loss improved from 4.80003 to 4.78056, saving model to saved_models/weights.best.from_scratch.hdf5
# Epoch 5/5
# 4300/6680 [==================>...........] - ETA: 22s - loss: 4.8568 - acc: 0.0000e+ - ETA: 26s - loss: 4.8342 - acc: 0.0250   - ETA: 25s - loss: 4.8059 - acc: 0.05 - ETA: 25s - loss: 4.8326 - acc: 0.03 - ETA: 24s - loss: 4.8256 - acc: 0.03 - ETA: 24s - loss: 4.8149 - acc: 0.03 - ETA: 24s - loss: 4.8157 - acc: 0.02 - ETA: 24s - loss: 4.8139 - acc: 0.02 - ETA: 23s - loss: 4.8188 - acc: 0.02 - ETA: 23s - loss: 4.8018 - acc: 0.03 - ETA: 23s - loss: 4.7909 - acc: 0.03 - ETA: 23s - loss: 4.7672 - acc: 0.03 - ETA: 23s - loss: 4.7604 - acc: 0.03 - ETA: 23s - loss: 4.7607 - acc: 0.02 - ETA: 23s - loss: 4.7707 - acc: 0.03 - ETA: 23s - loss: 4.7645 - acc: 0.02 - ETA: 23s - loss: 4.7658 - acc: 0.02 - ETA: 23s - loss: 4.7635 - acc: 0.02 - ETA: 23s - loss: 4.7633 - acc: 0.02 - ETA: 23s - loss: 4.7597 - acc: 0.02 - ETA: 23s - loss: 4.7670 - acc: 0.02 - ETA: 23s - loss: 4.7687 - acc: 0.02 - ETA: 22s - loss: 4.7709 - acc: 0.02 - ETA: 22s - loss: 4.7639 - acc: 0.02 - ETA: 22s - loss: 4.7631 - acc: 0.02 - ETA: 22s - loss: 4.7612 - acc: 0.02 - ETA: 22s - loss: 4.7612 - acc: 0.02 - ETA: 22s - loss: 4.7575 - acc: 0.02 - ETA: 22s - loss: 4.7518 - acc: 0.02 - ETA: 22s - loss: 4.7518 - acc: 0.02 - ETA: 22s - loss: 4.7525 - acc: 0.02 - ETA: 22s - loss: 4.7516 - acc: 0.02 - ETA: 22s - loss: 4.7562 - acc: 0.02 - ETA: 21s - loss: 4.7569 - acc: 0.02 - ETA: 21s - loss: 4.7610 - acc: 0.02 - ETA: 21s - loss: 4.7632 - acc: 0.02 - ETA: 21s - loss: 4.7622 - acc: 0.02 - ETA: 21s - loss: 4.7609 - acc: 0.01 - ETA: 21s - loss: 4.7609 - acc: 0.02 - ETA: 21s - loss: 4.7606 - acc: 0.02 - ETA: 21s - loss: 4.7601 - acc: 0.02 - ETA: 21s - loss: 4.7569 - acc: 0.02 - ETA: 21s - loss: 4.7560 - acc: 0.02 - ETA: 21s - loss: 4.7536 - acc: 0.02 - ETA: 21s - loss: 4.7544 - acc: 0.02 - ETA: 21s - loss: 4.7548 - acc: 0.02 - ETA: 21s - loss: 4.7499 - acc: 0.02 - ETA: 21s - loss: 4.7512 - acc: 0.02 - ETA: 20s - loss: 4.7495 - acc: 0.02 - ETA: 20s - loss: 4.7496 - acc: 0.02 - ETA: 20s - loss: 4.7489 - acc: 0.02 - ETA: 20s - loss: 4.7443 - acc: 0.02 - ETA: 20s - loss: 4.7425 - acc: 0.02 - ETA: 20s - loss: 4.7429 - acc: 0.02 - ETA: 20s - loss: 4.7446 - acc: 0.02 - ETA: 20s - loss: 4.7455 - acc: 0.02 - ETA: 20s - loss: 4.7477 - acc: 0.02 - ETA: 20s - loss: 4.7489 - acc: 0.02 - ETA: 20s - loss: 4.7457 - acc: 0.02 - ETA: 20s - loss: 4.7448 - acc: 0.02 - ETA: 19s - loss: 4.7471 - acc: 0.02 - ETA: 19s - loss: 4.7481 - acc: 0.02 - ETA: 19s - loss: 4.7527 - acc: 0.01 - ETA: 19s - loss: 4.7545 - acc: 0.01 - ETA: 19s - loss: 4.7536 - acc: 0.01 - ETA: 19s - loss: 4.7520 - acc: 0.01 - ETA: 19s - loss: 4.7488 - acc: 0.01 - ETA: 19s - loss: 4.7476 - acc: 0.02 - ETA: 19s - loss: 4.7446 - acc: 0.02 - ETA: 19s - loss: 4.7459 - acc: 0.02 - ETA: 19s - loss: 4.7447 - acc: 0.02 - ETA: 18s - loss: 4.7470 - acc: 0.02 - ETA: 18s - loss: 4.7451 - acc: 0.02 - ETA: 18s - loss: 4.7420 - acc: 0.02 - ETA: 18s - loss: 4.7414 - acc: 0.02 - ETA: 18s - loss: 4.7439 - acc: 0.02 - ETA: 18s - loss: 4.7429 - acc: 0.02 - ETA: 18s - loss: 4.7448 - acc: 0.02 - ETA: 18s - loss: 4.7475 - acc: 0.02 - ETA: 18s - loss: 4.7473 - acc: 0.02 - ETA: 18s - loss: 4.7465 - acc: 0.02 - ETA: 18s - loss: 4.7484 - acc: 0.02 - ETA: 18s - loss: 4.7465 - acc: 0.02 - ETA: 18s - loss: 4.7461 - acc: 0.02 - ETA: 17s - loss: 4.7438 - acc: 0.02 - ETA: 17s - loss: 4.7418 - acc: 0.02 - ETA: 17s - loss: 4.7420 - acc: 0.02 - ETA: 17s - loss: 4.7397 - acc: 0.02 - ETA: 17s - loss: 4.7386 - acc: 0.02 - ETA: 17s - loss: 4.7383 - acc: 0.02 - ETA: 17s - loss: 4.7372 - acc: 0.02 - ETA: 17s - loss: 4.7371 - acc: 0.02 - ETA: 17s - loss: 4.7378 - acc: 0.02 - ETA: 17s - loss: 4.7365 - acc: 0.02 - ETA: 17s - loss: 4.7354 - acc: 0.02 - ETA: 17s - loss: 4.7346 - acc: 0.02 - ETA: 17s - loss: 4.7355 - acc: 0.02 - ETA: 17s - loss: 4.7338 - acc: 0.02 - ETA: 16s - loss: 4.7333 - acc: 0.02 - ETA: 16s - loss: 4.7352 - acc: 0.02 - ETA: 16s - loss: 4.7350 - acc: 0.02 - ETA: 16s - loss: 4.7355 - acc: 0.02 - ETA: 16s - loss: 4.7348 - acc: 0.02 - ETA: 16s - loss: 4.7335 - acc: 0. ...
# 6680/6680 [==============================] - ETA: 8s - loss: 4.7400 - acc: 0.021 - ETA: 8s - loss: 4.7407 - acc: 0.021 - ETA: 8s - loss: 4.7408 - acc: 0.021 - ETA: 8s - loss: 4.7413 - acc: 0.021 - ETA: 8s - loss: 4.7415 - acc: 0.021 - ETA: 8s - loss: 4.7417 - acc: 0.021 - ETA: 8s - loss: 4.7414 - acc: 0.021 - ETA: 8s - loss: 4.7406 - acc: 0.021 - ETA: 8s - loss: 4.7409 - acc: 0.021 - ETA: 8s - loss: 4.7407 - acc: 0.021 - ETA: 8s - loss: 4.7405 - acc: 0.021 - ETA: 8s - loss: 4.7409 - acc: 0.021 - ETA: 8s - loss: 4.7412 - acc: 0.021 - ETA: 8s - loss: 4.7403 - acc: 0.021 - ETA: 7s - loss: 4.7407 - acc: 0.021 - ETA: 7s - loss: 4.7415 - acc: 0.021 - ETA: 7s - loss: 4.7417 - acc: 0.021 - ETA: 7s - loss: 4.7417 - acc: 0.021 - ETA: 7s - loss: 4.7412 - acc: 0.021 - ETA: 7s - loss: 4.7420 - acc: 0.021 - ETA: 7s - loss: 4.7420 - acc: 0.021 - ETA: 7s - loss: 4.7419 - acc: 0.021 - ETA: 7s - loss: 4.7422 - acc: 0.021 - ETA: 7s - loss: 4.7424 - acc: 0.021 - ETA: 7s - loss: 4.7413 - acc: 0.021 - ETA: 7s - loss: 4.7417 - acc: 0.021 - ETA: 7s - loss: 4.7406 - acc: 0.021 - ETA: 6s - loss: 4.7404 - acc: 0.021 - ETA: 6s - loss: 4.7406 - acc: 0.021 - ETA: 6s - loss: 4.7407 - acc: 0.021 - ETA: 6s - loss: 4.7404 - acc: 0.021 - ETA: 6s - loss: 4.7409 - acc: 0.021 - ETA: 6s - loss: 4.7409 - acc: 0.021 - ETA: 6s - loss: 4.7406 - acc: 0.021 - ETA: 6s - loss: 4.7417 - acc: 0.021 - ETA: 6s - loss: 4.7414 - acc: 0.021 - ETA: 6s - loss: 4.7416 - acc: 0.021 - ETA: 6s - loss: 4.7409 - acc: 0.021 - ETA: 6s - loss: 4.7409 - acc: 0.021 - ETA: 6s - loss: 4.7405 - acc: 0.021 - ETA: 5s - loss: 4.7404 - acc: 0.021 - ETA: 5s - loss: 4.7406 - acc: 0.022 - ETA: 5s - loss: 4.7406 - acc: 0.022 - ETA: 5s - loss: 4.7410 - acc: 0.022 - ETA: 5s - loss: 4.7414 - acc: 0.022 - ETA: 5s - loss: 4.7411 - acc: 0.022 - ETA: 5s - loss: 4.7416 - acc: 0.022 - ETA: 5s - loss: 4.7417 - acc: 0.022 - ETA: 5s - loss: 4.7421 - acc: 0.022 - ETA: 5s - loss: 4.7420 - acc: 0.022 - ETA: 5s - loss: 4.7421 - acc: 0.022 - ETA: 5s - loss: 4.7417 - acc: 0.021 - ETA: 5s - loss: 4.7419 - acc: 0.021 - ETA: 4s - loss: 4.7422 - acc: 0.021 - ETA: 4s - loss: 4.7421 - acc: 0.021 - ETA: 4s - loss: 4.7431 - acc: 0.021 - ETA: 4s - loss: 4.7432 - acc: 0.021 - ETA: 4s - loss: 4.7432 - acc: 0.021 - ETA: 4s - loss: 4.7428 - acc: 0.021 - ETA: 4s - loss: 4.7429 - acc: 0.021 - ETA: 4s - loss: 4.7431 - acc: 0.021 - ETA: 4s - loss: 4.7432 - acc: 0.021 - ETA: 4s - loss: 4.7427 - acc: 0.021 - ETA: 4s - loss: 4.7426 - acc: 0.021 - ETA: 4s - loss: 4.7432 - acc: 0.021 - ETA: 4s - loss: 4.7434 - acc: 0.021 - ETA: 3s - loss: 4.7431 - acc: 0.021 - ETA: 3s - loss: 4.7429 - acc: 0.021 - ETA: 3s - loss: 4.7430 - acc: 0.021 - ETA: 3s - loss: 4.7430 - acc: 0.021 - ETA: 3s - loss: 4.7426 - acc: 0.021 - ETA: 3s - loss: 4.7425 - acc: 0.021 - ETA: 3s - loss: 4.7425 - acc: 0.021 - ETA: 3s - loss: 4.7424 - acc: 0.021 - ETA: 3s - loss: 4.7431 - acc: 0.021 - ETA: 3s - loss: 4.7433 - acc: 0.021 - ETA: 3s - loss: 4.7435 - acc: 0.021 - ETA: 3s - loss: 4.7434 - acc: 0.021 - ETA: 3s - loss: 4.7431 - acc: 0.021 - ETA: 2s - loss: 4.7420 - acc: 0.021 - ETA: 2s - loss: 4.7419 - acc: 0.021 - ETA: 2s - loss: 4.7416 - acc: 0.021 - ETA: 2s - loss: 4.7421 - acc: 0.021 - ETA: 2s - loss: 4.7423 - acc: 0.021 - ETA: 2s - loss: 4.7425 - acc: 0.021 - ETA: 2s - loss: 4.7422 - acc: 0.021 - ETA: 2s - loss: 4.7417 - acc: 0.021 - ETA: 2s - loss: 4.7418 - acc: 0.021 - ETA: 2s - loss: 4.7415 - acc: 0.021 - ETA: 2s - loss: 4.7420 - acc: 0.021 - ETA: 2s - loss: 4.7420 - acc: 0.020 - ETA: 2s - loss: 4.7423 - acc: 0.020 - ETA: 1s - loss: 4.7422 - acc: 0.020 - ETA: 1s - loss: 4.7424 - acc: 0.020 - ETA: 1s - loss: 4.7422 - acc: 0.021 - ETA: 1s - loss: 4.7421 - acc: 0.020 - ETA: 1s - loss: 4.7424 - acc: 0.020 - ETA: 1s - loss: 4.7423 - acc: 0.020 - ETA: 1s - loss: 4.7430 - acc: 0.020 - ETA: 1s - loss: 4.7427 - acc: 0.020 - ETA: 1s - loss: 4.7429 - acc: 0.020 - ETA: 1s - loss: 4.7426 - acc: 0.020 - ETA: 1s - loss: 4.7432 - acc: 0.020 - ETA: 1s - loss: 4.7436 - acc: 0.021 - ETA ...
#
# Epoch 00005: val_loss improved from 4.78056 to 4.76435, saving model to saved_models/weights.best.from_scratch.hdf5

# %% [markdown]
# ### Load the Model with the Best Validation Loss

# %%
model.load_weights('saved_models/weights.best.from_scratch.hdf5')

# %% [markdown]
# ### Test the Model
#
# Try out your model on the test dataset of dog images.  Ensure that your test accuracy is greater than 1%.

# %%
# get index of predicted dog breed for each image in test set
dog_breed_predictions = [np.argmax(model.predict(np.expand_dims(tensor, axis=0))) for tensor in test_tensors]

# report test accuracy
test_accuracy = 100*np.sum(np.array(dog_breed_predictions)==np.argmax(test_targets, axis=1))/len(dog_breed_predictions)
print('Test accuracy: %.4f%%' % test_accuracy)
# Out:
# Test accuracy: 3.1100%

# %% [markdown]
# ---
# <a id='step4'></a>
# ## Step 4: Use a CNN to Classify Dog Breeds
#
# To reduce training time without sacrificing accuracy, we show you how to train a CNN using transfer learning.  In the following step, you will get a chance to use transfer learning to train your own CNN.
#
# ### Obtain Bottleneck Features

# %%
bottleneck_features = np.load('bottleneck_features/DogVGG16Data.npz')
train_VGG16 = bottleneck_features['train']
valid_VGG16 = bottleneck_features['valid']
test_VGG16 = bottleneck_features['test']

# %% [markdown]
# ### Model Architecture
#
# The model uses the the pre-trained VGG-16 model as a fixed feature extractor, where the last convolutional output of VGG-16 is fed as input to our model.  We only add a global average pooling layer and a fully connected layer, where the latter contains one node for each dog category and is equipped with a softmax.

# %%
VGG16_model = Sequential()
VGG16_model.add(GlobalAveragePooling2D(input_shape=train_VGG16.shape[1:]))
VGG16_model.add(Dense(133, activation='softmax'))

VGG16_model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# global_average_pooling2d_2 ( (None, 512)               0
# _________________________________________________________________
# dense_2 (Dense)              (None, 133)               68229
# =================================================================
# Total params: 68,229
# Trainable params: 68,229
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Compile the Model

# %%
VGG16_model.compile(loss='categorical_crossentropy', optimizer='rmsprop', metrics=['accuracy'])

# %% [markdown]
# ### Train the Model

# %%
checkpointer = ModelCheckpoint(filepath='saved_models/weights.best.VGG16.hdf5', 
                               verbose=1, save_best_only=True)

VGG16_model.fit(train_VGG16, train_targets, 
          validation_data=(valid_VGG16, valid_targets),
          epochs=20, batch_size=20, callbacks=[checkpointer], verbose=1)
# Out:
# Train on 6680 samples, validate on 835 samples
# Epoch 1/20
# 6680/6680 [==============================] - ETA: 10:22 - loss: 14.9031 - acc: 0.0000e+0 - ETA: 2:06 - loss: 15.1868 - acc: 0.0000e+0 - ETA: 1:11 - loss: 15.1409 - acc: 0.0056   - ETA: 43s - loss: 14.9783 - acc: 0.0100 - ETA: 32s - loss: 14.9158 - acc: 0.012 - ETA: 27s - loss: 14.8239 - acc: 0.010 - ETA: 22s - loss: 14.7639 - acc: 0.011 - ETA: 19s - loss: 14.7534 - acc: 0.010 - ETA: 16s - loss: 14.7093 - acc: 0.012 - ETA: 15s - loss: 14.7066 - acc: 0.011 - ETA: 13s - loss: 14.6513 - acc: 0.011 - ETA: 11s - loss: 14.5778 - acc: 0.013 - ETA: 10s - loss: 14.4206 - acc: 0.015 - ETA: 9s - loss: 14.3543 - acc: 0.018 - ETA: 9s - loss: 14.2850 - acc: 0.02 - ETA: 8s - loss: 14.2034 - acc: 0.02 - ETA: 8s - loss: 14.1058 - acc: 0.03 - ETA: 7s - loss: 14.0602 - acc: 0.03 - ETA: 7s - loss: 13.9491 - acc: 0.03 - ETA: 6s - loss: 13.9061 - acc: 0.03 - ETA: 6s - loss: 13.8770 - acc: 0.03 - ETA: 6s - loss: 13.8580 - acc: 0.04 - ETA: 5s - loss: 13.7582 - acc: 0.04 - ETA: 5s - loss: 13.7200 - acc: 0.04 - ETA: 5s - loss: 13.6715 - acc: 0.04 - ETA: 5s - loss: 13.5981 - acc: 0.05 - ETA: 4s - loss: 13.5726 - acc: 0.05 - ETA: 4s - loss: 13.5181 - acc: 0.05 - ETA: 4s - loss: 13.4179 - acc: 0.05 - ETA: 4s - loss: 13.4033 - acc: 0.05 - ETA: 3s - loss: 13.3277 - acc: 0.06 - ETA: 3s - loss: 13.2734 - acc: 0.06 - ETA: 3s - loss: 13.2142 - acc: 0.06 - ETA: 3s - loss: 13.1919 - acc: 0.06 - ETA: 3s - loss: 13.1373 - acc: 0.07 - ETA: 2s - loss: 13.0782 - acc: 0.07 - ETA: 2s - loss: 13.0578 - acc: 0.07 - ETA: 2s - loss: 13.0164 - acc: 0.07 - ETA: 2s - loss: 12.9777 - acc: 0.08 - ETA: 2s - loss: 12.9513 - acc: 0.08 - ETA: 2s - loss: 12.9204 - acc: 0.08 - ETA: 2s - loss: 12.8792 - acc: 0.08 - ETA: 1s - loss: 12.8403 - acc: 0.08 - ETA: 1s - loss: 12.8139 - acc: 0.09 - ETA: 1s - loss: 12.7776 - acc: 0.09 - ETA: 1s - loss: 12.7493 - acc: 0.09 - ETA: 1s - loss: 12.7321 - acc: 0.09 - ETA: 1s - loss: 12.7170 - acc: 0.09 - ETA: 1s - loss: 12.6997 - acc: 0.09 - ETA: 1s - loss: 12.6729 - acc: 0.09 - ETA: 1s - loss: 12.6450 - acc: 0.10 - ETA: 0s - loss: 12.6222 - acc: 0.10 - ETA: 0s - loss: 12.6071 - acc: 0.10 - ETA: 0s - loss: 12.5761 - acc: 0.10 - ETA: 0s - loss: 12.5810 - acc: 0.10 - ETA: 0s - loss: 12.5472 - acc: 0.10 - ETA: 0s - loss: 12.5193 - acc: 0.10 - ETA: 0s - loss: 12.4879 - acc: 0.11 - ETA: 0s - loss: 12.4400 - acc: 0.11 - ETA: 0s - loss: 12.4199 - acc: 0.11 - ETA: 0s - loss: 12.4140 - acc: 0.11 - ETA: 0s - loss: 12.4165 - acc: 0.11 - ETA: 0s - loss: 12.4029 - acc: 0.11 - ETA: 0s - loss: 12.3937 - acc: 0.11 - ETA: 0s - loss: 12.3792 - acc: 0.11 - 6s 940us/step - loss: 12.3589 - acc: 0.1192 - val_loss: 10.9651 - val_acc: 0.1988
#
# Epoch 00001: val_loss improved from inf to 10.96510, saving model to saved_models/weights.best.VGG16.hdf5
# Epoch 2/20
# 6680/6680 [==============================] - ETA: 4s - loss: 7.2917 - acc: 0.400 - ETA: 3s - loss: 9.3667 - acc: 0.333 - ETA: 3s - loss: 10.4844 - acc: 0.26 - ETA: 2s - loss: 10.5946 - acc: 0.24 - ETA: 2s - loss: 10.7554 - acc: 0.24 - ETA: 3s - loss: 10.7246 - acc: 0.24 - ETA: 3s - loss: 10.7128 - acc: 0.24 - ETA: 3s - loss: 10.8110 - acc: 0.24 - ETA: 4s - loss: 10.7857 - acc: 0.25 - ETA: 4s - loss: 10.9032 - acc: 0.24 - ETA: 4s - loss: 10.8660 - acc: 0.24 - ETA: 4s - loss: 10.8548 - acc: 0.24 - ETA: 4s - loss: 10.8462 - acc: 0.23 - ETA: 5s - loss: 10.7984 - acc: 0.23 - ETA: 5s - loss: 10.7624 - acc: 0.24 - ETA: 5s - loss: 10.7422 - acc: 0.24 - ETA: 5s - loss: 10.7348 - acc: 0.24 - ETA: 5s - loss: 10.7397 - acc: 0.23 - ETA: 5s - loss: 10.6414 - acc: 0.24 - ETA: 5s - loss: 10.6662 - acc: 0.24 - ETA: 5s - loss: 10.6415 - acc: 0.24 - ETA: 5s - loss: 10.6784 - acc: 0.24 - ETA: 5s - loss: 10.5484 - acc: 0.24 - ETA: 4s - loss: 10.4863 - acc: 0.24 - ETA: 4s - loss: 10.4643 - acc: 0.24 - ETA: 4s - loss: 10.3802 - acc: 0.25 - ETA: 3s - loss: 10.3289 - acc: 0.25 - ETA: 3s - loss: 10.2686 - acc: 0.25 - ETA: 3s - loss: 10.2632 - acc: 0.25 - ETA: 3s - loss: 10.3001 - acc: 0.25 - ETA: 3s - loss: 10.3397 - acc: 0.25 - ETA: 2s - loss: 10.3251 - acc: 0.25 - ETA: 2s - loss: 10.2804 - acc: 0.25 - ETA: 2s - loss: 10.2761 - acc: 0.25 - ETA: 2s - loss: 10.2573 - acc: 0.26 - ETA: 2s - loss: 10.2937 - acc: 0.25 - ETA: 2s - loss: 10.2910 - acc: 0.25 - ETA: 2s - loss: 10.2845 - acc: 0.25 - ETA: 2s - loss: 10.2780 - acc: 0.25 - ETA: 3s - loss: 10.2585 - acc: 0.25 - ETA: 3s - loss: 10.2356 - acc: 0.25 - ETA: 3s - loss: 10.2589 - acc: 0.25 - ETA: 3s - loss: 10.2699 - acc: 0.25 - ETA: 3s - loss: 10.2901 - acc: 0.25 - ETA: 3s - loss: 10.2617 - acc: 0.26 - ETA: 3s - loss: 10.2809 - acc: 0.25 - ETA: 3s - loss: 10.2725 - acc: 0.25 - ETA: 3s - loss: 10.2880 - acc: 0.25 - ETA: 3s - loss: 10.2864 - acc: 0.25 - ETA: 2s - loss: 10.2889 - acc: 0.25 - ETA: 2s - loss: 10.3053 - acc: 0.25 - ETA: 2s - loss: 10.2842 - acc: 0.26 - ETA: 2s - loss: 10.2996 - acc: 0.26 - ETA: 2s - loss: 10.2963 - acc: 0.26 - ETA: 2s - loss: 10.3044 - acc: 0.25 - ETA: 2s - loss: 10.2933 - acc: 0.26 - ETA: 2s - loss: 10.2959 - acc: 0.26 - ETA: 2s - loss: 10.3062 - acc: 0.26 - ETA: 2s - loss: 10.2998 - acc: 0.26 - ETA: 2s - loss: 10.3069 - acc: 0.26 - ETA: 2s - loss: 10.3329 - acc: 0.25 - ETA: 2s - loss: 10.3168 - acc: 0.26 - ETA: 2s - loss: 10.3311 - acc: 0.25 - ETA: 2s - loss: 10.3333 - acc: 0.25 - ETA: 2s - loss: 10.3503 - acc: 0.25 - ETA: 2s - loss: 10.3373 - acc: 0.26 - ETA: 2s - loss: 10.3478 - acc: 0.26 - ETA: 2s - loss: 10.3345 - acc: 0.25 - ETA: 2s - loss: 10.3417 - acc: 0.25 - ETA: 1s - loss: 10.3214 - acc: 0.26 - ETA: 1s - loss: 10.3131 - acc: 0.26 - ETA: 1s - loss: 10.3080 - acc: 0.26 - ETA: 1s - loss: 10.3020 - acc: 0.26 - ETA: 1s - loss: 10.2928 - acc: 0.26 - ETA: 1s - loss: 10.2951 - acc: 0.26 - ETA: 1s - loss: 10.2983 - acc: 0.26 - ETA: 1s - loss: 10.3017 - acc: 0.26 - ETA: 1s - loss: 10.3116 - acc: 0.26 - ETA: 1s - loss: 10.3116 - acc: 0.26 - ETA: 1s - loss: 10.3144 - acc: 0.26 - ETA: 1s - loss: 10.3220 - acc: 0.26 - ETA: 1s - loss: 10.3240 - acc: 0.26 - ETA: 1s - loss: 10.3131 - acc: 0.26 - ETA: 1s - loss: 10.2944 - acc: 0.26 - ETA: 1s - loss: 10.3047 - acc: 0.26 - ETA: 1s - loss: 10.3142 - acc: 0.26 - ETA: 1s - loss: 10.3156 - acc: 0.26 - ETA: 1s - loss: 10.3159 - acc: 0.26 - ETA: 1s - loss: 10.3158 - acc: 0.26 - ETA: 1s - loss: 10.3119 - acc: 0.26 - ETA: 1s - loss: 10.3100 - acc: 0.26 - ETA: 1s - loss: 10.2961 - acc: 0.26 - ETA: 1s - loss: 10.3067 - acc: 0.26 - ETA: 1s - loss: 10.3040 - acc: 0.26 - ETA: 1s - loss: 10.3065 - acc: 0.26 - ETA: 1s - loss: 10.2998 - acc: 0.26 - ETA: 1s - loss: 10.2978 - acc: 0.26 - ETA: 1s - loss: 10.2819 - acc: 0.26 - ETA: 0s - loss: 10.2840 - acc: 0.26 - ETA: 0s - loss: 10.2919 - acc: 0.26 - ETA: 0s - loss: 10.2978 - acc: 0.26 - ETA: 0s - loss: 10.2996 - acc: 0.26 - ETA: 0s - loss: 10.2934 - acc: 0.26 - ETA: 0s - loss: 10.2997 - acc: 0.26 - ETA ...
#
# Epoch 00002: val_loss improved from 10.96510 to 10.11110, saving model to saved_models/weights.best.VGG16.hdf5
# Epoch 3/20
# 6680/6680 [==============================] - ETA: 3s - loss: 9.1906 - acc: 0.350 - ETA: 2s - loss: 10.1668 - acc: 0.28 - ETA: 2s - loss: 10.1435 - acc: 0.28 - ETA: 2s - loss: 9.7804 - acc: 0.3130 - ETA: 2s - loss: 9.7772 - acc: 0.314 - ETA: 2s - loss: 9.7447 - acc: 0.316 - ETA: 2s - loss: 9.7362 - acc: 0.317 - ETA: 2s - loss: 9.5960 - acc: 0.327 - ETA: 2s - loss: 9.6726 - acc: 0.324 - ETA: 2s - loss: 9.6289 - acc: 0.327 - ETA: 2s - loss: 9.7045 - acc: 0.322 - ETA: 2s - loss: 9.6776 - acc: 0.324 - ETA: 2s - loss: 9.7470 - acc: 0.322 - ETA: 2s - loss: 9.7778 - acc: 0.320 - ETA: 2s - loss: 9.8083 - acc: 0.318 - ETA: 1s - loss: 9.7360 - acc: 0.326 - ETA: 1s - loss: 9.7459 - acc: 0.325 - ETA: 1s - loss: 9.7509 - acc: 0.324 - ETA: 1s - loss: 9.7897 - acc: 0.324 - ETA: 1s - loss: 9.7730 - acc: 0.323 - ETA: 1s - loss: 9.7534 - acc: 0.321 - ETA: 1s - loss: 9.7069 - acc: 0.324 - ETA: 1s - loss: 9.7146 - acc: 0.325 - ETA: 1s - loss: 9.7020 - acc: 0.326 - ETA: 1s - loss: 9.6874 - acc: 0.328 - ETA: 1s - loss: 9.6858 - acc: 0.329 - ETA: 1s - loss: 9.7010 - acc: 0.328 - ETA: 1s - loss: 9.6961 - acc: 0.329 - ETA: 1s - loss: 9.7120 - acc: 0.328 - ETA: 1s - loss: 9.7241 - acc: 0.328 - ETA: 1s - loss: 9.7214 - acc: 0.329 - ETA: 1s - loss: 9.7047 - acc: 0.331 - ETA: 1s - loss: 9.7091 - acc: 0.330 - ETA: 1s - loss: 9.7579 - acc: 0.327 - ETA: 1s - loss: 9.7428 - acc: 0.327 - ETA: 1s - loss: 9.7284 - acc: 0.327 - ETA: 1s - loss: 9.7203 - acc: 0.328 - ETA: 1s - loss: 9.7033 - acc: 0.328 - ETA: 0s - loss: 9.6936 - acc: 0.328 - ETA: 0s - loss: 9.6660 - acc: 0.328 - ETA: 0s - loss: 9.6599 - acc: 0.329 - ETA: 0s - loss: 9.6380 - acc: 0.330 - ETA: 0s - loss: 9.6381 - acc: 0.330 - ETA: 0s - loss: 9.6361 - acc: 0.331 - ETA: 0s - loss: 9.6529 - acc: 0.330 - ETA: 0s - loss: 9.6541 - acc: 0.330 - ETA: 0s - loss: 9.6346 - acc: 0.332 - ETA: 0s - loss: 9.6236 - acc: 0.332 - ETA: 0s - loss: 9.6104 - acc: 0.333 - ETA: 0s - loss: 9.6199 - acc: 0.332 - ETA: 0s - loss: 9.6241 - acc: 0.332 - ETA: 0s - loss: 9.6250 - acc: 0.332 - ETA: 0s - loss: 9.6088 - acc: 0.332 - ETA: 0s - loss: 9.6054 - acc: 0.332 - ETA: 0s - loss: 9.5840 - acc: 0.334 - ETA: 0s - loss: 9.5731 - acc: 0.334 - ETA: 0s - loss: 9.5540 - acc: 0.336 - ETA: 0s - loss: 9.5555 - acc: 0.336 - ETA: 0s - loss: 9.5546 - acc: 0.336 - 4s 531us/step - loss: 9.5613 - acc: 0.3362 - val_loss: 9.6859 - val_acc: 0.3150
#
# Epoch 00003: val_loss improved from 10.11110 to 9.68593, saving model to saved_models/weights.best.VGG16.hdf5
# Epoch 4/20
# 6680/6680 [==============================] - ETA: 4s - loss: 8.8942 - acc: 0.350 - ETA: 3s - loss: 9.8040 - acc: 0.333 - ETA: 2s - loss: 9.7296 - acc: 0.342 - ETA: 3s - loss: 9.8935 - acc: 0.335 - ETA: 3s - loss: 9.5179 - acc: 0.354 - ETA: 3s - loss: 9.5553 - acc: 0.350 - ETA: 3s - loss: 9.4312 - acc: 0.356 - ETA: 2s - loss: 9.4090 - acc: 0.356 - ETA: 3s - loss: 9.3392 - acc: 0.359 - ETA: 3s - loss: 9.3453 - acc: 0.359 - ETA: 2s - loss: 9.3179 - acc: 0.365 - ETA: 2s - loss: 9.3332 - acc: 0.362 - ETA: 2s - loss: 9.2778 - acc: 0.366 - ETA: 2s - loss: 9.2457 - acc: 0.366 - ETA: 2s - loss: 9.2319 - acc: 0.365 - ETA: 2s - loss: 9.2381 - acc: 0.366 - ETA: 2s - loss: 9.2089 - acc: 0.369 - ETA: 2s - loss: 9.1978 - acc: 0.372 - ETA: 2s - loss: 9.1774 - acc: 0.372 - ETA: 2s - loss: 9.1495 - acc: 0.376 - ETA: 2s - loss: 9.0963 - acc: 0.378 - ETA: 2s - loss: 9.1432 - acc: 0.375 - ETA: 2s - loss: 9.1885 - acc: 0.375 - ETA: 2s - loss: 9.1937 - acc: 0.374 - ETA: 2s - loss: 9.1580 - acc: 0.377 - ETA: 2s - loss: 9.1384 - acc: 0.379 - ETA: 1s - loss: 9.1538 - acc: 0.378 - ETA: 1s - loss: 9.1862 - acc: 0.376 - ETA: 1s - loss: 9.2155 - acc: 0.374 - ETA: 1s - loss: 9.1630 - acc: 0.377 - ETA: 1s - loss: 9.2493 - acc: 0.372 - ETA: 1s - loss: 9.2396 - acc: 0.372 - ETA: 1s - loss: 9.2284 - acc: 0.373 - ETA: 1s - loss: 9.2274 - acc: 0.373 - ETA: 1s - loss: 9.2020 - acc: 0.375 - ETA: 1s - loss: 9.2141 - acc: 0.374 - ETA: 1s - loss: 9.1894 - acc: 0.376 - ETA: 1s - loss: 9.1954 - acc: 0.376 - ETA: 1s - loss: 9.1747 - acc: 0.377 - ETA: 1s - loss: 9.1806 - acc: 0.377 - ETA: 1s - loss: 9.1992 - acc: 0.375 - ETA: 1s - loss: 9.1749 - acc: 0.377 - ETA: 1s - loss: 9.1920 - acc: 0.377 - ETA: 1s - loss: 9.1760 - acc: 0.377 - ETA: 0s - loss: 9.1753 - acc: 0.377 - ETA: 0s - loss: 9.1702 - acc: 0.378 - ETA: 0s - loss: 9.1563 - acc: 0.378 - ETA: 0s - loss: 9.1699 - acc: 0.377 - ETA: 0s - loss: 9.1659 - acc: 0.378 - ETA: 0s - loss: 9.1676 - acc: 0.378 - ETA: 0s - loss: 9.2053 - acc: 0.376 - ETA: 0s - loss: 9.2294 - acc: 0.374 - ETA: 0s - loss: 9.2213 - acc: 0.375 - ETA: 0s - loss: 9.2298 - acc: 0.375 - ETA: 0s - loss: 9.2146 - acc: 0.376 - ETA: 0s - loss: 9.2106 - acc: 0.376 - ETA: 0s - loss: 9.2026 - acc: 0.377 - ETA: 0s - loss: 9.1960 - acc: 0.377 - ETA: 0s - loss: 9.2112 - acc: 0.376 - ETA: 0s - loss: 9.1868 - acc: 0.378 - ETA: 0s - loss: 9.1739 - acc: 0.379 - 4s 529us/step - loss: 9.1736 - acc: 0.3796 - val_loss: 9.4404 - val_acc: 0.3461
#
# Epoch 00004: val_loss improved from 9.68593 to 9.44037, saving model to saved_models/weights.best.VGG16.hdf5
# Epoch 5/20
# 6680/6680 [==============================] - ETA: 4s - loss: 9.9714 - acc: 0.350 - ETA: 3s - loss: 10.0269 - acc: 0.34 - ETA: 3s - loss: 9.4356 - acc: 0.3667 - ETA: 3s - loss: 9.6114 - acc: 0.359 - ETA: 3s - loss: 9.8755 - acc: 0.345 - ETA: 3s - loss: 9.5654 - acc: 0.365 - ETA: 3s - loss: 9.2815 - acc: 0.381 - ETA: 2s - loss: 9.3029 - acc: 0.383 - ETA: 2s - loss: 9.2549 - acc: 0.386 - ETA: 2s - loss: 9.2019 - acc: 0.390 - ETA: 2s - loss: 8.9985 - acc: 0.402 - ETA: 2s - loss: 8.8470 - acc: 0.414 - ETA: 2s - loss: 8.8109 - acc: 0.417 - ETA: 2s - loss: 8.9349 - acc: 0.410 - ETA: 2s - loss: 8.9900 - acc: 0.407 - ETA: 2s - loss: 9.0211 - acc: 0.405 - ETA: 2s - loss: 9.0372 - acc: 0.403 - ETA: 2s - loss: 9.0402 - acc: 0.402 - ETA: 2s - loss: 9.0022 - acc: 0.405 - ETA: 2s - loss: 9.0327 - acc: 0.404 - ETA: 2s - loss: 9.0505 - acc: 0.404 - ETA: 2s - loss: 9.0428 - acc: 0.404 - ETA: 2s - loss: 9.0613 - acc: 0.402 - ETA: 2s - loss: 9.0929 - acc: 0.401 - ETA: 2s - loss: 9.0968 - acc: 0.401 - ETA: 2s - loss: 9.1110 - acc: 0.398 - ETA: 2s - loss: 9.1215 - acc: 0.398 - ETA: 2s - loss: 9.0548 - acc: 0.402 - ETA: 1s - loss: 9.0644 - acc: 0.402 - ETA: 1s - loss: 9.0723 - acc: 0.400 - ETA: 1s - loss: 9.0743 - acc: 0.399 - ETA: 1s - loss: 9.0952 - acc: 0.397 - ETA: 1s - loss: 9.0817 - acc: 0.398 - ETA: 1s - loss: 9.0679 - acc: 0.398 - ETA: 1s - loss: 9.0891 - acc: 0.396 - ETA: 1s - loss: 9.1028 - acc: 0.396 - ETA: 1s - loss: 9.1070 - acc: 0.395 - ETA: 1s - loss: 9.1188 - acc: 0.393 - ETA: 1s - loss: 9.1111 - acc: 0.394 - ETA: 1s - loss: 9.1118 - acc: 0.394 - ETA: 1s - loss: 9.0798 - acc: 0.396 - ETA: 1s - loss: 9.0589 - acc: 0.397 - ETA: 1s - loss: 9.0392 - acc: 0.399 - ETA: 1s - loss: 9.0649 - acc: 0.397 - ETA: 0s - loss: 9.0465 - acc: 0.397 - ETA: 0s - loss: 9.0367 - acc: 0.398 - ETA: 0s - loss: 9.0423 - acc: 0.398 - ETA: 0s - loss: 9.0235 - acc: 0.399 - ETA: 0s - loss: 9.0089 - acc: 0.400 - ETA: 0s - loss: 9.0090 - acc: 0.400 - ETA: 0s - loss: 9.0082 - acc: 0.400 - ETA: 0s - loss: 9.0167 - acc: 0.400 - ETA: 0s - loss: 9.0189 - acc: 0.400 - ETA: 0s - loss: 9.0513 - acc: 0.398 - ETA: 0s - loss: 9.0451 - acc: 0.399 - ETA: 0s - loss: 9.0584 - acc: 0.398 - ETA: 0s - loss: 9.0363 - acc: 0.399 - ETA: 0s - loss: 9.0231 - acc: 0.400 - ETA: 0s - loss: 9.0100 - acc: 0.400 - 4s 531us/step - loss: 9.0243 - acc: 0.4001 - val_loss: 9.3933 - val_acc: 0.3425
#
# Epoch 00005: val_loss improved from 9.44037 to 9.39326, saving model to saved_models/weights.best.VGG16.hdf5
# Epoch 6/20
# 6680/6680 [==============================] - ETA: 2s - loss: 11.8370 - acc: 0.15 - ETA: 4s - loss: 10.0631 - acc: 0.35 - ETA: 5s - loss: 9.7288 - acc: 0.3714 - ETA: 6s - loss: 9.2852 - acc: 0.400 - ETA: 7s - loss: 8.9043 - acc: 0.422 - ETA: 7s - loss: 8.7391 - acc: 0.434 - ETA: 7s - loss: 8.7584 - acc: 0.436 - ETA: 7s - loss: 8.8689 - acc: 0.432 - ETA: 7s - loss: 9.0632 - acc: 0.418 - ETA: 8s - loss: 9.0632 - acc: 0.416 - ETA: 8s - loss: 9.1258 - acc: 0.413 - ETA: 8s - loss: 8.9842 - acc: 0.420 - ETA: 8s - loss: 9.0791 - acc: 0.413 - ETA: 8s - loss: 9.0447 - acc: 0.413 - ETA: 8s - loss: 9.0923 - acc: 0.411 - ETA: 8s - loss: 9.1528 - acc: 0.409 - ETA: 8s - loss: 9.3206 - acc: 0.400 - ETA: 8s - loss: 9.1931 - acc: 0.406 - ETA: 7s - loss: 9.1501 - acc: 0.411 - ETA: 6s - loss: 9.0464 - acc: 0.416 - ETA: 5s - loss: 9.1249 - acc: 0.413 - ETA: 5s - loss: 9.0145 - acc: 0.418 - ETA: 4s - loss: 8.9282 - acc: 0.422 - ETA: 4s - loss: 8.9620 - acc: 0.422 - ETA: 4s - loss: 8.9974 - acc: 0.417 - ETA: 4s - loss: 9.0537 - acc: 0.414 - ETA: 3s - loss: 9.1066 - acc: 0.410 - ETA: 3s - loss: 9.1457 - acc: 0.408 - ETA: 3s - loss: 9.1903 - acc: 0.405 - ETA: 3s - loss: 9.1162 - acc: 0.409 - ETA: 3s - loss: 9.0759 - acc: 0.411 - ETA: 3s - loss: 9.0794 - acc: 0.411 - ETA: 2s - loss: 9.0821 - acc: 0.411 - ETA: 2s - loss: 9.0713 - acc: 0.411 - ETA: 2s - loss: 9.0313 - acc: 0.413 - ETA: 2s - loss: 9.0027 - acc: 0.415 - ETA: 2s - loss: 8.9728 - acc: 0.416 - ETA: 2s - loss: 8.9438 - acc: 0.417 - ETA: 2s - loss: 8.9588 - acc: 0.417 - ETA: 2s - loss: 8.9909 - acc: 0.414 - ETA: 1s - loss: 8.9863 - acc: 0.414 - ETA: 1s - loss: 8.9586 - acc: 0.415 - ETA: 1s - loss: 8.9585 - acc: 0.416 - ETA: 1s - loss: 8.9435 - acc: 0.416 - ETA: 1s - loss: 8.9436 - acc: 0.416 - ETA: 1s - loss: 8.9530 - acc: 0.415 - ETA: 1s - loss: 8.9729 - acc: 0.414 - ETA: 1s - loss: 8.9641 - acc: 0.415 - ETA: 1s - loss: 8.9672 - acc: 0.415 - ETA: 1s - loss: 8.9546 - acc: 0.416 - ETA: 1s - loss: 8.9681 - acc: 0.415 - ETA: 1s - loss: 8.9780 - acc: 0.414 - ETA: 1s - loss: 8.9862 - acc: 0.413 - ETA: 1s - loss: 8.9888 - acc: 0.413 - ETA: 1s - loss: 9.0024 - acc: 0.413 - ETA: 1s - loss: 8.9985 - acc: 0.413 - ETA: 1s - loss: 8.9788 - acc: 0.414 - ETA: 1s - loss: 8.9906 - acc: 0.413 - ETA: 1s - loss: 8.9902 - acc: 0.413 - ETA: 1s - loss: 9.0037 - acc: 0.412 - ETA: 1s - loss: 8.9898 - acc: 0.413 - ETA: 1s - loss: 8.9859 - acc: 0.413 - ETA: 1s - loss: 8.9843 - acc: 0.413 - ETA: 1s - loss: 8.9809 - acc: 0.413 - ETA: 1s - loss: 8.9294 - acc: 0.416 - ETA: 1s - loss: 8.8970 - acc: 0.419 - ETA: 0s - loss: 8.9180 - acc: 0.417 - ETA: 0s - loss: 8.9216 - acc: 0.417 - ETA: 0s - loss: 8.9062 - acc: 0.416 - ETA: 0s - loss: 8.9041 - acc: 0.417 - ETA: 0s - loss: 8.8890 - acc: 0.417 - ETA: 0s - loss: 8.8805 - acc: 0.417 - ETA: 0s - loss: 8.8822 - acc: 0.417 - ETA: 0s - loss: 8.9125 - acc: 0.416 - ETA: 0s - loss: 8.9032 - acc: 0.416 - ETA: 0s - loss: 8.9141 - acc: 0.415 - ETA: 0s - loss: 8.9214 - acc: 0.415 - ETA: 0s - loss: 8.9210 - acc: 0.415 - ETA: 0s - loss: 8.9231 - acc: 0.415 - ETA: 0s - loss: 8.9220 - acc: 0.415 - 5s 709us/step - loss: 8.9220 - acc: 0.4154 - val_loss: 9.2981 - val_acc: 0.3497
#
# Epoch 00006: val_loss improved from 9.39326 to 9.29815, saving model to saved_models/weights.best.VGG16.hdf5
# Epoch 7/20
# 6680/6680 [==============================] - ETA: 5s - loss: 9.7015 - acc: 0.400 - ETA: 4s - loss: 8.3841 - acc: 0.458 - ETA: 3s - loss: 9.3680 - acc: 0.400 - ETA: 3s - loss: 9.1971 - acc: 0.403 - ETA: 3s - loss: 9.0333 - acc: 0.410 - ETA: 3s - loss: 8.8082 - acc: 0.425 - ETA: 3s - loss: 8.7251 - acc: 0.433 - ETA: 3s - loss: 8.6533 - acc: 0.438 - ETA: 2s - loss: 8.7323 - acc: 0.432 - ETA: 2s - loss: 8.6878 - acc: 0.434 - ETA: 2s - loss: 8.7840 - acc: 0.429 - ETA: 2s - loss: 8.6680 - acc: 0.437 - ETA: 2s - loss: 8.5796 - acc: 0.442 - ETA: 2s - loss: 8.5981 - acc: 0.442 - ETA: 2s - loss: 8.6130 - acc: 0.439 - ETA: 2s - loss: 8.5972 - acc: 0.439 - ETA: 2s - loss: 8.5803 - acc: 0.441 - ETA: 2s - loss: 8.6018 - acc: 0.440 - ETA: 2s - loss: 8.5804 - acc: 0.442 - ETA: 2s - loss: 8.6261 - acc: 0.439 - ETA: 2s - loss: 8.7005 - acc: 0.436 - ETA: 2s - loss: 8.7547 - acc: 0.433 - ETA: 2s - loss: 8.7398 - acc: 0.434 - ETA: 2s - loss: 8.7595 - acc: 0.434 - ETA: 2s - loss: 8.7512 - acc: 0.434 - ETA: 2s - loss: 8.7521 - acc: 0.432 - ETA: 2s - loss: 8.7848 - acc: 0.430 - ETA: 1s - loss: 8.8108 - acc: 0.428 - ETA: 1s - loss: 8.7579 - acc: 0.431 - ETA: 1s - loss: 8.7811 - acc: 0.430 - ETA: 1s - loss: 8.7442 - acc: 0.432 - ETA: 1s - loss: 8.7419 - acc: 0.432 - ETA: 1s - loss: 8.7720 - acc: 0.431 - ETA: 1s - loss: 8.7570 - acc: 0.432 - ETA: 1s - loss: 8.7504 - acc: 0.432 - ETA: 1s - loss: 8.7644 - acc: 0.431 - ETA: 1s - loss: 8.7734 - acc: 0.431 - ETA: 1s - loss: 8.7639 - acc: 0.432 - ETA: 1s - loss: 8.7855 - acc: 0.431 - ETA: 1s - loss: 8.7816 - acc: 0.431 - ETA: 1s - loss: 8.7647 - acc: 0.431 - ETA: 1s - loss: 8.7715 - acc: 0.431 - ETA: 1s - loss: 8.7758 - acc: 0.431 - ETA: 1s - loss: 8.7860 - acc: 0.430 - ETA: 1s - loss: 8.7612 - acc: 0.432 - ETA: 1s - loss: 8.7684 - acc: 0.431 - ETA: 0s - loss: 8.8012 - acc: 0.429 - ETA: 0s - loss: 8.7834 - acc: 0.431 - ETA: 0s - loss: 8.7699 - acc: 0.431 - ETA: 0s - loss: 8.8089 - acc: 0.429 - ETA: 0s - loss: 8.8091 - acc: 0.428 - ETA: 0s - loss: 8.7788 - acc: 0.430 - ETA: 0s - loss: 8.7823 - acc: 0.430 - ETA: 0s - loss: 8.7902 - acc: 0.430 - ETA: 0s - loss: 8.8008 - acc: 0.429 - ETA: 0s - loss: 8.7956 - acc: 0.429 - ETA: 0s - loss: 8.7850 - acc: 0.430 - ETA: 0s - loss: 8.8062 - acc: 0.428 - ETA: 0s - loss: 8.7830 - acc: 0.429 - ETA: 0s - loss: 8.7985 - acc: 0.429 - ETA: 0s - loss: 8.8076 - acc: 0.428 - ETA: 0s - loss: 8.7999 - acc: 0.429 - ETA: 0s - loss: 8.7980 - acc: 0.429 - 4s 562us/step - loss: 8.8047 - acc: 0.4292 - val_loss: 9.1596 - val_acc: 0.3701
#
# Epoch 00007: val_loss improved from 9.29815 to 9.15957, saving model to saved_models/weights.best.VGG16.hdf5
# Epoch 8/20
# 6680/6680 [==============================] - ETA: 3s - loss: 8.8668 - acc: 0.450 - ETA: 3s - loss: 8.7515 - acc: 0.441 - ETA: 3s - loss: 8.5368 - acc: 0.459 - ETA: 3s - loss: 8.2380 - acc: 0.481 - ETA: 3s - loss: 8.8013 - acc: 0.443 - ETA: 2s - loss: 9.0057 - acc: 0.426 - ETA: 2s - loss: 9.0210 - acc: 0.423 - ETA: 2s - loss: 9.0193 - acc: 0.423 - ETA: 2s - loss: 8.9888 - acc: 0.427 - ETA: 2s - loss: 8.9036 - acc: 0.431 - ETA: 2s - loss: 8.7790 - acc: 0.439 - ETA: 2s - loss: 8.8155 - acc: 0.437 - ETA: 2s - loss: 8.8802 - acc: 0.433 - ETA: 2s - loss: 8.8945 - acc: 0.431 - ETA: 2s - loss: 8.9115 - acc: 0.430 - ETA: 2s - loss: 8.9425 - acc: 0.428 - ETA: 2s - loss: 8.9570 - acc: 0.428 - ETA: 2s - loss: 8.9105 - acc: 0.432 - ETA: 2s - loss: 8.9557 - acc: 0.427 - ETA: 2s - loss: 8.9683 - acc: 0.427 - ETA: 2s - loss: 8.9956 - acc: 0.425 - ETA: 2s - loss: 8.9362 - acc: 0.428 - ETA: 2s - loss: 8.9711 - acc: 0.426 - ETA: 1s - loss: 8.9361 - acc: 0.428 - ETA: 1s - loss: 8.9135 - acc: 0.429 - ETA: 1s - loss: 8.8895 - acc: 0.431 - ETA: 1s - loss: 8.8651 - acc: 0.432 - ETA: 1s - loss: 8.8160 - acc: 0.435 - ETA: 1s - loss: 8.8027 - acc: 0.436 - ETA: 1s - loss: 8.7863 - acc: 0.438 - ETA: 1s - loss: 8.7676 - acc: 0.439 - ETA: 1s - loss: 8.7496 - acc: 0.440 - ETA: 1s - loss: 8.7305 - acc: 0.442 - ETA: 1s - loss: 8.7127 - acc: 0.442 - ETA: 1s - loss: 8.7453 - acc: 0.440 - ETA: 1s - loss: 8.7137 - acc: 0.442 - ETA: 1s - loss: 8.6906 - acc: 0.442 - ETA: 1s - loss: 8.7127 - acc: 0.441 - ETA: 1s - loss: 8.6793 - acc: 0.443 - ETA: 1s - loss: 8.6687 - acc: 0.443 - ETA: 0s - loss: 8.6870 - acc: 0.442 - ETA: 0s - loss: 8.6707 - acc: 0.442 - ETA: 0s - loss: 8.6823 - acc: 0.442 - ETA: 0s - loss: 8.7038 - acc: 0.440 - ETA: 0s - loss: 8.7023 - acc: 0.441 - ETA: 0s - loss: 8.7042 - acc: 0.440 - ETA: 0s - loss: 8.7198 - acc: 0.440 - ETA: 0s - loss: 8.7321 - acc: 0.439 - ETA: 0s - loss: 8.7290 - acc: 0.439 - ETA: 0s - loss: 8.7163 - acc: 0.440 - ETA: 0s - loss: 8.7224 - acc: 0.440 - ETA: 0s - loss: 8.7088 - acc: 0.440 - ETA: 0s - loss: 8.7176 - acc: 0.440 - ETA: 0s - loss: 8.7265 - acc: 0.439 - ETA: 0s - loss: 8.7332 - acc: 0.439 - ETA: 0s - loss: 8.7318 - acc: 0.439 - ETA: 0s - loss: 8.7377 - acc: 0.438 - ETA: 0s - loss: 8.7466 - acc: 0.437 - ETA: 0s - loss: 8.7362 - acc: 0.437 - ETA: 0s - loss: 8.7539 - acc: 0.436 - 4s 530us/step - loss: 8.7511 - acc: 0.4364 - val_loss: 9.0453 - val_acc: 0.3868
#
# Epoch 00008: val_loss improved from 9.15957 to 9.04533, saving model to saved_models/weights.best.VGG16.hdf5
# Epoch 9/20
# 6680/6680 [==============================] - ETA: 3s - loss: 9.1730 - acc: 0.400 - ETA: 3s - loss: 10.0366 - acc: 0.35 - ETA: 3s - loss: 9.1588 - acc: 0.4091 - ETA: 2s - loss: 9.1082 - acc: 0.421 - ETA: 2s - loss: 8.7137 - acc: 0.444 - ETA: 2s - loss: 8.7395 - acc: 0.445 - ETA: 2s - loss: 8.8818 - acc: 0.436 - ETA: 2s - loss: 8.7773 - acc: 0.444 - ETA: 2s - loss: 8.5868 - acc: 0.455 - ETA: 2s - loss: 8.6257 - acc: 0.453 - ETA: 2s - loss: 8.6570 - acc: 0.452 - ETA: 2s - loss: 8.6227 - acc: 0.454 - ETA: 2s - loss: 8.7989 - acc: 0.443 - ETA: 2s - loss: 8.8079 - acc: 0.442 - ETA: 2s - loss: 8.8017 - acc: 0.444 - ETA: 2s - loss: 8.8589 - acc: 0.440 - ETA: 2s - loss: 8.8916 - acc: 0.438 - ETA: 2s - loss: 8.7976 - acc: 0.443 - ETA: 2s - loss: 8.7774 - acc: 0.444 - ETA: 2s - loss: 8.7145 - acc: 0.447 - ETA: 2s - loss: 8.6928 - acc: 0.448 - ETA: 2s - loss: 8.6818 - acc: 0.448 - ETA: 2s - loss: 8.6275 - acc: 0.452 - ETA: 2s - loss: 8.6632 - acc: 0.450 - ETA: 2s - loss: 8.6411 - acc: 0.451 - ETA: 2s - loss: 8.6378 - acc: 0.451 - ETA: 2s - loss: 8.6329 - acc: 0.452 - ETA: 2s - loss: 8.6314 - acc: 0.452 - ETA: 1s - loss: 8.6181 - acc: 0.453 - ETA: 1s - loss: 8.6198 - acc: 0.453 - ETA: 1s - loss: 8.6007 - acc: 0.454 - ETA: 1s - loss: 8.6142 - acc: 0.453 - ETA: 1s - loss: 8.6289 - acc: 0.452 - ETA: 1s - loss: 8.6160 - acc: 0.452 - ETA: 1s - loss: 8.6026 - acc: 0.453 - ETA: 1s - loss: 8.5672 - acc: 0.455 - ETA: 1s - loss: 8.5760 - acc: 0.455 - ETA: 1s - loss: 8.5819 - acc: 0.455 - ETA: 1s - loss: 8.5979 - acc: 0.454 - ETA: 1s - loss: 8.6107 - acc: 0.452 - ETA: 1s - loss: 8.6159 - acc: 0.452 - ETA: 1s - loss: 8.6445 - acc: 0.450 - ETA: 1s - loss: 8.6518 - acc: 0.450 - ETA: 1s - loss: 8.6454 - acc: 0.450 - ETA: 1s - loss: 8.6613 - acc: 0.450 - ETA: 1s - loss: 8.6537 - acc: 0.450 - ETA: 1s - loss: 8.6842 - acc: 0.447 - ETA: 0s - loss: 8.6859 - acc: 0.448 - ETA: 0s - loss: 8.6678 - acc: 0.449 - ETA: 0s - loss: 8.6681 - acc: 0.449 - ETA: 0s - loss: 8.6911 - acc: 0.447 - ETA: 0s - loss: 8.6820 - acc: 0.448 - ETA: 0s - loss: 8.6597 - acc: 0.449 - ETA: 0s - loss: 8.6718 - acc: 0.448 - ETA: 0s - loss: 8.6588 - acc: 0.449 - ETA: 0s - loss: 8.6504 - acc: 0.449 - ETA: 0s - loss: 8.6438 - acc: 0.449 - ETA: 0s - loss: 8.6597 - acc: 0.449 - ETA: 0s - loss: 8.6576 - acc: 0.449 - ETA: 0s - loss: 8.6681 - acc: 0.448 - ETA: 0s - loss: 8.6648 - acc: 0.448 - ETA: 0s - loss: 8.6663 - acc: 0.448 - ETA: 0s - loss: 8.6807 - acc: 0.447 - ETA: 0s - loss: 8.6648 - acc: 0.448 - ETA: 0s - loss: 8.6518 - acc: 0.449 - ETA: 0s - loss: 8.6509 - acc: 0.449 - ETA: 0s - loss: 8.6528 - acc: 0.449 - ETA: 0s - loss: 8.6554 - acc: 0.448 - ETA: 0s - loss: 8.6567 - acc: 0.448 - ETA: 0s - loss: 8.6610 - acc: 0.448 - ETA: 0s - loss: 8.6465 - acc: 0.449 - ETA: 0s - loss: 8.6432 - acc: 0.449 - 4s 657us/step - loss: 8.6464 - acc: 0.4493 - val_loss: 9.0945 - val_acc: 0.3772
#
# Epoch 00009: val_loss did not improve from 9.04533
# Epoch 10/20
# 6680/6680 [==============================] - ETA: 3s - loss: 11.6798 - acc: 0.25 - ETA: 2s - loss: 8.7858 - acc: 0.4444 - ETA: 2s - loss: 9.2743 - acc: 0.415 - ETA: 2s - loss: 8.9990 - acc: 0.428 - ETA: 2s - loss: 8.7686 - acc: 0.444 - ETA: 2s - loss: 8.6891 - acc: 0.451 - ETA: 2s - loss: 8.7005 - acc: 0.450 - ETA: 3s - loss: 8.7157 - acc: 0.447 - ETA: 3s - loss: 8.7443 - acc: 0.446 - ETA: 3s - loss: 8.6527 - acc: 0.452 - ETA: 3s - loss: 8.7957 - acc: 0.443 - ETA: 4s - loss: 8.7988 - acc: 0.443 - ETA: 4s - loss: 8.7519 - acc: 0.445 - ETA: 4s - loss: 8.7253 - acc: 0.446 - ETA: 4s - loss: 8.8017 - acc: 0.441 - ETA: 4s - loss: 8.8276 - acc: 0.438 - ETA: 4s - loss: 8.9100 - acc: 0.433 - ETA: 4s - loss: 8.8496 - acc: 0.437 - ETA: 4s - loss: 8.8903 - acc: 0.434 - ETA: 5s - loss: 8.8631 - acc: 0.436 - ETA: 5s - loss: 8.8468 - acc: 0.437 - ETA: 5s - loss: 8.7981 - acc: 0.440 - ETA: 5s - loss: 8.8142 - acc: 0.438 - ETA: 4s - loss: 8.8210 - acc: 0.437 - ETA: 4s - loss: 8.8437 - acc: 0.436 - ETA: 3s - loss: 8.7998 - acc: 0.437 - ETA: 3s - loss: 8.7554 - acc: 0.438 - ETA: 3s - loss: 8.7797 - acc: 0.436 - ETA: 3s - loss: 8.7554 - acc: 0.438 - ETA: 2s - loss: 8.7494 - acc: 0.438 - ETA: 2s - loss: 8.7489 - acc: 0.438 - ETA: 2s - loss: 8.7449 - acc: 0.439 - ETA: 2s - loss: 8.7638 - acc: 0.438 - ETA: 2s - loss: 8.7573 - acc: 0.437 - ETA: 2s - loss: 8.7270 - acc: 0.439 - ETA: 2s - loss: 8.7559 - acc: 0.437 - ETA: 2s - loss: 8.7866 - acc: 0.435 - ETA: 1s - loss: 8.7516 - acc: 0.437 - ETA: 1s - loss: 8.7264 - acc: 0.439 - ETA: 1s - loss: 8.7016 - acc: 0.440 - ETA: 1s - loss: 8.6822 - acc: 0.442 - ETA: 1s - loss: 8.6496 - acc: 0.444 - ETA: 1s - loss: 8.6615 - acc: 0.443 - ETA: 1s - loss: 8.6645 - acc: 0.443 - ETA: 1s - loss: 8.6420 - acc: 0.445 - ETA: 1s - loss: 8.6335 - acc: 0.445 - ETA: 1s - loss: 8.6252 - acc: 0.446 - ETA: 1s - loss: 8.6374 - acc: 0.445 - ETA: 1s - loss: 8.6389 - acc: 0.445 - ETA: 1s - loss: 8.6422 - acc: 0.445 - ETA: 1s - loss: 8.6512 - acc: 0.445 - ETA: 1s - loss: 8.6406 - acc: 0.445 - ETA: 1s - loss: 8.6398 - acc: 0.445 - ETA: 1s - loss: 8.6335 - acc: 0.445 - ETA: 1s - loss: 8.6371 - acc: 0.445 - ETA: 1s - loss: 8.6425 - acc: 0.445 - ETA: 1s - loss: 8.6348 - acc: 0.446 - ETA: 1s - loss: 8.6348 - acc: 0.445 - ETA: 1s - loss: 8.6186 - acc: 0.446 - ETA: 1s - loss: 8.6070 - acc: 0.447 - ETA: 1s - loss: 8.6227 - acc: 0.446 - ETA: 1s - loss: 8.6196 - acc: 0.446 - ETA: 1s - loss: 8.6309 - acc: 0.445 - ETA: 0s - loss: 8.5937 - acc: 0.447 - ETA: 0s - loss: 8.5836 - acc: 0.448 - ETA: 0s - loss: 8.5557 - acc: 0.450 - ETA: 0s - loss: 8.5389 - acc: 0.451 - ETA: 0s - loss: 8.5335 - acc: 0.451 - ETA: 0s - loss: 8.5247 - acc: 0.451 - ETA: 0s - loss: 8.5226 - acc: 0.451 - ETA: 0s - loss: 8.5041 - acc: 0.452 - ETA: 0s - loss: 8.5062 - acc: 0.452 - ETA: 0s - loss: 8.5080 - acc: 0.452 - ETA: 0s - loss: 8.4991 - acc: 0.452 - ETA: 0s - loss: 8.5108 - acc: 0.451 - ETA: 0s - loss: 8.4942 - acc: 0.452 - ETA: 0s - loss: 8.4817 - acc: 0.452 - 5s 686us/step - loss: 8.4784 - acc: 0.4525 - val_loss: 8.7457 - val_acc: 0.3928
#
# Epoch 00010: val_loss improved from 9.04533 to 8.74565, saving model to saved_models/weights.best.VGG16.hdf5
# Epoch 11/20
# 6680/6680 [==============================] - ETA: 4s - loss: 6.5981 - acc: 0.550 - ETA: 4s - loss: 7.6443 - acc: 0.500 - ETA: 3s - loss: 7.5954 - acc: 0.509 - ETA: 3s - loss: 7.5551 - acc: 0.515 - ETA: 3s - loss: 7.6943 - acc: 0.504 - ETA: 3s - loss: 7.3628 - acc: 0.527 - ETA: 3s - loss: 7.4907 - acc: 0.520 - ETA: 3s - loss: 7.6701 - acc: 0.509 - ETA: 3s - loss: 7.8085 - acc: 0.498 - ETA: 2s - loss: 7.8925 - acc: 0.491 - ETA: 2s - loss: 7.9180 - acc: 0.489 - ETA: 2s - loss: 7.9647 - acc: 0.487 - ETA: 2s - loss: 7.9778 - acc: 0.487 - ETA: 2s - loss: 7.9854 - acc: 0.486 - ETA: 2s - loss: 8.0504 - acc: 0.482 - ETA: 2s - loss: 7.9919 - acc: 0.484 - ETA: 2s - loss: 7.9579 - acc: 0.485 - ETA: 2s - loss: 7.9787 - acc: 0.485 - ETA: 2s - loss: 7.9846 - acc: 0.485 - ETA: 2s - loss: 8.0245 - acc: 0.483 - ETA: 2s - loss: 8.0328 - acc: 0.483 - ETA: 2s - loss: 8.0496 - acc: 0.482 - ETA: 2s - loss: 8.1116 - acc: 0.477 - ETA: 2s - loss: 8.1237 - acc: 0.476 - ETA: 2s - loss: 8.1161 - acc: 0.477 - ETA: 2s - loss: 8.1208 - acc: 0.477 - ETA: 2s - loss: 8.1377 - acc: 0.476 - ETA: 1s - loss: 8.1414 - acc: 0.476 - ETA: 1s - loss: 8.1675 - acc: 0.475 - ETA: 1s - loss: 8.1122 - acc: 0.477 - ETA: 1s - loss: 8.1231 - acc: 0.477 - ETA: 1s - loss: 8.1236 - acc: 0.476 - ETA: 1s - loss: 8.1318 - acc: 0.475 - ETA: 1s - loss: 8.1312 - acc: 0.474 - ETA: 1s - loss: 8.1122 - acc: 0.476 - ETA: 1s - loss: 8.1637 - acc: 0.472 - ETA: 1s - loss: 8.1579 - acc: 0.472 - ETA: 1s - loss: 8.1798 - acc: 0.470 - ETA: 1s - loss: 8.1888 - acc: 0.470 - ETA: 1s - loss: 8.1974 - acc: 0.469 - ETA: 1s - loss: 8.2155 - acc: 0.468 - ETA: 1s - loss: 8.2263 - acc: 0.466 - ETA: 1s - loss: 8.2077 - acc: 0.467 - ETA: 1s - loss: 8.1952 - acc: 0.468 - ETA: 0s - loss: 8.2306 - acc: 0.466 - ETA: 0s - loss: 8.2338 - acc: 0.466 - ETA: 0s - loss: 8.2200 - acc: 0.467 - ETA: 0s - loss: 8.2291 - acc: 0.466 - ETA: 0s - loss: 8.2201 - acc: 0.467 - ETA: 0s - loss: 8.2300 - acc: 0.466 - ETA: 0s - loss: 8.2485 - acc: 0.466 - ETA: 0s - loss: 8.2396 - acc: 0.466 - ETA: 0s - loss: 8.2116 - acc: 0.468 - ETA: 0s - loss: 8.1975 - acc: 0.469 - ETA: 0s - loss: 8.1711 - acc: 0.471 - ETA: 0s - loss: 8.1744 - acc: 0.470 - ETA: 0s - loss: 8.1926 - acc: 0.469 - ETA: 0s - loss: 8.1811 - acc: 0.469 - ETA: 0s - loss: 8.1671 - acc: 0.470 - ETA: 0s - loss: 8.1733 - acc: 0.470 - ETA: 0s - loss: 8.1880 - acc: 0.469 - ETA: 0s - loss: 8.1720 - acc: 0.470 - 4s 544us/step - loss: 8.1569 - acc: 0.4717 - val_loss: 8.6507 - val_acc: 0.4000
#
# Epoch 00011: val_loss improved from 8.74565 to 8.65070, saving model to saved_models/weights.best.VGG16.hdf5
# Epoch 12/20
# 6680/6680 [==============================] - ETA: 3s - loss: 6.4476 - acc: 0.600 - ETA: 4s - loss: 9.0803 - acc: 0.420 - ETA: 3s - loss: 7.9093 - acc: 0.490 - ETA: 4s - loss: 7.9965 - acc: 0.485 - ETA: 3s - loss: 8.3230 - acc: 0.470 - ETA: 3s - loss: 8.2023 - acc: 0.480 - ETA: 3s - loss: 8.2827 - acc: 0.476 - ETA: 3s - loss: 8.2695 - acc: 0.476 - ETA: 3s - loss: 8.4523 - acc: 0.465 - ETA: 3s - loss: 8.4729 - acc: 0.464 - ETA: 3s - loss: 8.3578 - acc: 0.470 - ETA: 2s - loss: 8.2113 - acc: 0.478 - ETA: 2s - loss: 8.1856 - acc: 0.479 - ETA: 2s - loss: 8.2203 - acc: 0.477 - ETA: 2s - loss: 8.2014 - acc: 0.478 - ETA: 2s - loss: 8.2359 - acc: 0.476 - ETA: 2s - loss: 8.1534 - acc: 0.480 - ETA: 2s - loss: 8.2698 - acc: 0.474 - ETA: 2s - loss: 8.2611 - acc: 0.473 - ETA: 2s - loss: 8.2105 - acc: 0.476 - ETA: 2s - loss: 8.2456 - acc: 0.474 - ETA: 2s - loss: 8.2244 - acc: 0.474 - ETA: 2s - loss: 8.1848 - acc: 0.475 - ETA: 2s - loss: 8.2268 - acc: 0.473 - ETA: 1s - loss: 8.2120 - acc: 0.475 - ETA: 1s - loss: 8.2486 - acc: 0.472 - ETA: 1s - loss: 8.2735 - acc: 0.471 - ETA: 1s - loss: 8.2316 - acc: 0.473 - ETA: 1s - loss: 8.2602 - acc: 0.471 - ETA: 1s - loss: 8.2429 - acc: 0.472 - ETA: 1s - loss: 8.2120 - acc: 0.474 - ETA: 1s - loss: 8.2103 - acc: 0.474 - ETA: 1s - loss: 8.1925 - acc: 0.474 - ETA: 1s - loss: 8.1586 - acc: 0.476 - ETA: 1s - loss: 8.1363 - acc: 0.477 - ETA: 1s - loss: 8.1162 - acc: 0.478 - ETA: 1s - loss: 8.1578 - acc: 0.476 - ETA: 1s - loss: 8.1585 - acc: 0.476 - ETA: 1s - loss: 8.1321 - acc: 0.477 - ETA: 1s - loss: 8.0965 - acc: 0.479 - ETA: 1s - loss: 8.0423 - acc: 0.482 - ETA: 1s - loss: 8.0165 - acc: 0.484 - ETA: 0s - loss: 8.0005 - acc: 0.485 - ETA: 0s - loss: 7.9807 - acc: 0.486 - ETA: 0s - loss: 7.9910 - acc: 0.485 - ETA: 0s - loss: 7.9856 - acc: 0.486 - ETA: 0s - loss: 8.0282 - acc: 0.483 - ETA: 0s - loss: 8.0265 - acc: 0.482 - ETA: 0s - loss: 8.0097 - acc: 0.483 - ETA: 0s - loss: 8.0116 - acc: 0.483 - ETA: 0s - loss: 8.0119 - acc: 0.483 - ETA: 0s - loss: 7.9929 - acc: 0.484 - ETA: 0s - loss: 8.0025 - acc: 0.483 - ETA: 0s - loss: 8.0220 - acc: 0.482 - ETA: 0s - loss: 8.0224 - acc: 0.482 - ETA: 0s - loss: 8.0297 - acc: 0.481 - ETA: 0s - loss: 8.0171 - acc: 0.482 - ETA: 0s - loss: 8.0117 - acc: 0.482 - ETA: 0s - loss: 7.9938 - acc: 0.483 - ETA: 0s - loss: 7.9718 - acc: 0.483 - ETA: 0s - loss: 7.9593 - acc: 0.484 - 4s 539us/step - loss: 7.9661 - acc: 0.4837 - val_loss: 8.4066 - val_acc: 0.3964
# Epoch 00012: val_loss improved from 8.65070 to 8.40660, saving model to saved_models/weights.best.VGG16.hdf5
# Epoch 13/20
# 6680/6680 [==============================] - ETA: 4s - loss: 6.8558 - acc: 0.500 - ETA: 3s - loss: 8.9028 - acc: 0.408 - ETA: 3s - loss: 8.4522 - acc: 0.454 - ETA: 3s - loss: 8.3714 - acc: 0.460 - ETA: 4s - loss: 8.2426 - acc: 0.465 - ETA: 4s - loss: 8.1512 - acc: 0.471 - ETA: 4s - loss: 7.8540 - acc: 0.488 - ETA: 3s - loss: 7.7562 - acc: 0.489 - ETA: 3s - loss: 7.7323 - acc: 0.490 - ETA: 3s - loss: 7.6555 - acc: 0.493 - ETA: 3s - loss: 7.7106 - acc: 0.491 - ETA: 3s - loss: 7.7494 - acc: 0.491 - ETA: 3s - loss: 7.7490 - acc: 0.491 - ETA: 3s - loss: 7.7804 - acc: 0.488 - ETA: 3s - loss: 7.8159 - acc: 0.485 - ETA: 3s - loss: 7.7414 - acc: 0.489 - ETA: 3s - loss: 7.7525 - acc: 0.489 - ETA: 2s - loss: 7.7259 - acc: 0.491 - ETA: 2s - loss: 7.7347 - acc: 0.490 - ETA: 2s - loss: 7.6942 - acc: 0.493 - ETA: 2s - loss: 7.6425 - acc: 0.497 - ETA: 2s - loss: 7.6767 - acc: 0.495 - ETA: 2s - loss: 7.7269 - acc: 0.493 - ETA: 2s - loss: 7.7069 - acc: 0.495 - ETA: 2s - loss: 7.7158 - acc: 0.495 - ETA: 2s - loss: 7.7046 - acc: 0.496 - ETA: 2s - loss: 7.7726 - acc: 0.492 - ETA: 2s - loss: 7.8063 - acc: 0.491 - ETA: 2s - loss: 7.7614 - acc: 0.493 - ETA: 2s - loss: 7.7532 - acc: 0.493 - ETA: 2s - loss: 7.7455 - acc: 0.494 - ETA: 2s - loss: 7.7017 - acc: 0.497 - ETA: 2s - loss: 7.6881 - acc: 0.498 - ETA: 1s - loss: 7.6852 - acc: 0.498 - ETA: 1s - loss: 7.6516 - acc: 0.499 - ETA: 1s - loss: 7.6308 - acc: 0.500 - ETA: 1s - loss: 7.6532 - acc: 0.498 - ETA: 1s - loss: 7.6759 - acc: 0.497 - ETA: 1s - loss: 7.6683 - acc: 0.497 - ETA: 1s - loss: 7.6857 - acc: 0.496 - ETA: 1s - loss: 7.6562 - acc: 0.498 - ETA: 1s - loss: 7.6760 - acc: 0.497 - ETA: 1s - loss: 7.6248 - acc: 0.500 - ETA: 1s - loss: 7.6282 - acc: 0.500 - ETA: 1s - loss: 7.6208 - acc: 0.501 - ETA: 1s - loss: 7.6175 - acc: 0.502 - ETA: 1s - loss: 7.6185 - acc: 0.502 - ETA: 1s - loss: 7.6225 - acc: 0.501 - ETA: 1s - loss: 7.6167 - acc: 0.501 - ETA: 0s - loss: 7.6274 - acc: 0.500 - ETA: 0s - loss: 7.6200 - acc: 0.501 - ETA: 0s - loss: 7.6285 - acc: 0.500 - ETA: 0s - loss: 7.6301 - acc: 0.499 - ETA: 0s - loss: 7.6182 - acc: 0.500 - ETA: 0s - loss: 7.6362 - acc: 0.499 - ETA: 0s - loss: 7.6368 - acc: 0.499 - ETA: 0s - loss: 7.6714 - acc: 0.497 - ETA: 0s - loss: 7.6440 - acc: 0.499 - ETA: 0s - loss: 7.6133 - acc: 0.501 - ETA: 0s - loss: 7.6251 - acc: 0.500 - ETA: 0s - loss: 7.6246 - acc: 0.500 - ETA: 0s - loss: 7.6074 - acc: 0.501 - 4s 553us/step - loss: 7.6103 - acc: 0.5010 - val_loss: 8.2076 - val_acc: 0.4204
#
# Epoch 00013: val_loss improved from 8.40660 to 8.20756, saving model to saved_models/weights.best.VGG16.hdf5
# Epoch 14/20
# 6680/6680 [==============================] - ETA: 2s - loss: 5.7727 - acc: 0.600 - ETA: 3s - loss: 6.8817 - acc: 0.564 - ETA: 2s - loss: 7.8898 - acc: 0.500 - ETA: 3s - loss: 7.9781 - acc: 0.494 - ETA: 3s - loss: 7.7046 - acc: 0.512 - ETA: 4s - loss: 7.8108 - acc: 0.506 - ETA: 4s - loss: 7.7312 - acc: 0.512 - ETA: 4s - loss: 7.8184 - acc: 0.507 - ETA: 5s - loss: 7.9624 - acc: 0.496 - ETA: 5s - loss: 7.8443 - acc: 0.503 - ETA: 5s - loss: 7.8715 - acc: 0.501 - ETA: 5s - loss: 7.8832 - acc: 0.501 - ETA: 5s - loss: 7.8998 - acc: 0.500 - ETA: 6s - loss: 7.8891 - acc: 0.500 - ETA: 6s - loss: 7.8175 - acc: 0.503 - ETA: 6s - loss: 7.7440 - acc: 0.508 - ETA: 6s - loss: 7.7643 - acc: 0.504 - ETA: 6s - loss: 7.7433 - acc: 0.505 - ETA: 6s - loss: 7.7061 - acc: 0.508 - ETA: 6s - loss: 7.6734 - acc: 0.510 - ETA: 5s - loss: 7.7050 - acc: 0.507 - ETA: 5s - loss: 7.5782 - acc: 0.515 - ETA: 4s - loss: 7.4929 - acc: 0.518 - ETA: 4s - loss: 7.4571 - acc: 0.520 - ETA: 4s - loss: 7.5712 - acc: 0.514 - ETA: 4s - loss: 7.5843 - acc: 0.513 - ETA: 4s - loss: 7.5504 - acc: 0.515 - ETA: 4s - loss: 7.5537 - acc: 0.514 - ETA: 4s - loss: 7.5233 - acc: 0.516 - ETA: 4s - loss: 7.5127 - acc: 0.517 - ETA: 4s - loss: 7.5025 - acc: 0.517 - ETA: 4s - loss: 7.4901 - acc: 0.517 - ETA: 4s - loss: 7.4784 - acc: 0.517 - ETA: 4s - loss: 7.4818 - acc: 0.517 - ETA: 4s - loss: 7.5005 - acc: 0.516 - ETA: 4s - loss: 7.5150 - acc: 0.514 - ETA: 4s - loss: 7.4901 - acc: 0.515 - ETA: 4s - loss: 7.4848 - acc: 0.515 - ETA: 4s - loss: 7.4774 - acc: 0.515 - ETA: 4s - loss: 7.4823 - acc: 0.515 - ETA: 4s - loss: 7.5060 - acc: 0.513 - ETA: 4s - loss: 7.5486 - acc: 0.511 - ETA: 3s - loss: 7.4613 - acc: 0.514 - ETA: 3s - loss: 7.4818 - acc: 0.513 - ETA: 3s - loss: 7.5010 - acc: 0.512 - ETA: 3s - loss: 7.4531 - acc: 0.514 - ETA: 3s - loss: 7.4953 - acc: 0.511 - ETA: 3s - loss: 7.4384 - acc: 0.514 - ETA: 2s - loss: 7.4342 - acc: 0.514 - ETA: 2s - loss: 7.4543 - acc: 0.513 - ETA: 2s - loss: 7.4803 - acc: 0.511 - ETA: 2s - loss: 7.4490 - acc: 0.513 - ETA: 2s - loss: 7.4920 - acc: 0.510 - ETA: 2s - loss: 7.4948 - acc: 0.510 - ETA: 2s - loss: 7.5056 - acc: 0.509 - ETA: 1s - loss: 7.5212 - acc: 0.508 - ETA: 1s - loss: 7.5289 - acc: 0.507 - ETA: 1s - loss: 7.5185 - acc: 0.508 - ETA: 1s - loss: 7.5386 - acc: 0.507 - ETA: 1s - loss: 7.5321 - acc: 0.507 - ETA: 1s - loss: 7.5291 - acc: 0.507 - ETA: 1s - loss: 7.5223 - acc: 0.507 - ETA: 1s - loss: 7.5161 - acc: 0.508 - ETA: 1s - loss: 7.5030 - acc: 0.509 - ETA: 1s - loss: 7.5195 - acc: 0.508 - ETA: 1s - loss: 7.4913 - acc: 0.508 - ETA: 0s - loss: 7.4623 - acc: 0.510 - ETA: 0s - loss: 7.4568 - acc: 0.511 - ETA: 0s - loss: 7.4566 - acc: 0.511 - ETA: 0s - loss: 7.4341 - acc: 0.512 - ETA: 0s - loss: 7.4283 - acc: 0.513 - ETA: 0s - loss: 7.4219 - acc: 0.513 - ETA: 0s - loss: 7.4092 - acc: 0.514 - ETA: 0s - loss: 7.4005 - acc: 0.515 - ETA: 0s - loss: 7.3974 - acc: 0.515 - ETA: 0s - loss: 7.3852 - acc: 0.516 - ETA: 0s - loss: 7.3840 - acc: 0.516 - ETA: 0s - loss: 7.3788 - acc: 0.516 - ETA: 0s - loss: 7.3532 - acc: 0.518 - 5s 746us/step - loss: 7.3579 - acc: 0.5184 - val_loss: 7.8658 - val_acc: 0.4467
#
# Epoch 00014: val_loss improved from 8.20756 to 7.86576, saving model to saved_models/weights.best.VGG16.hdf5
# Epoch 15/20
# 6680/6680 [==============================] - ETA: 7s - loss: 5.6705 - acc: 0.650 - ETA: 7s - loss: 7.3200 - acc: 0.512 - ETA: 7s - loss: 6.7606 - acc: 0.558 - ETA: 7s - loss: 7.3886 - acc: 0.525 - ETA: 8s - loss: 7.5524 - acc: 0.505 - ETA: 8s - loss: 7.5412 - acc: 0.504 - ETA: 8s - loss: 7.5002 - acc: 0.510 - ETA: 8s - loss: 7.1791 - acc: 0.531 - ETA: 6s - loss: 7.2055 - acc: 0.531 - ETA: 5s - loss: 7.1373 - acc: 0.535 - ETA: 5s - loss: 7.2354 - acc: 0.529 - ETA: 5s - loss: 7.1649 - acc: 0.533 - ETA: 4s - loss: 7.1928 - acc: 0.532 - ETA: 4s - loss: 7.1497 - acc: 0.535 - ETA: 4s - loss: 7.2655 - acc: 0.527 - ETA: 4s - loss: 7.2416 - acc: 0.530 - ETA: 3s - loss: 7.1529 - acc: 0.535 - ETA: 3s - loss: 7.1674 - acc: 0.533 - ETA: 3s - loss: 7.2206 - acc: 0.531 - ETA: 3s - loss: 7.2004 - acc: 0.531 - ETA: 3s - loss: 7.2091 - acc: 0.529 - ETA: 3s - loss: 7.2486 - acc: 0.527 - ETA: 2s - loss: 7.1739 - acc: 0.530 - ETA: 2s - loss: 7.2120 - acc: 0.529 - ETA: 2s - loss: 7.1695 - acc: 0.532 - ETA: 2s - loss: 7.2232 - acc: 0.529 - ETA: 2s - loss: 7.2459 - acc: 0.529 - ETA: 2s - loss: 7.2657 - acc: 0.529 - ETA: 2s - loss: 7.2783 - acc: 0.529 - ETA: 2s - loss: 7.2614 - acc: 0.529 - ETA: 2s - loss: 7.2221 - acc: 0.531 - ETA: 2s - loss: 7.2384 - acc: 0.529 - ETA: 1s - loss: 7.2797 - acc: 0.528 - ETA: 1s - loss: 7.2382 - acc: 0.529 - ETA: 1s - loss: 7.2740 - acc: 0.526 - ETA: 1s - loss: 7.2761 - acc: 0.526 - ETA: 1s - loss: 7.2716 - acc: 0.527 - ETA: 1s - loss: 7.3199 - acc: 0.524 - ETA: 1s - loss: 7.3183 - acc: 0.525 - ETA: 1s - loss: 7.3370 - acc: 0.524 - ETA: 1s - loss: 7.3163 - acc: 0.525 - ETA: 1s - loss: 7.2996 - acc: 0.526 - ETA: 1s - loss: 7.3228 - acc: 0.525 - ETA: 1s - loss: 7.3015 - acc: 0.526 - ETA: 1s - loss: 7.2879 - acc: 0.526 - ETA: 1s - loss: 7.2882 - acc: 0.526 - ETA: 1s - loss: 7.2766 - acc: 0.527 - ETA: 0s - loss: 7.2893 - acc: 0.526 - ETA: 0s - loss: 7.2827 - acc: 0.527 - ETA: 0s - loss: 7.2624 - acc: 0.528 - ETA: 0s - loss: 7.2631 - acc: 0.528 - ETA: 0s - loss: 7.2586 - acc: 0.528 - ETA: 0s - loss: 7.2832 - acc: 0.527 - ETA: 0s - loss: 7.2691 - acc: 0.528 - ETA: 0s - loss: 7.2604 - acc: 0.529 - ETA: 0s - loss: 7.2501 - acc: 0.530 - ETA: 0s - loss: 7.2088 - acc: 0.531 - ETA: 0s - loss: 7.1899 - acc: 0.532 - ETA: 0s - loss: 7.1886 - acc: 0.532 - ETA: 0s - loss: 7.2006 - acc: 0.531 - ETA: 0s - loss: 7.1886 - acc: 0.532 - ETA: 0s - loss: 7.1916 - acc: 0.532 - ETA: 0s - loss: 7.1802 - acc: 0.532 - ETA: 0s - loss: 7.1788 - acc: 0.532 - 4s 568us/step - loss: 7.2014 - acc: 0.5307 - val_loss: 7.8349 - val_acc: 0.4479
#
# Epoch 00015: val_loss improved from 7.86576 to 7.83492, saving model to saved_models/weights.best.VGG16.hdf5
# Epoch 16/20
# 6680/6680 [==============================] - ETA: 4s - loss: 8.9354 - acc: 0.400 - ETA: 4s - loss: 7.6108 - acc: 0.508 - ETA: 4s - loss: 7.3689 - acc: 0.520 - ETA: 4s - loss: 7.3842 - acc: 0.521 - ETA: 3s - loss: 6.7684 - acc: 0.556 - ETA: 3s - loss: 6.7346 - acc: 0.559 - ETA: 3s - loss: 6.7248 - acc: 0.563 - ETA: 3s - loss: 6.6567 - acc: 0.568 - ETA: 3s - loss: 6.7154 - acc: 0.562 - ETA: 3s - loss: 6.6672 - acc: 0.564 - ETA: 3s - loss: 6.7205 - acc: 0.561 - ETA: 3s - loss: 6.7273 - acc: 0.561 - ETA: 3s - loss: 6.7241 - acc: 0.561 - ETA: 3s - loss: 6.6746 - acc: 0.563 - ETA: 2s - loss: 6.7464 - acc: 0.557 - ETA: 2s - loss: 6.7322 - acc: 0.559 - ETA: 2s - loss: 6.8023 - acc: 0.554 - ETA: 2s - loss: 6.9240 - acc: 0.547 - ETA: 2s - loss: 6.9390 - acc: 0.547 - ETA: 2s - loss: 6.9619 - acc: 0.546 - ETA: 2s - loss: 7.0255 - acc: 0.542 - ETA: 2s - loss: 7.0270 - acc: 0.542 - ETA: 2s - loss: 7.0700 - acc: 0.540 - ETA: 2s - loss: 7.0534 - acc: 0.540 - ETA: 2s - loss: 7.0825 - acc: 0.538 - ETA: 2s - loss: 7.1288 - acc: 0.535 - ETA: 2s - loss: 7.1162 - acc: 0.536 - ETA: 2s - loss: 7.1171 - acc: 0.535 - ETA: 1s - loss: 7.1342 - acc: 0.534 - ETA: 1s - loss: 7.1192 - acc: 0.534 - ETA: 1s - loss: 7.1299 - acc: 0.533 - ETA: 1s - loss: 7.1280 - acc: 0.533 - ETA: 1s - loss: 7.1235 - acc: 0.533 - ETA: 1s - loss: 7.1124 - acc: 0.534 - ETA: 1s - loss: 7.0932 - acc: 0.536 - ETA: 1s - loss: 7.0592 - acc: 0.539 - ETA: 1s - loss: 7.1023 - acc: 0.536 - ETA: 1s - loss: 7.0427 - acc: 0.539 - ETA: 1s - loss: 7.0439 - acc: 0.539 - ETA: 1s - loss: 7.0640 - acc: 0.538 - ETA: 1s - loss: 7.0671 - acc: 0.538 - ETA: 1s - loss: 7.0670 - acc: 0.537 - ETA: 1s - loss: 7.0713 - acc: 0.537 - ETA: 1s - loss: 7.0704 - acc: 0.537 - ETA: 1s - loss: 7.0678 - acc: 0.537 - ETA: 0s - loss: 7.0657 - acc: 0.537 - ETA: 0s - loss: 7.0723 - acc: 0.537 - ETA: 0s - loss: 7.0783 - acc: 0.536 - ETA: 0s - loss: 7.0623 - acc: 0.537 - ETA: 0s - loss: 7.0421 - acc: 0.539 - ETA: 0s - loss: 7.0437 - acc: 0.539 - ETA: 0s - loss: 7.0226 - acc: 0.540 - ETA: 0s - loss: 7.0202 - acc: 0.541 - ETA: 0s - loss: 7.0076 - acc: 0.542 - ETA: 0s - loss: 7.0094 - acc: 0.541 - ETA: 0s - loss: 7.0292 - acc: 0.540 - ETA: 0s - loss: 7.0400 - acc: 0.540 - ETA: 0s - loss: 7.0333 - acc: 0.540 - ETA: 0s - loss: 7.0459 - acc: 0.540 - ETA: 0s - loss: 7.0479 - acc: 0.540 - ETA: 0s - loss: 7.0554 - acc: 0.539 - ETA: 0s - loss: 7.0537 - acc: 0.539 - ETA: 0s - loss: 7.0399 - acc: 0.540 - ETA: 0s - loss: 7.0295 - acc: 0.540 - 4s 565us/step - loss: 7.0276 - acc: 0.5409 - val_loss: 7.6821 - val_acc: 0.4491
#
# Epoch 00016: val_loss improved from 7.83492 to 7.68211, saving model to saved_models/weights.best.VGG16.hdf5
# Epoch 17/20
# 6680/6680 [==============================] - ETA: 4s - loss: 4.0728 - acc: 0.700 - ETA: 2s - loss: 6.4025 - acc: 0.587 - ETA: 2s - loss: 6.6107 - acc: 0.580 - ETA: 2s - loss: 6.6333 - acc: 0.572 - ETA: 2s - loss: 6.7458 - acc: 0.569 - ETA: 2s - loss: 6.8251 - acc: 0.562 - ETA: 2s - loss: 6.8983 - acc: 0.557 - ETA: 2s - loss: 6.7956 - acc: 0.564 - ETA: 2s - loss: 6.7427 - acc: 0.566 - ETA: 2s - loss: 6.7330 - acc: 0.568 - ETA: 2s - loss: 6.8859 - acc: 0.558 - ETA: 2s - loss: 6.8765 - acc: 0.560 - ETA: 2s - loss: 6.8138 - acc: 0.563 - ETA: 2s - loss: 6.8374 - acc: 0.561 - ETA: 2s - loss: 6.8772 - acc: 0.558 - ETA: 2s - loss: 6.8452 - acc: 0.559 - ETA: 2s - loss: 6.8200 - acc: 0.561 - ETA: 2s - loss: 6.8037 - acc: 0.562 - ETA: 2s - loss: 6.7735 - acc: 0.564 - ETA: 2s - loss: 6.8311 - acc: 0.560 - ETA: 2s - loss: 6.7758 - acc: 0.564 - ETA: 2s - loss: 6.7726 - acc: 0.563 - ETA: 2s - loss: 6.8551 - acc: 0.558 - ETA: 2s - loss: 6.8271 - acc: 0.559 - ETA: 1s - loss: 6.8618 - acc: 0.558 - ETA: 1s - loss: 6.9226 - acc: 0.554 - ETA: 1s - loss: 6.9135 - acc: 0.555 - ETA: 1s - loss: 6.9195 - acc: 0.555 - ETA: 1s - loss: 6.9183 - acc: 0.554 - ETA: 1s - loss: 6.8785 - acc: 0.557 - ETA: 1s - loss: 6.8542 - acc: 0.558 - ETA: 1s - loss: 6.8740 - acc: 0.557 - ETA: 1s - loss: 6.8907 - acc: 0.556 - ETA: 1s - loss: 6.8648 - acc: 0.557 - ETA: 1s - loss: 6.8704 - acc: 0.557 - ETA: 1s - loss: 6.8978 - acc: 0.555 - ETA: 1s - loss: 6.8908 - acc: 0.556 - ETA: 1s - loss: 6.8825 - acc: 0.556 - ETA: 1s - loss: 6.8598 - acc: 0.558 - ETA: 1s - loss: 6.8608 - acc: 0.558 - ETA: 1s - loss: 6.8777 - acc: 0.557 - ETA: 1s - loss: 6.8690 - acc: 0.557 - ETA: 1s - loss: 6.9238 - acc: 0.554 - ETA: 0s - loss: 6.9139 - acc: 0.554 - ETA: 0s - loss: 6.9176 - acc: 0.554 - ETA: 0s - loss: 6.9324 - acc: 0.553 - ETA: 0s - loss: 6.9563 - acc: 0.551 - ETA: 0s - loss: 6.9479 - acc: 0.552 - ETA: 0s - loss: 6.9484 - acc: 0.552 - ETA: 0s - loss: 6.9132 - acc: 0.554 - ETA: 0s - loss: 6.9059 - acc: 0.554 - ETA: 0s - loss: 6.9290 - acc: 0.553 - ETA: 0s - loss: 6.9434 - acc: 0.552 - ETA: 0s - loss: 6.9385 - acc: 0.552 - ETA: 0s - loss: 6.9351 - acc: 0.553 - ETA: 0s - loss: 6.9153 - acc: 0.554 - ETA: 0s - loss: 6.9243 - acc: 0.553 - 3s 499us/step - loss: 6.9228 - acc: 0.5531 - val_loss: 7.5753 - val_acc: 0.4575
#
# Epoch 00017: val_loss improved from 7.68211 to 7.57533, saving model to saved_models/weights.best.VGG16.hdf5
# Epoch 18/20
# 6680/6680 [==============================] - ETA: 3s - loss: 9.0361 - acc: 0.400 - ETA: 3s - loss: 7.4196 - acc: 0.521 - ETA: 2s - loss: 6.7259 - acc: 0.557 - ETA: 2s - loss: 6.8612 - acc: 0.554 - ETA: 2s - loss: 6.6340 - acc: 0.573 - ETA: 2s - loss: 6.6044 - acc: 0.576 - ETA: 2s - loss: 6.5860 - acc: 0.578 - ETA: 2s - loss: 6.6117 - acc: 0.577 - ETA: 2s - loss: 6.6978 - acc: 0.571 - ETA: 2s - loss: 6.7207 - acc: 0.570 - ETA: 2s - loss: 6.8165 - acc: 0.563 - ETA: 2s - loss: 6.8397 - acc: 0.562 - ETA: 2s - loss: 6.7678 - acc: 0.567 - ETA: 2s - loss: 6.8065 - acc: 0.564 - ETA: 2s - loss: 6.7896 - acc: 0.564 - ETA: 1s - loss: 6.7857 - acc: 0.566 - ETA: 1s - loss: 6.7885 - acc: 0.565 - ETA: 1s - loss: 6.7432 - acc: 0.567 - ETA: 1s - loss: 6.7859 - acc: 0.564 - ETA: 1s - loss: 6.7715 - acc: 0.564 - ETA: 1s - loss: 6.7930 - acc: 0.563 - ETA: 1s - loss: 6.7832 - acc: 0.563 - ETA: 2s - loss: 6.7739 - acc: 0.563 - ETA: 2s - loss: 6.7762 - acc: 0.563 - ETA: 2s - loss: 6.7867 - acc: 0.562 - ETA: 2s - loss: 6.7877 - acc: 0.563 - ETA: 2s - loss: 6.7570 - acc: 0.564 - ETA: 2s - loss: 6.7535 - acc: 0.564 - ETA: 2s - loss: 6.7913 - acc: 0.562 - ETA: 2s - loss: 6.8205 - acc: 0.560 - ETA: 2s - loss: 6.8211 - acc: 0.560 - ETA: 2s - loss: 6.8498 - acc: 0.558 - ETA: 2s - loss: 6.8505 - acc: 0.558 - ETA: 2s - loss: 6.8481 - acc: 0.558 - ETA: 2s - loss: 6.8572 - acc: 0.557 - ETA: 2s - loss: 6.8316 - acc: 0.559 - ETA: 2s - loss: 6.8268 - acc: 0.560 - ETA: 2s - loss: 6.8284 - acc: 0.559 - ETA: 1s - loss: 6.8109 - acc: 0.560 - ETA: 1s - loss: 6.8569 - acc: 0.557 - ETA: 1s - loss: 6.8312 - acc: 0.559 - ETA: 1s - loss: 6.8130 - acc: 0.560 - ETA: 1s - loss: 6.8008 - acc: 0.561 - ETA: 1s - loss: 6.7787 - acc: 0.562 - ETA: 1s - loss: 6.7792 - acc: 0.562 - ETA: 1s - loss: 6.7763 - acc: 0.562 - ETA: 1s - loss: 6.7801 - acc: 0.562 - ETA: 1s - loss: 6.8176 - acc: 0.560 - ETA: 1s - loss: 6.8318 - acc: 0.559 - ETA: 1s - loss: 6.8461 - acc: 0.558 - ETA: 1s - loss: 6.8614 - acc: 0.557 - ETA: 1s - loss: 6.8638 - acc: 0.557 - ETA: 1s - loss: 6.8647 - acc: 0.557 - ETA: 0s - loss: 6.8672 - acc: 0.556 - ETA: 0s - loss: 6.8599 - acc: 0.556 - ETA: 0s - loss: 6.8611 - acc: 0.556 - ETA: 0s - loss: 6.8799 - acc: 0.555 - ETA: 0s - loss: 6.8813 - acc: 0.555 - ETA: 0s - loss: 6.8767 - acc: 0.556 - ETA: 0s - loss: 6.8850 - acc: 0.555 - ETA: 0s - loss: 6.8822 - acc: 0.556 - ETA: 0s - loss: 6.8855 - acc: 0.555 - ETA: 0s - loss: 6.8740 - acc: 0.556 - ETA: 0s - loss: 6.8712 - acc: 0.556 - ETA: 0s - loss: 6.8523 - acc: 0.557 - ETA: 0s - loss: 6.8526 - acc: 0.557 - ETA: 0s - loss: 6.8571 - acc: 0.557 - ETA: 0s - loss: 6.8498 - acc: 0.557 - ETA: 0s - loss: 6.8593 - acc: 0.556 - 4s 628us/step - loss: 6.8380 - acc: 0.5582 - val_loss: 7.6880 - val_acc: 0.4419
#
# Epoch 00018: val_loss did not improve from 7.57533
# Epoch 19/20
# 6680/6680 [==============================] - ETA: 3s - loss: 6.8122 - acc: 0.500 - ETA: 2s - loss: 6.0618 - acc: 0.600 - ETA: 2s - loss: 6.3305 - acc: 0.585 - ETA: 2s - loss: 6.4352 - acc: 0.583 - ETA: 2s - loss: 6.3530 - acc: 0.590 - ETA: 2s - loss: 6.4139 - acc: 0.583 - ETA: 2s - loss: 6.5751 - acc: 0.574 - ETA: 2s - loss: 6.5765 - acc: 0.573 - ETA: 2s - loss: 6.4255 - acc: 0.580 - ETA: 2s - loss: 6.4151 - acc: 0.581 - ETA: 2s - loss: 6.4731 - acc: 0.579 - ETA: 2s - loss: 6.5297 - acc: 0.575 - ETA: 2s - loss: 6.5887 - acc: 0.571 - ETA: 2s - loss: 6.6382 - acc: 0.568 - ETA: 2s - loss: 6.6403 - acc: 0.568 - ETA: 2s - loss: 6.6789 - acc: 0.566 - ETA: 2s - loss: 6.6510 - acc: 0.567 - ETA: 2s - loss: 6.6475 - acc: 0.568 - ETA: 2s - loss: 6.6503 - acc: 0.568 - ETA: 2s - loss: 6.6834 - acc: 0.565 - ETA: 2s - loss: 6.6592 - acc: 0.567 - ETA: 2s - loss: 6.7125 - acc: 0.564 - ETA: 2s - loss: 6.7106 - acc: 0.564 - ETA: 2s - loss: 6.7170 - acc: 0.564 - ETA: 1s - loss: 6.7433 - acc: 0.563 - ETA: 1s - loss: 6.7406 - acc: 0.564 - ETA: 1s - loss: 6.7141 - acc: 0.565 - ETA: 1s - loss: 6.7150 - acc: 0.565 - ETA: 1s - loss: 6.7604 - acc: 0.563 - ETA: 1s - loss: 6.7590 - acc: 0.563 - ETA: 1s - loss: 6.7646 - acc: 0.563 - ETA: 1s - loss: 6.7572 - acc: 0.563 - ETA: 1s - loss: 6.7500 - acc: 0.563 - ETA: 1s - loss: 6.7422 - acc: 0.564 - ETA: 1s - loss: 6.7711 - acc: 0.562 - ETA: 1s - loss: 6.7546 - acc: 0.563 - ETA: 1s - loss: 6.7445 - acc: 0.564 - ETA: 1s - loss: 6.7528 - acc: 0.564 - ETA: 1s - loss: 6.7384 - acc: 0.564 - ETA: 1s - loss: 6.7333 - acc: 0.564 - ETA: 1s - loss: 6.7403 - acc: 0.563 - ETA: 1s - loss: 6.7227 - acc: 0.565 - ETA: 1s - loss: 6.7676 - acc: 0.562 - ETA: 1s - loss: 6.7389 - acc: 0.564 - ETA: 0s - loss: 6.7395 - acc: 0.563 - ETA: 0s - loss: 6.7265 - acc: 0.564 - ETA: 0s - loss: 6.6851 - acc: 0.566 - ETA: 0s - loss: 6.6910 - acc: 0.566 - ETA: 0s - loss: 6.6676 - acc: 0.567 - ETA: 0s - loss: 6.6447 - acc: 0.568 - ETA: 0s - loss: 6.6578 - acc: 0.568 - ETA: 0s - loss: 6.6763 - acc: 0.566 - ETA: 0s - loss: 6.6900 - acc: 0.565 - ETA: 0s - loss: 6.7176 - acc: 0.564 - ETA: 0s - loss: 6.7624 - acc: 0.560 - ETA: 0s - loss: 6.7564 - acc: 0.561 - ETA: 0s - loss: 6.7562 - acc: 0.561 - ETA: 0s - loss: 6.7610 - acc: 0.561 - ETA: 0s - loss: 6.7484 - acc: 0.562 - ETA: 0s - loss: 6.7418 - acc: 0.562 - ETA: 0s - loss: 6.7353 - acc: 0.562 - 4s 539us/step - loss: 6.7392 - acc: 0.5627 - val_loss: 7.5136 - val_acc: 0.4599
#
# Epoch 00019: val_loss improved from 7.57533 to 7.51361, saving model to saved_models/weights.best.VGG16.hdf5
# Epoch 20/20
# 6680/6680 [==============================] - ETA: 3s - loss: 7.2707 - acc: 0.550 - ETA: 3s - loss: 5.5942 - acc: 0.642 - ETA: 3s - loss: 5.7425 - acc: 0.631 - ETA: 3s - loss: 6.1020 - acc: 0.607 - ETA: 2s - loss: 6.0728 - acc: 0.601 - ETA: 2s - loss: 6.3138 - acc: 0.589 - ETA: 2s - loss: 6.2383 - acc: 0.596 - ETA: 2s - loss: 6.2029 - acc: 0.598 - ETA: 2s - loss: 6.3755 - acc: 0.588 - ETA: 2s - loss: 6.2866 - acc: 0.595 - ETA: 2s - loss: 6.3092 - acc: 0.594 - ETA: 3s - loss: 6.3406 - acc: 0.593 - ETA: 3s - loss: 6.3904 - acc: 0.589 - ETA: 3s - loss: 6.3806 - acc: 0.589 - ETA: 3s - loss: 6.4032 - acc: 0.588 - ETA: 3s - loss: 6.3817 - acc: 0.589 - ETA: 3s - loss: 6.3793 - acc: 0.590 - ETA: 3s - loss: 6.4049 - acc: 0.587 - ETA: 3s - loss: 6.3761 - acc: 0.589 - ETA: 3s - loss: 6.3786 - acc: 0.588 - ETA: 3s - loss: 6.4010 - acc: 0.587 - ETA: 3s - loss: 6.3840 - acc: 0.588 - ETA: 3s - loss: 6.4058 - acc: 0.586 - ETA: 4s - loss: 6.4644 - acc: 0.583 - ETA: 4s - loss: 6.4788 - acc: 0.582 - ETA: 4s - loss: 6.5626 - acc: 0.576 - ETA: 4s - loss: 6.5414 - acc: 0.578 - ETA: 3s - loss: 6.5604 - acc: 0.578 - ETA: 3s - loss: 6.6143 - acc: 0.575 - ETA: 3s - loss: 6.6208 - acc: 0.574 - ETA: 3s - loss: 6.6161 - acc: 0.575 - ETA: 3s - loss: 6.5983 - acc: 0.576 - ETA: 3s - loss: 6.5918 - acc: 0.577 - ETA: 3s - loss: 6.6249 - acc: 0.575 - ETA: 3s - loss: 6.6148 - acc: 0.576 - ETA: 3s - loss: 6.6267 - acc: 0.575 - ETA: 3s - loss: 6.6170 - acc: 0.576 - ETA: 3s - loss: 6.5841 - acc: 0.578 - ETA: 3s - loss: 6.5625 - acc: 0.579 - ETA: 3s - loss: 6.5865 - acc: 0.578 - ETA: 3s - loss: 6.5843 - acc: 0.578 - ETA: 3s - loss: 6.5823 - acc: 0.579 - ETA: 3s - loss: 6.5758 - acc: 0.579 - ETA: 3s - loss: 6.5678 - acc: 0.579 - ETA: 3s - loss: 6.5542 - acc: 0.580 - ETA: 3s - loss: 6.5377 - acc: 0.581 - ETA: 3s - loss: 6.5298 - acc: 0.581 - ETA: 3s - loss: 6.5190 - acc: 0.582 - ETA: 3s - loss: 6.5162 - acc: 0.581 - ETA: 2s - loss: 6.4973 - acc: 0.582 - ETA: 2s - loss: 6.4797 - acc: 0.583 - ETA: 2s - loss: 6.4932 - acc: 0.582 - ETA: 2s - loss: 6.4906 - acc: 0.583 - ETA: 2s - loss: 6.5139 - acc: 0.581 - ETA: 2s - loss: 6.5860 - acc: 0.577 - ETA: 2s - loss: 6.5860 - acc: 0.577 - ETA: 2s - loss: 6.5955 - acc: 0.576 - ETA: 2s - loss: 6.5842 - acc: 0.577 - ETA: 1s - loss: 6.5870 - acc: 0.576 - ETA: 1s - loss: 6.5959 - acc: 0.576 - ETA: 1s - loss: 6.5948 - acc: 0.575 - ETA: 1s - loss: 6.6085 - acc: 0.575 - ETA: 1s - loss: 6.6087 - acc: 0.575 - ETA: 1s - loss: 6.6109 - acc: 0.574 - ETA: 1s - loss: 6.5935 - acc: 0.575 - ETA: 1s - loss: 6.6082 - acc: 0.574 - ETA: 1s - loss: 6.6172 - acc: 0.574 - ETA: 1s - loss: 6.5955 - acc: 0.575 - ETA: 1s - loss: 6.5927 - acc: 0.575 - ETA: 0s - loss: 6.6033 - acc: 0.575 - ETA: 0s - loss: 6.6300 - acc: 0.573 - ETA: 0s - loss: 6.6113 - acc: 0.574 - ETA: 0s - loss: 6.6021 - acc: 0.575 - ETA: 0s - loss: 6.6029 - acc: 0.575 - ETA: 0s - loss: 6.6193 - acc: 0.574 - ETA: 0s - loss: 6.6219 - acc: 0.574 - ETA: 0s - loss: 6.6476 - acc: 0.572 - ETA: 0s - loss: 6.6478 - acc: 0.572 - ETA: 0s - loss: 6.6554 - acc: 0.572 - ETA: 0s - loss: 6.6518 - acc: 0.571 - ETA: 0s - loss: 6.6486 - acc: 0.571 - 5s 733us/step - loss: 6.6498 - acc: 0.5717 - val_loss: 7.4482 - val_acc: 0.4743
#
# Epoch 00020: val_loss improved from 7.51361 to 7.44819, saving model to saved_models/weights.best.VGG16.hdf5

# %% [markdown]
# ### Load the Model with the Best Validation Loss

# %%
VGG16_model.load_weights('saved_models/weights.best.VGG16.hdf5')

# %% [markdown]
# ### Test the Model
#
# Now, we can use the CNN to test how well it identifies breed within our test dataset of dog images.  We print the test accuracy below.

# %%
# get index of predicted dog breed for each image in test set
VGG16_predictions = [np.argmax(VGG16_model.predict(np.expand_dims(feature, axis=0))) for feature in test_VGG16]

# report test accuracy
test_accuracy = 100*np.sum(np.array(VGG16_predictions)==np.argmax(test_targets, axis=1))/len(VGG16_predictions)
print('Test accuracy: %.4f%%' % test_accuracy)
# Out:
# Test accuracy: 45.0957%

# %% [markdown]
# ### Predict Dog Breed with the Model

# %%
from extract_bottleneck_features import *

def VGG16_predict_breed(img_path):
    # extract bottleneck features
    bottleneck_feature = extract_VGG16(path_to_tensor(img_path))
    # obtain predicted vector
    predicted_vector = VGG16_model.predict(bottleneck_feature)
    # return dog breed that is predicted by the model
    return dog_names[np.argmax(predicted_vector)]

# %% [markdown]
# ---
# <a id='step5'></a>
# ## Step 5: Create a CNN to Classify Dog Breeds (using Transfer Learning)
#
# You will now use transfer learning to create a CNN that can identify dog breed from images.  Your CNN must attain at least 60% accuracy on the test set.
#
# In Step 4, we used transfer learning to create a CNN using VGG-16 bottleneck features.  In this section, you must use the bottleneck features from a different pre-trained model.  To make things easier for you, we have pre-computed the features for all of the networks that are currently available in Keras:
# - [VGG-19](https://s3-us-west-1.amazonaws.com/udacity-aind/dog-project/DogVGG19Data.npz) bottleneck features
# - [ResNet-50](https://s3-us-west-1.amazonaws.com/udacity-aind/dog-project/DogResnet50Data.npz) bottleneck features
# - [Inception](https://s3-us-west-1.amazonaws.com/udacity-aind/dog-project/DogInceptionV3Data.npz) bottleneck features
# - [Xception](https://s3-us-west-1.amazonaws.com/udacity-aind/dog-project/DogXceptionData.npz) bottleneck features
#
# The files are encoded as such:
#
#     Dog{network}Data.npz
#
# where `{network}`, in the above filename, can be one of `VGG19`, `Resnet50`, `InceptionV3`, or `Xception`.  Pick one of the above architectures, download the corresponding bottleneck features, and store the downloaded file in the `bottleneck_features/` folder in the repository.
#
# ### (IMPLEMENTATION) Obtain Bottleneck Features
#
# In the code block below, extract the bottleneck features corresponding to the train, test, and validation sets by running the following:
#
#     bottleneck_features = np.load('bottleneck_features/Dog{network}Data.npz')
#     train_{network} = bottleneck_features['train']
#     valid_{network} = bottleneck_features['valid']
#     test_{network} = bottleneck_features['test']

# %%
### TODO: Obtain bottleneck features from another pre-trained CNN.
bottleneck_features = np.load('bottleneck_features/DogResnet50Data.npz')
train_Resnet50 = bottleneck_features['train']
valid_Resnet50 = bottleneck_features['valid']
test_Resnet50 = bottleneck_features['test']

# %% [markdown]
# ### (IMPLEMENTATION) Model Architecture
#
# Create a CNN to classify dog breed.  At the end of your code cell block, summarize the layers of your model by executing the line:
#
#         <your model's name>.summary()
#
# __Question 5:__ Outline the steps you took to get to your final CNN architecture and your reasoning at each step.  Describe why you think the architecture is suitable for the current problem.
#
# __Answer:__

# %%
### TODO: Define your architecture.
Resnet50_model = Sequential()
Resnet50_model.add(GlobalAveragePooling2D(input_shape=train_Resnet50.shape[1:]))
Resnet50_model.add(Dense(133, activation='softmax'))

Resnet50_model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# global_average_pooling2d_3 ( (None, 2048)              0
# _________________________________________________________________
# dense_3 (Dense)              (None, 133)               272517
# =================================================================
# Total params: 272,517
# Trainable params: 272,517
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### (IMPLEMENTATION) Compile the Model

# %%
### TODO: Compile the model.
Resnet50_model.compile(loss='categorical_crossentropy', optimizer='rmsprop', metrics=['accuracy'])

# %% [markdown]
# ### (IMPLEMENTATION) Train the Model
#
# Train your model in the code cell below.  Use model checkpointing to save the model that attains the best validation loss.
#
# You are welcome to [augment the training data](https://blog.keras.io/building-powerful-image-classification-models-using-very-little-data.html), but this is not a requirement.

# %%
### TODO: Train the model.
checkpointer = ModelCheckpoint(filepath='saved_models/weights.best.Resnet50.hdf5', 
                               verbose=1, save_best_only=True)

Resnet50_model.fit(train_Resnet50, train_targets, 
          validation_data=(valid_Resnet50, valid_targets),
          epochs=20, batch_size=20, callbacks=[checkpointer], verbose=1)
# Out:
# Train on 6680 samples, validate on 835 samples
# Epoch 1/20
# 6680/6680 [==============================] - ETA: 7:28 - loss: 5.1778 - acc: 0.0000e+0 - ETA: 37s - loss: 5.7815 - acc: 0.0375    - ETA: 21s - loss: 5.2125 - acc: 0.09 - ETA: 15s - loss: 4.8324 - acc: 0.12 - ETA: 11s - loss: 4.3675 - acc: 0.17 - ETA: 9s - loss: 4.1285 - acc: 0.1968 - ETA: 8s - loss: 3.9276 - acc: 0.226 - ETA: 7s - loss: 3.6662 - acc: 0.264 - ETA: 6s - loss: 3.4949 - acc: 0.293 - ETA: 6s - loss: 3.3632 - acc: 0.317 - ETA: 5s - loss: 3.2457 - acc: 0.333 - ETA: 5s - loss: 3.1397 - acc: 0.349 - ETA: 4s - loss: 2.9598 - acc: 0.376 - ETA: 4s - loss: 2.8126 - acc: 0.397 - ETA: 3s - loss: 2.7290 - acc: 0.412 - ETA: 3s - loss: 2.6521 - acc: 0.422 - ETA: 3s - loss: 2.5370 - acc: 0.445 - ETA: 2s - loss: 2.4343 - acc: 0.461 - ETA: 2s - loss: 2.3525 - acc: 0.472 - ETA: 2s - loss: 2.2691 - acc: 0.486 - ETA: 2s - loss: 2.2268 - acc: 0.494 - ETA: 1s - loss: 2.1726 - acc: 0.503 - ETA: 1s - loss: 2.1260 - acc: 0.512 - ETA: 1s - loss: 2.0711 - acc: 0.523 - ETA: 1s - loss: 2.0337 - acc: 0.530 - ETA: 1s - loss: 1.9830 - acc: 0.539 - ETA: 1s - loss: 1.9575 - acc: 0.543 - ETA: 1s - loss: 1.9167 - acc: 0.550 - ETA: 1s - loss: 1.8886 - acc: 0.555 - ETA: 0s - loss: 1.8631 - acc: 0.560 - ETA: 0s - loss: 1.8359 - acc: 0.563 - ETA: 0s - loss: 1.8092 - acc: 0.567 - ETA: 0s - loss: 1.7858 - acc: 0.571 - ETA: 0s - loss: 1.7562 - acc: 0.576 - ETA: 0s - loss: 1.7249 - acc: 0.581 - ETA: 0s - loss: 1.6940 - acc: 0.587 - ETA: 0s - loss: 1.6623 - acc: 0.593 - ETA: 0s - loss: 1.6286 - acc: 0.600 - 4s 555us/step - loss: 1.6215 - acc: 0.6013 - val_loss: 0.8621 - val_acc: 0.7305
#
# Epoch 00001: val_loss improved from inf to 0.86211, saving model to saved_models/weights.best.Resnet50.hdf5
# Epoch 2/20
# 6680/6680 [==============================] - ETA: 2s - loss: 0.7578 - acc: 0.800 - ETA: 1s - loss: 0.3884 - acc: 0.881 - ETA: 1s - loss: 0.3909 - acc: 0.888 - ETA: 1s - loss: 0.4091 - acc: 0.879 - ETA: 1s - loss: 0.4278 - acc: 0.878 - ETA: 1s - loss: 0.4442 - acc: 0.867 - ETA: 1s - loss: 0.4445 - acc: 0.865 - ETA: 1s - loss: 0.4389 - acc: 0.870 - ETA: 1s - loss: 0.4377 - acc: 0.871 - ETA: 1s - loss: 0.4385 - acc: 0.872 - ETA: 1s - loss: 0.4428 - acc: 0.868 - ETA: 1s - loss: 0.4536 - acc: 0.863 - ETA: 1s - loss: 0.4523 - acc: 0.863 - ETA: 1s - loss: 0.4375 - acc: 0.868 - ETA: 1s - loss: 0.4404 - acc: 0.867 - ETA: 1s - loss: 0.4400 - acc: 0.867 - ETA: 1s - loss: 0.4402 - acc: 0.867 - ETA: 1s - loss: 0.4339 - acc: 0.867 - ETA: 1s - loss: 0.4471 - acc: 0.862 - ETA: 1s - loss: 0.4438 - acc: 0.863 - ETA: 1s - loss: 0.4486 - acc: 0.862 - ETA: 1s - loss: 0.4430 - acc: 0.865 - ETA: 0s - loss: 0.4441 - acc: 0.865 - ETA: 0s - loss: 0.4443 - acc: 0.865 - ETA: 0s - loss: 0.4443 - acc: 0.865 - ETA: 0s - loss: 0.4445 - acc: 0.865 - ETA: 0s - loss: 0.4466 - acc: 0.864 - ETA: 0s - loss: 0.4485 - acc: 0.862 - ETA: 0s - loss: 0.4450 - acc: 0.864 - ETA: 0s - loss: 0.4451 - acc: 0.863 - ETA: 0s - loss: 0.4443 - acc: 0.863 - ETA: 0s - loss: 0.4421 - acc: 0.864 - ETA: 0s - loss: 0.4385 - acc: 0.865 - ETA: 0s - loss: 0.4389 - acc: 0.865 - ETA: 0s - loss: 0.4417 - acc: 0.864 - ETA: 0s - loss: 0.4409 - acc: 0.864 - ETA: 0s - loss: 0.4400 - acc: 0.865 - ETA: 0s - loss: 0.4371 - acc: 0.865 - ETA: 0s - loss: 0.4350 - acc: 0.865 - ETA: 0s - loss: 0.4356 - acc: 0.865 - ETA: 0s - loss: 0.4371 - acc: 0.864 - ETA: 0s - loss: 0.4356 - acc: 0.865 - ETA: 0s - loss: 0.4356 - acc: 0.864 - ETA: 0s - loss: 0.4340 - acc: 0.864 - 3s 382us/step - loss: 0.4335 - acc: 0.8647 - val_loss: 0.7692 - val_acc: 0.7701
#
# Epoch 00002: val_loss improved from 0.86211 to 0.76917, saving model to saved_models/weights.best.Resnet50.hdf5
# Epoch 3/20
# 6680/6680 [==============================] - ETA: 7s - loss: 0.2305 - acc: 0.850 - ETA: 6s - loss: 0.1747 - acc: 0.950 - ETA: 6s - loss: 0.2214 - acc: 0.935 - ETA: 6s - loss: 0.2218 - acc: 0.933 - ETA: 6s - loss: 0.2126 - acc: 0.937 - ETA: 6s - loss: 0.2451 - acc: 0.933 - ETA: 6s - loss: 0.2270 - acc: 0.938 - ETA: 6s - loss: 0.2224 - acc: 0.938 - ETA: 6s - loss: 0.2342 - acc: 0.933 - ETA: 6s - loss: 0.2364 - acc: 0.937 - ETA: 6s - loss: 0.2262 - acc: 0.938 - ETA: 6s - loss: 0.2315 - acc: 0.936 - ETA: 5s - loss: 0.2229 - acc: 0.937 - ETA: 4s - loss: 0.2269 - acc: 0.933 - ETA: 4s - loss: 0.2246 - acc: 0.931 - ETA: 3s - loss: 0.2251 - acc: 0.934 - ETA: 3s - loss: 0.2316 - acc: 0.932 - ETA: 3s - loss: 0.2359 - acc: 0.930 - ETA: 2s - loss: 0.2309 - acc: 0.932 - ETA: 2s - loss: 0.2294 - acc: 0.933 - ETA: 2s - loss: 0.2307 - acc: 0.930 - ETA: 2s - loss: 0.2321 - acc: 0.930 - ETA: 2s - loss: 0.2319 - acc: 0.929 - ETA: 2s - loss: 0.2358 - acc: 0.928 - ETA: 2s - loss: 0.2293 - acc: 0.931 - ETA: 1s - loss: 0.2337 - acc: 0.928 - ETA: 1s - loss: 0.2345 - acc: 0.928 - ETA: 1s - loss: 0.2368 - acc: 0.927 - ETA: 1s - loss: 0.2345 - acc: 0.928 - ETA: 1s - loss: 0.2342 - acc: 0.929 - ETA: 1s - loss: 0.2360 - acc: 0.928 - ETA: 1s - loss: 0.2448 - acc: 0.925 - ETA: 1s - loss: 0.2481 - acc: 0.924 - ETA: 1s - loss: 0.2477 - acc: 0.924 - ETA: 0s - loss: 0.2485 - acc: 0.924 - ETA: 0s - loss: 0.2546 - acc: 0.923 - ETA: 0s - loss: 0.2590 - acc: 0.921 - ETA: 0s - loss: 0.2592 - acc: 0.921 - ETA: 0s - loss: 0.2592 - acc: 0.921 - ETA: 0s - loss: 0.2587 - acc: 0.921 - ETA: 0s - loss: 0.2606 - acc: 0.920 - ETA: 0s - loss: 0.2608 - acc: 0.920 - ETA: 0s - loss: 0.2608 - acc: 0.919 - ETA: 0s - loss: 0.2591 - acc: 0.920 - ETA: 0s - loss: 0.2606 - acc: 0.919 - ETA: 0s - loss: 0.2599 - acc: 0.919 - ETA: 0s - loss: 0.2608 - acc: 0.919 - 3s 394us/step - loss: 0.2637 - acc: 0.9183 - val_loss: 0.6752 - val_acc: 0.7868
#
# Epoch 00003: val_loss improved from 0.76917 to 0.67519, saving model to saved_models/weights.best.Resnet50.hdf5
# Epoch 4/20
# 6680/6680 [==============================] - ETA: 3s - loss: 0.2230 - acc: 0.900 - ETA: 2s - loss: 0.1218 - acc: 0.961 - ETA: 1s - loss: 0.1483 - acc: 0.950 - ETA: 1s - loss: 0.1353 - acc: 0.953 - ETA: 1s - loss: 0.1263 - acc: 0.958 - ETA: 1s - loss: 0.1291 - acc: 0.954 - ETA: 1s - loss: 0.1351 - acc: 0.952 - ETA: 1s - loss: 0.1310 - acc: 0.955 - ETA: 1s - loss: 0.1386 - acc: 0.952 - ETA: 1s - loss: 0.1418 - acc: 0.951 - ETA: 1s - loss: 0.1409 - acc: 0.951 - ETA: 1s - loss: 0.1416 - acc: 0.953 - ETA: 1s - loss: 0.1458 - acc: 0.952 - ETA: 1s - loss: 0.1475 - acc: 0.950 - ETA: 1s - loss: 0.1503 - acc: 0.950 - ETA: 1s - loss: 0.1569 - acc: 0.947 - ETA: 1s - loss: 0.1665 - acc: 0.944 - ETA: 1s - loss: 0.1660 - acc: 0.943 - ETA: 1s - loss: 0.1684 - acc: 0.942 - ETA: 1s - loss: 0.1699 - acc: 0.942 - ETA: 1s - loss: 0.1710 - acc: 0.943 - ETA: 0s - loss: 0.1728 - acc: 0.943 - ETA: 0s - loss: 0.1730 - acc: 0.943 - ETA: 0s - loss: 0.1697 - acc: 0.944 - ETA: 0s - loss: 0.1687 - acc: 0.944 - ETA: 0s - loss: 0.1697 - acc: 0.944 - ETA: 0s - loss: 0.1697 - acc: 0.944 - ETA: 0s - loss: 0.1698 - acc: 0.945 - ETA: 0s - loss: 0.1714 - acc: 0.944 - ETA: 0s - loss: 0.1710 - acc: 0.945 - ETA: 0s - loss: 0.1733 - acc: 0.944 - ETA: 0s - loss: 0.1752 - acc: 0.943 - ETA: 0s - loss: 0.1745 - acc: 0.943 - ETA: 0s - loss: 0.1741 - acc: 0.943 - ETA: 0s - loss: 0.1747 - acc: 0.944 - ETA: 0s - loss: 0.1741 - acc: 0.944 - ETA: 0s - loss: 0.1734 - acc: 0.944 - ETA: 0s - loss: 0.1793 - acc: 0.943 - 2s 324us/step - loss: 0.1792 - acc: 0.9436 - val_loss: 0.6255 - val_acc: 0.8060
#
# Epoch 00004: val_loss improved from 0.67519 to 0.62551, saving model to saved_models/weights.best.Resnet50.hdf5
# Epoch 5/20
# 6680/6680 [==============================] - ETA: 1s - loss: 0.0475 - acc: 1.000 - ETA: 1s - loss: 0.1001 - acc: 0.970 - ETA: 1s - loss: 0.1089 - acc: 0.963 - ETA: 2s - loss: 0.1113 - acc: 0.962 - ETA: 1s - loss: 0.1094 - acc: 0.963 - ETA: 1s - loss: 0.1047 - acc: 0.964 - ETA: 1s - loss: 0.1054 - acc: 0.965 - ETA: 1s - loss: 0.1011 - acc: 0.966 - ETA: 1s - loss: 0.0956 - acc: 0.968 - ETA: 1s - loss: 0.0977 - acc: 0.968 - ETA: 1s - loss: 0.0965 - acc: 0.967 - ETA: 1s - loss: 0.1016 - acc: 0.966 - ETA: 1s - loss: 0.1046 - acc: 0.966 - ETA: 1s - loss: 0.1057 - acc: 0.965 - ETA: 1s - loss: 0.1046 - acc: 0.965 - ETA: 1s - loss: 0.1077 - acc: 0.964 - ETA: 1s - loss: 0.1108 - acc: 0.964 - ETA: 1s - loss: 0.1082 - acc: 0.965 - ETA: 1s - loss: 0.1072 - acc: 0.965 - ETA: 1s - loss: 0.1071 - acc: 0.965 - ETA: 0s - loss: 0.1070 - acc: 0.965 - ETA: 0s - loss: 0.1078 - acc: 0.965 - ETA: 0s - loss: 0.1086 - acc: 0.965 - ETA: 0s - loss: 0.1111 - acc: 0.963 - ETA: 0s - loss: 0.1116 - acc: 0.963 - ETA: 0s - loss: 0.1110 - acc: 0.963 - ETA: 0s - loss: 0.1102 - acc: 0.964 - ETA: 0s - loss: 0.1094 - acc: 0.964 - ETA: 0s - loss: 0.1090 - acc: 0.964 - ETA: 0s - loss: 0.1084 - acc: 0.964 - ETA: 0s - loss: 0.1103 - acc: 0.964 - ETA: 0s - loss: 0.1100 - acc: 0.964 - ETA: 0s - loss: 0.1096 - acc: 0.964 - ETA: 0s - loss: 0.1101 - acc: 0.964 - ETA: 0s - loss: 0.1107 - acc: 0.964 - ETA: 0s - loss: 0.1109 - acc: 0.963 - ETA: 0s - loss: 0.1110 - acc: 0.964 - ETA: 0s - loss: 0.1122 - acc: 0.963 - ETA: 0s - loss: 0.1123 - acc: 0.963 - ETA: 0s - loss: 0.1140 - acc: 0.963 - ETA: 0s - loss: 0.1146 - acc: 0.963 - ETA: 0s - loss: 0.1140 - acc: 0.963 - ETA: 0s - loss: 0.1154 - acc: 0.963 - ETA: 0s - loss: 0.1184 - acc: 0.963 - ETA: 0s - loss: 0.1169 - acc: 0.963 - ETA: 0s - loss: 0.1182 - acc: 0.963 - ETA: 0s - loss: 0.1161 - acc: 0.964 - ETA: 0s - loss: 0.1185 - acc: 0.963 - ETA: 0s - loss: 0.1188 - acc: 0.963 - ETA: 0s - loss: 0.1217 - acc: 0.962 - 3s 416us/step - loss: 0.1218 - acc: 0.9623 - val_loss: 0.7239 - val_acc: 0.7988
#
# Epoch 00005: val_loss did not improve from 0.62551
# Epoch 6/20
# 6680/6680 [==============================] - ETA: 1s - loss: 0.2255 - acc: 0.900 - ETA: 3s - loss: 0.1096 - acc: 0.941 - ETA: 4s - loss: 0.1232 - acc: 0.937 - ETA: 5s - loss: 0.1084 - acc: 0.945 - ETA: 5s - loss: 0.1091 - acc: 0.945 - ETA: 6s - loss: 0.0955 - acc: 0.953 - ETA: 6s - loss: 0.0925 - acc: 0.958 - ETA: 6s - loss: 0.0851 - acc: 0.962 - ETA: 6s - loss: 0.0853 - acc: 0.965 - ETA: 6s - loss: 0.0845 - acc: 0.966 - ETA: 6s - loss: 0.0834 - acc: 0.966 - ETA: 6s - loss: 0.0793 - acc: 0.970 - ETA: 6s - loss: 0.0787 - acc: 0.969 - ETA: 6s - loss: 0.0776 - acc: 0.970 - ETA: 6s - loss: 0.0790 - acc: 0.970 - ETA: 6s - loss: 0.0802 - acc: 0.970 - ETA: 5s - loss: 0.0829 - acc: 0.970 - ETA: 6s - loss: 0.0813 - acc: 0.970 - ETA: 6s - loss: 0.0812 - acc: 0.970 - ETA: 5s - loss: 0.0788 - acc: 0.970 - ETA: 4s - loss: 0.0793 - acc: 0.971 - ETA: 3s - loss: 0.0835 - acc: 0.970 - ETA: 3s - loss: 0.0802 - acc: 0.971 - ETA: 3s - loss: 0.0757 - acc: 0.975 - ETA: 2s - loss: 0.0764 - acc: 0.974 - ETA: 2s - loss: 0.0752 - acc: 0.974 - ETA: 2s - loss: 0.0758 - acc: 0.974 - ETA: 2s - loss: 0.0766 - acc: 0.975 - ETA: 2s - loss: 0.0787 - acc: 0.974 - ETA: 1s - loss: 0.0798 - acc: 0.974 - ETA: 1s - loss: 0.0793 - acc: 0.974 - ETA: 1s - loss: 0.0822 - acc: 0.973 - ETA: 1s - loss: 0.0824 - acc: 0.972 - ETA: 1s - loss: 0.0813 - acc: 0.972 - ETA: 1s - loss: 0.0823 - acc: 0.971 - ETA: 1s - loss: 0.0825 - acc: 0.971 - ETA: 1s - loss: 0.0843 - acc: 0.971 - ETA: 0s - loss: 0.0837 - acc: 0.971 - ETA: 0s - loss: 0.0836 - acc: 0.971 - ETA: 0s - loss: 0.0850 - acc: 0.971 - ETA: 0s - loss: 0.0883 - acc: 0.970 - ETA: 0s - loss: 0.0868 - acc: 0.971 - ETA: 0s - loss: 0.0869 - acc: 0.971 - ETA: 0s - loss: 0.0867 - acc: 0.970 - ETA: 0s - loss: 0.0859 - acc: 0.971 - ETA: 0s - loss: 0.0873 - acc: 0.970 - ETA: 0s - loss: 0.0870 - acc: 0.971 - ETA: 0s - loss: 0.0880 - acc: 0.970 - ETA: 0s - loss: 0.0880 - acc: 0.970 - 3s 420us/step - loss: 0.0890 - acc: 0.9705 - val_loss: 0.6815 - val_acc: 0.8216
#
# Epoch 00006: val_loss did not improve from 0.62551
# Epoch 7/20
# 6680/6680 [==============================] - ETA: 3s - loss: 0.0127 - acc: 1.000 - ETA: 2s - loss: 0.0383 - acc: 0.995 - ETA: 1s - loss: 0.0490 - acc: 0.992 - ETA: 1s - loss: 0.0442 - acc: 0.994 - ETA: 1s - loss: 0.0499 - acc: 0.991 - ETA: 1s - loss: 0.0515 - acc: 0.989 - ETA: 1s - loss: 0.0492 - acc: 0.991 - ETA: 1s - loss: 0.0487 - acc: 0.991 - ETA: 1s - loss: 0.0474 - acc: 0.991 - ETA: 1s - loss: 0.0496 - acc: 0.989 - ETA: 1s - loss: 0.0515 - acc: 0.987 - ETA: 1s - loss: 0.0523 - acc: 0.986 - ETA: 1s - loss: 0.0506 - acc: 0.987 - ETA: 1s - loss: 0.0517 - acc: 0.987 - ETA: 1s - loss: 0.0549 - acc: 0.986 - ETA: 1s - loss: 0.0545 - acc: 0.985 - ETA: 1s - loss: 0.0540 - acc: 0.985 - ETA: 1s - loss: 0.0537 - acc: 0.985 - ETA: 1s - loss: 0.0582 - acc: 0.984 - ETA: 1s - loss: 0.0595 - acc: 0.984 - ETA: 1s - loss: 0.0592 - acc: 0.984 - ETA: 1s - loss: 0.0615 - acc: 0.984 - ETA: 1s - loss: 0.0641 - acc: 0.983 - ETA: 1s - loss: 0.0643 - acc: 0.983 - ETA: 1s - loss: 0.0628 - acc: 0.983 - ETA: 0s - loss: 0.0630 - acc: 0.983 - ETA: 0s - loss: 0.0628 - acc: 0.983 - ETA: 0s - loss: 0.0625 - acc: 0.983 - ETA: 0s - loss: 0.0619 - acc: 0.983 - ETA: 0s - loss: 0.0621 - acc: 0.983 - ETA: 0s - loss: 0.0631 - acc: 0.983 - ETA: 0s - loss: 0.0625 - acc: 0.982 - ETA: 0s - loss: 0.0624 - acc: 0.982 - ETA: 0s - loss: 0.0634 - acc: 0.981 - ETA: 0s - loss: 0.0629 - acc: 0.982 - ETA: 0s - loss: 0.0643 - acc: 0.981 - ETA: 0s - loss: 0.0650 - acc: 0.981 - ETA: 0s - loss: 0.0656 - acc: 0.981 - ETA: 0s - loss: 0.0660 - acc: 0.981 - ETA: 0s - loss: 0.0675 - acc: 0.980 - ETA: 0s - loss: 0.0674 - acc: 0.980 - ETA: 0s - loss: 0.0666 - acc: 0.980 - ETA: 0s - loss: 0.0667 - acc: 0.980 - 2s 354us/step - loss: 0.0664 - acc: 0.9807 - val_loss: 0.7181 - val_acc: 0.8120
#
# Epoch 00007: val_loss did not improve from 0.62551
# Epoch 8/20
# 6680/6680 [==============================] - ETA: 2s - loss: 0.0371 - acc: 1.000 - ETA: 2s - loss: 0.0412 - acc: 0.988 - ETA: 2s - loss: 0.0296 - acc: 0.994 - ETA: 2s - loss: 0.0448 - acc: 0.992 - ETA: 2s - loss: 0.0383 - acc: 0.993 - ETA: 1s - loss: 0.0371 - acc: 0.994 - ETA: 2s - loss: 0.0357 - acc: 0.993 - ETA: 1s - loss: 0.0344 - acc: 0.994 - ETA: 1s - loss: 0.0373 - acc: 0.993 - ETA: 1s - loss: 0.0405 - acc: 0.991 - ETA: 1s - loss: 0.0402 - acc: 0.991 - ETA: 1s - loss: 0.0386 - acc: 0.992 - ETA: 1s - loss: 0.0395 - acc: 0.992 - ETA: 1s - loss: 0.0383 - acc: 0.992 - ETA: 1s - loss: 0.0401 - acc: 0.991 - ETA: 1s - loss: 0.0405 - acc: 0.990 - ETA: 1s - loss: 0.0402 - acc: 0.990 - ETA: 1s - loss: 0.0391 - acc: 0.991 - ETA: 1s - loss: 0.0388 - acc: 0.991 - ETA: 1s - loss: 0.0426 - acc: 0.991 - ETA: 1s - loss: 0.0422 - acc: 0.991 - ETA: 1s - loss: 0.0415 - acc: 0.991 - ETA: 1s - loss: 0.0412 - acc: 0.991 - ETA: 1s - loss: 0.0412 - acc: 0.992 - ETA: 1s - loss: 0.0408 - acc: 0.992 - ETA: 1s - loss: 0.0413 - acc: 0.991 - ETA: 1s - loss: 0.0412 - acc: 0.991 - ETA: 1s - loss: 0.0409 - acc: 0.991 - ETA: 1s - loss: 0.0412 - acc: 0.991 - ETA: 1s - loss: 0.0409 - acc: 0.991 - ETA: 1s - loss: 0.0411 - acc: 0.991 - ETA: 1s - loss: 0.0405 - acc: 0.991 - ETA: 1s - loss: 0.0407 - acc: 0.991 - ETA: 1s - loss: 0.0405 - acc: 0.991 - ETA: 1s - loss: 0.0401 - acc: 0.991 - ETA: 1s - loss: 0.0434 - acc: 0.990 - ETA: 1s - loss: 0.0448 - acc: 0.990 - ETA: 1s - loss: 0.0448 - acc: 0.990 - ETA: 1s - loss: 0.0450 - acc: 0.989 - ETA: 0s - loss: 0.0466 - acc: 0.989 - ETA: 0s - loss: 0.0469 - acc: 0.988 - ETA: 0s - loss: 0.0469 - acc: 0.988 - ETA: 0s - loss: 0.0494 - acc: 0.987 - ETA: 0s - loss: 0.0489 - acc: 0.987 - ETA: 0s - loss: 0.0485 - acc: 0.988 - ETA: 0s - loss: 0.0483 - acc: 0.988 - ETA: 0s - loss: 0.0483 - acc: 0.987 - ETA: 0s - loss: 0.0495 - acc: 0.987 - ETA: 0s - loss: 0.0487 - acc: 0.987 - ETA: 0s - loss: 0.0487 - acc: 0.987 - ETA: 0s - loss: 0.0493 - acc: 0.987 - ETA: 0s - loss: 0.0495 - acc: 0.987 - ETA: 0s - loss: 0.0492 - acc: 0.987 - ETA: 0s - loss: 0.0490 - acc: 0.987 - 3s 479us/step - loss: 0.0496 - acc: 0.9873 - val_loss: 0.7253 - val_acc: 0.8251
#
# Epoch 00008: val_loss did not improve from 0.62551
# Epoch 9/20
# 6680/6680 [==============================] - ETA: 6s - loss: 0.0921 - acc: 0.950 - ETA: 6s - loss: 0.0589 - acc: 0.975 - ETA: 7s - loss: 0.0427 - acc: 0.983 - ETA: 7s - loss: 0.0337 - acc: 0.988 - ETA: 7s - loss: 0.0482 - acc: 0.981 - ETA: 7s - loss: 0.0388 - acc: 0.985 - ETA: 7s - loss: 0.0362 - acc: 0.987 - ETA: 7s - loss: 0.0329 - acc: 0.988 - ETA: 7s - loss: 0.0329 - acc: 0.988 - ETA: 5s - loss: 0.0301 - acc: 0.991 - ETA: 4s - loss: 0.0253 - acc: 0.993 - ETA: 3s - loss: 0.0252 - acc: 0.993 - ETA: 3s - loss: 0.0241 - acc: 0.993 - ETA: 3s - loss: 0.0254 - acc: 0.992 - ETA: 3s - loss: 0.0262 - acc: 0.992 - ETA: 3s - loss: 0.0259 - acc: 0.992 - ETA: 2s - loss: 0.0251 - acc: 0.993 - ETA: 2s - loss: 0.0260 - acc: 0.993 - ETA: 2s - loss: 0.0301 - acc: 0.993 - ETA: 2s - loss: 0.0292 - acc: 0.993 - ETA: 2s - loss: 0.0293 - acc: 0.993 - ETA: 2s - loss: 0.0283 - acc: 0.993 - ETA: 1s - loss: 0.0318 - acc: 0.993 - ETA: 1s - loss: 0.0318 - acc: 0.993 - ETA: 1s - loss: 0.0321 - acc: 0.993 - ETA: 1s - loss: 0.0322 - acc: 0.992 - ETA: 1s - loss: 0.0319 - acc: 0.992 - ETA: 1s - loss: 0.0323 - acc: 0.992 - ETA: 1s - loss: 0.0322 - acc: 0.991 - ETA: 1s - loss: 0.0328 - acc: 0.991 - ETA: 1s - loss: 0.0319 - acc: 0.991 - ETA: 1s - loss: 0.0317 - acc: 0.991 - ETA: 1s - loss: 0.0324 - acc: 0.991 - ETA: 1s - loss: 0.0319 - acc: 0.991 - ETA: 1s - loss: 0.0319 - acc: 0.992 - ETA: 1s - loss: 0.0332 - acc: 0.991 - ETA: 0s - loss: 0.0332 - acc: 0.991 - ETA: 0s - loss: 0.0328 - acc: 0.991 - ETA: 0s - loss: 0.0322 - acc: 0.991 - ETA: 0s - loss: 0.0330 - acc: 0.991 - ETA: 0s - loss: 0.0327 - acc: 0.991 - ETA: 0s - loss: 0.0337 - acc: 0.991 - ETA: 0s - loss: 0.0354 - acc: 0.990 - ETA: 0s - loss: 0.0359 - acc: 0.990 - ETA: 0s - loss: 0.0357 - acc: 0.990 - ETA: 0s - loss: 0.0357 - acc: 0.990 - ETA: 0s - loss: 0.0354 - acc: 0.990 - ETA: 0s - loss: 0.0349 - acc: 0.990 - ETA: 0s - loss: 0.0355 - acc: 0.990 - ETA: 0s - loss: 0.0351 - acc: 0.990 - ETA: 0s - loss: 0.0350 - acc: 0.990 - ETA: 0s - loss: 0.0360 - acc: 0.989 - 3s 439us/step - loss: 0.0366 - acc: 0.9895 - val_loss: 0.7276 - val_acc: 0.8228
#
# Epoch 00009: val_loss did not improve from 0.62551
# Epoch 10/20
# 6680/6680 [==============================] - ETA: 3s - loss: 0.0108 - acc: 1.000 - ETA: 2s - loss: 0.0105 - acc: 1.000 - ETA: 2s - loss: 0.0122 - acc: 1.000 - ETA: 2s - loss: 0.0126 - acc: 1.000 - ETA: 2s - loss: 0.0224 - acc: 0.998 - ETA: 2s - loss: 0.0191 - acc: 0.998 - ETA: 2s - loss: 0.0175 - acc: 0.998 - ETA: 2s - loss: 0.0186 - acc: 0.997 - ETA: 2s - loss: 0.0194 - acc: 0.996 - ETA: 1s - loss: 0.0179 - acc: 0.997 - ETA: 1s - loss: 0.0171 - acc: 0.997 - ETA: 1s - loss: 0.0171 - acc: 0.997 - ETA: 1s - loss: 0.0186 - acc: 0.996 - ETA: 1s - loss: 0.0208 - acc: 0.996 - ETA: 1s - loss: 0.0208 - acc: 0.996 - ETA: 1s - loss: 0.0199 - acc: 0.996 - ETA: 1s - loss: 0.0189 - acc: 0.996 - ETA: 1s - loss: 0.0200 - acc: 0.996 - ETA: 1s - loss: 0.0200 - acc: 0.996 - ETA: 1s - loss: 0.0203 - acc: 0.996 - ETA: 1s - loss: 0.0196 - acc: 0.996 - ETA: 1s - loss: 0.0198 - acc: 0.996 - ETA: 1s - loss: 0.0202 - acc: 0.996 - ETA: 1s - loss: 0.0214 - acc: 0.995 - ETA: 1s - loss: 0.0214 - acc: 0.995 - ETA: 0s - loss: 0.0219 - acc: 0.995 - ETA: 0s - loss: 0.0222 - acc: 0.995 - ETA: 0s - loss: 0.0220 - acc: 0.995 - ETA: 0s - loss: 0.0223 - acc: 0.994 - ETA: 0s - loss: 0.0231 - acc: 0.994 - ETA: 0s - loss: 0.0245 - acc: 0.993 - ETA: 0s - loss: 0.0244 - acc: 0.993 - ETA: 0s - loss: 0.0247 - acc: 0.993 - ETA: 0s - loss: 0.0245 - acc: 0.993 - ETA: 0s - loss: 0.0256 - acc: 0.992 - ETA: 0s - loss: 0.0257 - acc: 0.992 - ETA: 0s - loss: 0.0262 - acc: 0.993 - ETA: 0s - loss: 0.0259 - acc: 0.993 - ETA: 0s - loss: 0.0277 - acc: 0.992 - ETA: 0s - loss: 0.0278 - acc: 0.992 - ETA: 0s - loss: 0.0280 - acc: 0.992 - ETA: 0s - loss: 0.0278 - acc: 0.992 - ETA: 0s - loss: 0.0278 - acc: 0.992 - 2s 354us/step - loss: 0.0278 - acc: 0.9921 - val_loss: 0.7815 - val_acc: 0.8228
#
# Epoch 00010: val_loss did not improve from 0.62551
# Epoch 11/20
# 6680/6680 [==============================] - ETA: 3s - loss: 0.0166 - acc: 1.000 - ETA: 3s - loss: 0.0240 - acc: 0.992 - ETA: 2s - loss: 0.0170 - acc: 0.997 - ETA: 1s - loss: 0.0129 - acc: 0.998 - ETA: 2s - loss: 0.0130 - acc: 0.998 - ETA: 1s - loss: 0.0167 - acc: 0.996 - ETA: 1s - loss: 0.0153 - acc: 0.996 - ETA: 1s - loss: 0.0153 - acc: 0.996 - ETA: 1s - loss: 0.0152 - acc: 0.996 - ETA: 1s - loss: 0.0154 - acc: 0.996 - ETA: 1s - loss: 0.0157 - acc: 0.996 - ETA: 1s - loss: 0.0148 - acc: 0.997 - ETA: 1s - loss: 0.0145 - acc: 0.997 - ETA: 1s - loss: 0.0141 - acc: 0.996 - ETA: 1s - loss: 0.0152 - acc: 0.995 - ETA: 1s - loss: 0.0157 - acc: 0.995 - ETA: 1s - loss: 0.0156 - acc: 0.995 - ETA: 1s - loss: 0.0154 - acc: 0.995 - ETA: 1s - loss: 0.0173 - acc: 0.995 - ETA: 1s - loss: 0.0176 - acc: 0.995 - ETA: 1s - loss: 0.0173 - acc: 0.995 - ETA: 1s - loss: 0.0178 - acc: 0.995 - ETA: 1s - loss: 0.0175 - acc: 0.995 - ETA: 1s - loss: 0.0175 - acc: 0.995 - ETA: 1s - loss: 0.0175 - acc: 0.995 - ETA: 1s - loss: 0.0178 - acc: 0.995 - ETA: 1s - loss: 0.0176 - acc: 0.995 - ETA: 1s - loss: 0.0174 - acc: 0.995 - ETA: 1s - loss: 0.0174 - acc: 0.995 - ETA: 1s - loss: 0.0171 - acc: 0.995 - ETA: 1s - loss: 0.0170 - acc: 0.995 - ETA: 1s - loss: 0.0169 - acc: 0.995 - ETA: 1s - loss: 0.0176 - acc: 0.995 - ETA: 1s - loss: 0.0191 - acc: 0.994 - ETA: 1s - loss: 0.0184 - acc: 0.995 - ETA: 1s - loss: 0.0193 - acc: 0.994 - ETA: 1s - loss: 0.0231 - acc: 0.993 - ETA: 1s - loss: 0.0249 - acc: 0.993 - ETA: 0s - loss: 0.0242 - acc: 0.993 - ETA: 0s - loss: 0.0239 - acc: 0.993 - ETA: 0s - loss: 0.0237 - acc: 0.993 - ETA: 0s - loss: 0.0235 - acc: 0.994 - ETA: 0s - loss: 0.0233 - acc: 0.994 - ETA: 0s - loss: 0.0231 - acc: 0.994 - ETA: 0s - loss: 0.0230 - acc: 0.994 - ETA: 0s - loss: 0.0229 - acc: 0.994 - ETA: 0s - loss: 0.0227 - acc: 0.994 - ETA: 0s - loss: 0.0227 - acc: 0.994 - ETA: 0s - loss: 0.0231 - acc: 0.994 - ETA: 0s - loss: 0.0230 - acc: 0.994 - ETA: 0s - loss: 0.0230 - acc: 0.994 - ETA: 0s - loss: 0.0229 - acc: 0.994 - ETA: 0s - loss: 0.0228 - acc: 0.994 - ETA: 0s - loss: 0.0226 - acc: 0.994 - ETA: 0s - loss: 0.0224 - acc: 0.994 - ETA: 0s - loss: 0.0223 - acc: 0.994 - ETA: 0s - loss: 0.0219 - acc: 0.994 - ETA: 0s - loss: 0.0216 - acc: 0.994 - ETA: 0s - loss: 0.0221 - acc: 0.994 - ETA: 0s - loss: 0.0219 - acc: 0.994 - ETA: 0s - loss: 0.0218 - acc: 0.994 - ETA: 0s - loss: 0.0220 - acc: 0.994 - ETA: 0s - loss: 0.0219 - acc: 0.994 - ETA: 0s - loss: 0.0218 - acc: 0.994 - ETA: 0s - loss: 0.0219 - acc: 0.994 - ETA: 0s - loss: 0.0218 - acc: 0.994 - ETA: 0s - loss: 0.0217 - acc: 0.994 - 4s 608us/step - loss: 0.0216 - acc: 0.9945 - val_loss: 0.8274 - val_acc: 0.8096
#
# Epoch 00011: val_loss did not improve from 0.62551
# Epoch 12/20
# 6680/6680 [==============================] - ETA: 6s - loss: 0.0077 - acc: 1.000 - ETA: 6s - loss: 0.0088 - acc: 1.000 - ETA: 7s - loss: 0.0085 - acc: 1.000 - ETA: 7s - loss: 0.0083 - acc: 1.000 - ETA: 7s - loss: 0.0069 - acc: 1.000 - ETA: 7s - loss: 0.0059 - acc: 1.000 - ETA: 4s - loss: 0.0055 - acc: 1.000 - ETA: 3s - loss: 0.0091 - acc: 0.998 - ETA: 3s - loss: 0.0090 - acc: 0.998 - ETA: 2s - loss: 0.0084 - acc: 0.999 - ETA: 2s - loss: 0.0118 - acc: 0.997 - ETA: 2s - loss: 0.0181 - acc: 0.995 - ETA: 2s - loss: 0.0220 - acc: 0.995 - ETA: 1s - loss: 0.0201 - acc: 0.996 - ETA: 1s - loss: 0.0198 - acc: 0.996 - ETA: 1s - loss: 0.0193 - acc: 0.995 - ETA: 1s - loss: 0.0200 - acc: 0.995 - ETA: 1s - loss: 0.0191 - acc: 0.995 - ETA: 1s - loss: 0.0182 - acc: 0.996 - ETA: 1s - loss: 0.0176 - acc: 0.996 - ETA: 1s - loss: 0.0171 - acc: 0.996 - ETA: 1s - loss: 0.0168 - acc: 0.996 - ETA: 0s - loss: 0.0163 - acc: 0.996 - ETA: 0s - loss: 0.0159 - acc: 0.996 - ETA: 0s - loss: 0.0157 - acc: 0.997 - ETA: 0s - loss: 0.0156 - acc: 0.996 - ETA: 0s - loss: 0.0153 - acc: 0.996 - ETA: 0s - loss: 0.0158 - acc: 0.996 - ETA: 0s - loss: 0.0171 - acc: 0.996 - ETA: 0s - loss: 0.0169 - acc: 0.996 - ETA: 0s - loss: 0.0166 - acc: 0.996 - ETA: 0s - loss: 0.0164 - acc: 0.996 - ETA: 0s - loss: 0.0169 - acc: 0.996 - ETA: 0s - loss: 0.0168 - acc: 0.996 - ETA: 0s - loss: 0.0166 - acc: 0.996 - ETA: 0s - loss: 0.0172 - acc: 0.995 - ETA: 0s - loss: 0.0175 - acc: 0.995 - ETA: 0s - loss: 0.0175 - acc: 0.995 - ETA: 0s - loss: 0.0171 - acc: 0.995 - ETA: 0s - loss: 0.0172 - acc: 0.995 - 2s 324us/step - loss: 0.0176 - acc: 0.9957 - val_loss: 0.8177 - val_acc: 0.8108
#
# Epoch 00012: val_loss did not improve from 0.62551
# Epoch 13/20
# 6680/6680 [==============================] - ETA: 1s - loss: 0.0927 - acc: 0.950 - ETA: 1s - loss: 0.0112 - acc: 0.995 - ETA: 2s - loss: 0.0085 - acc: 0.996 - ETA: 2s - loss: 0.0161 - acc: 0.990 - ETA: 2s - loss: 0.0259 - acc: 0.991 - ETA: 2s - loss: 0.0305 - acc: 0.991 - ETA: 2s - loss: 0.0266 - acc: 0.992 - ETA: 2s - loss: 0.0235 - acc: 0.993 - ETA: 2s - loss: 0.0226 - acc: 0.993 - ETA: 1s - loss: 0.0200 - acc: 0.994 - ETA: 1s - loss: 0.0185 - acc: 0.995 - ETA: 1s - loss: 0.0170 - acc: 0.995 - ETA: 1s - loss: 0.0154 - acc: 0.996 - ETA: 1s - loss: 0.0150 - acc: 0.996 - ETA: 1s - loss: 0.0148 - acc: 0.996 - ETA: 1s - loss: 0.0180 - acc: 0.996 - ETA: 1s - loss: 0.0195 - acc: 0.995 - ETA: 1s - loss: 0.0182 - acc: 0.995 - ETA: 1s - loss: 0.0178 - acc: 0.995 - ETA: 1s - loss: 0.0177 - acc: 0.995 - ETA: 1s - loss: 0.0172 - acc: 0.995 - ETA: 1s - loss: 0.0165 - acc: 0.995 - ETA: 1s - loss: 0.0162 - acc: 0.995 - ETA: 1s - loss: 0.0159 - acc: 0.995 - ETA: 1s - loss: 0.0164 - acc: 0.995 - ETA: 1s - loss: 0.0161 - acc: 0.995 - ETA: 0s - loss: 0.0165 - acc: 0.995 - ETA: 0s - loss: 0.0163 - acc: 0.995 - ETA: 0s - loss: 0.0166 - acc: 0.995 - ETA: 0s - loss: 0.0165 - acc: 0.995 - ETA: 0s - loss: 0.0161 - acc: 0.995 - ETA: 0s - loss: 0.0156 - acc: 0.995 - ETA: 0s - loss: 0.0158 - acc: 0.995 - ETA: 0s - loss: 0.0154 - acc: 0.995 - ETA: 0s - loss: 0.0152 - acc: 0.995 - ETA: 0s - loss: 0.0151 - acc: 0.995 - ETA: 0s - loss: 0.0153 - acc: 0.995 - ETA: 0s - loss: 0.0150 - acc: 0.995 - ETA: 0s - loss: 0.0150 - acc: 0.995 - ETA: 0s - loss: 0.0152 - acc: 0.995 - ETA: 0s - loss: 0.0151 - acc: 0.995 - ETA: 0s - loss: 0.0153 - acc: 0.995 - ETA: 0s - loss: 0.0152 - acc: 0.995 - ETA: 0s - loss: 0.0150 - acc: 0.995 - 2s 374us/step - loss: 0.0149 - acc: 0.9955 - val_loss: 0.7948 - val_acc: 0.8240
#
# Epoch 00013: val_loss did not improve from 0.62551
# Epoch 14/20
# 6680/6680 [==============================] - ETA: 4s - loss: 0.0030 - acc: 1.000 - ETA: 2s - loss: 0.0040 - acc: 1.000 - ETA: 1s - loss: 0.0045 - acc: 1.000 - ETA: 1s - loss: 0.0038 - acc: 1.000 - ETA: 2s - loss: 0.0036 - acc: 1.000 - ETA: 1s - loss: 0.0032 - acc: 1.000 - ETA: 1s - loss: 0.0030 - acc: 1.000 - ETA: 1s - loss: 0.0039 - acc: 0.999 - ETA: 1s - loss: 0.0044 - acc: 0.998 - ETA: 1s - loss: 0.0052 - acc: 0.997 - ETA: 1s - loss: 0.0054 - acc: 0.998 - ETA: 1s - loss: 0.0052 - acc: 0.998 - ETA: 1s - loss: 0.0068 - acc: 0.997 - ETA: 1s - loss: 0.0067 - acc: 0.998 - ETA: 1s - loss: 0.0063 - acc: 0.998 - ETA: 1s - loss: 0.0064 - acc: 0.997 - ETA: 1s - loss: 0.0062 - acc: 0.998 - ETA: 1s - loss: 0.0061 - acc: 0.998 - ETA: 1s - loss: 0.0062 - acc: 0.997 - ETA: 1s - loss: 0.0060 - acc: 0.997 - ETA: 1s - loss: 0.0059 - acc: 0.998 - ETA: 1s - loss: 0.0059 - acc: 0.998 - ETA: 1s - loss: 0.0060 - acc: 0.998 - ETA: 1s - loss: 0.0067 - acc: 0.997 - ETA: 0s - loss: 0.0078 - acc: 0.997 - ETA: 0s - loss: 0.0082 - acc: 0.997 - ETA: 0s - loss: 0.0109 - acc: 0.997 - ETA: 0s - loss: 0.0109 - acc: 0.997 - ETA: 0s - loss: 0.0113 - acc: 0.997 - ETA: 0s - loss: 0.0109 - acc: 0.997 - ETA: 0s - loss: 0.0107 - acc: 0.997 - ETA: 0s - loss: 0.0108 - acc: 0.997 - ETA: 0s - loss: 0.0115 - acc: 0.997 - ETA: 0s - loss: 0.0116 - acc: 0.997 - ETA: 0s - loss: 0.0114 - acc: 0.997 - ETA: 0s - loss: 0.0112 - acc: 0.997 - ETA: 0s - loss: 0.0116 - acc: 0.997 - ETA: 0s - loss: 0.0117 - acc: 0.997 - ETA: 0s - loss: 0.0121 - acc: 0.996 - ETA: 0s - loss: 0.0118 - acc: 0.997 - ETA: 0s - loss: 0.0116 - acc: 0.997 - ETA: 0s - loss: 0.0121 - acc: 0.996 - 2s 348us/step - loss: 0.0121 - acc: 0.9969 - val_loss: 0.8269 - val_acc: 0.8204
#
# Epoch 00014: val_loss did not improve from 0.62551
# Epoch 15/20
# 6680/6680 [==============================] - ETA: 4s - loss: 0.0013 - acc: 1.000 - ETA: 2s - loss: 0.0076 - acc: 1.000 - ETA: 1s - loss: 0.0086 - acc: 0.997 - ETA: 1s - loss: 0.0151 - acc: 0.996 - ETA: 1s - loss: 0.0126 - acc: 0.996 - ETA: 1s - loss: 0.0117 - acc: 0.996 - ETA: 1s - loss: 0.0111 - acc: 0.997 - ETA: 1s - loss: 0.0103 - acc: 0.997 - ETA: 1s - loss: 0.0092 - acc: 0.997 - ETA: 1s - loss: 0.0094 - acc: 0.997 - ETA: 1s - loss: 0.0092 - acc: 0.997 - ETA: 1s - loss: 0.0090 - acc: 0.997 - ETA: 1s - loss: 0.0084 - acc: 0.998 - ETA: 1s - loss: 0.0129 - acc: 0.997 - ETA: 1s - loss: 0.0131 - acc: 0.997 - ETA: 1s - loss: 0.0126 - acc: 0.997 - ETA: 1s - loss: 0.0120 - acc: 0.997 - ETA: 1s - loss: 0.0114 - acc: 0.997 - ETA: 1s - loss: 0.0110 - acc: 0.997 - ETA: 0s - loss: 0.0105 - acc: 0.997 - ETA: 0s - loss: 0.0112 - acc: 0.997 - ETA: 0s - loss: 0.0111 - acc: 0.997 - ETA: 0s - loss: 0.0113 - acc: 0.997 - ETA: 0s - loss: 0.0112 - acc: 0.997 - ETA: 1s - loss: 0.0110 - acc: 0.997 - ETA: 1s - loss: 0.0110 - acc: 0.997 - ETA: 1s - loss: 0.0109 - acc: 0.997 - ETA: 1s - loss: 0.0109 - acc: 0.997 - ETA: 1s - loss: 0.0107 - acc: 0.997 - ETA: 1s - loss: 0.0106 - acc: 0.997 - ETA: 1s - loss: 0.0105 - acc: 0.997 - ETA: 1s - loss: 0.0105 - acc: 0.997 - ETA: 1s - loss: 0.0105 - acc: 0.997 - ETA: 1s - loss: 0.0109 - acc: 0.997 - ETA: 0s - loss: 0.0109 - acc: 0.997 - ETA: 0s - loss: 0.0108 - acc: 0.997 - ETA: 0s - loss: 0.0106 - acc: 0.997 - ETA: 0s - loss: 0.0106 - acc: 0.997 - ETA: 0s - loss: 0.0109 - acc: 0.997 - ETA: 0s - loss: 0.0106 - acc: 0.997 - ETA: 0s - loss: 0.0107 - acc: 0.997 - ETA: 0s - loss: 0.0106 - acc: 0.997 - ETA: 0s - loss: 0.0104 - acc: 0.997 - ETA: 0s - loss: 0.0102 - acc: 0.997 - ETA: 0s - loss: 0.0103 - acc: 0.997 - ETA: 0s - loss: 0.0104 - acc: 0.997 - ETA: 0s - loss: 0.0102 - acc: 0.997 - ETA: 0s - loss: 0.0100 - acc: 0.997 - ETA: 0s - loss: 0.0103 - acc: 0.997 - ETA: 0s - loss: 0.0102 - acc: 0.997 - 3s 451us/step - loss: 0.0101 - acc: 0.9972 - val_loss: 0.8582 - val_acc: 0.8263
#
# Epoch 00015: val_loss did not improve from 0.62551
# Epoch 16/20
# 6680/6680 [==============================] - ETA: 4s - loss: 4.4387e-04 - acc: 1.000 - ETA: 5s - loss: 0.0354 - acc: 0.9875    - ETA: 6s - loss: 0.0208 - acc: 0.992 - ETA: 6s - loss: 0.0147 - acc: 0.995 - ETA: 6s - loss: 0.0115 - acc: 0.996 - ETA: 6s - loss: 0.0095 - acc: 0.996 - ETA: 6s - loss: 0.0081 - acc: 0.997 - ETA: 6s - loss: 0.0075 - acc: 0.997 - ETA: 6s - loss: 0.0069 - acc: 0.998 - ETA: 6s - loss: 0.0063 - acc: 0.998 - ETA: 6s - loss: 0.0058 - acc: 0.998 - ETA: 5s - loss: 0.0094 - acc: 0.997 - ETA: 5s - loss: 0.0093 - acc: 0.996 - ETA: 4s - loss: 0.0085 - acc: 0.997 - ETA: 3s - loss: 0.0076 - acc: 0.997 - ETA: 3s - loss: 0.0067 - acc: 0.997 - ETA: 2s - loss: 0.0139 - acc: 0.997 - ETA: 2s - loss: 0.0133 - acc: 0.997 - ETA: 2s - loss: 0.0125 - acc: 0.997 - ETA: 2s - loss: 0.0119 - acc: 0.998 - ETA: 2s - loss: 0.0114 - acc: 0.997 - ETA: 2s - loss: 0.0108 - acc: 0.997 - ETA: 1s - loss: 0.0101 - acc: 0.998 - ETA: 1s - loss: 0.0097 - acc: 0.998 - ETA: 1s - loss: 0.0095 - acc: 0.998 - ETA: 1s - loss: 0.0092 - acc: 0.998 - ETA: 1s - loss: 0.0090 - acc: 0.998 - ETA: 1s - loss: 0.0090 - acc: 0.998 - ETA: 1s - loss: 0.0089 - acc: 0.998 - ETA: 1s - loss: 0.0087 - acc: 0.998 - ETA: 1s - loss: 0.0085 - acc: 0.998 - ETA: 1s - loss: 0.0084 - acc: 0.998 - ETA: 1s - loss: 0.0082 - acc: 0.998 - ETA: 1s - loss: 0.0081 - acc: 0.998 - ETA: 1s - loss: 0.0080 - acc: 0.998 - ETA: 0s - loss: 0.0083 - acc: 0.998 - ETA: 0s - loss: 0.0080 - acc: 0.998 - ETA: 0s - loss: 0.0080 - acc: 0.998 - ETA: 0s - loss: 0.0081 - acc: 0.998 - ETA: 0s - loss: 0.0078 - acc: 0.998 - ETA: 0s - loss: 0.0077 - acc: 0.998 - ETA: 0s - loss: 0.0079 - acc: 0.998 - ETA: 0s - loss: 0.0081 - acc: 0.998 - ETA: 0s - loss: 0.0080 - acc: 0.998 - ETA: 0s - loss: 0.0086 - acc: 0.998 - ETA: 0s - loss: 0.0088 - acc: 0.998 - ETA: 0s - loss: 0.0085 - acc: 0.998 - ETA: 0s - loss: 0.0083 - acc: 0.998 - ETA: 0s - loss: 0.0087 - acc: 0.998 - 3s 415us/step - loss: 0.0086 - acc: 0.9981 - val_loss: 0.8643 - val_acc: 0.8287
#
# Epoch 00016: val_loss did not improve from 0.62551
# Epoch 17/20
# 6680/6680 [==============================] - ETA: 3s - loss: 3.1774e-04 - acc: 1.000 - ETA: 2s - loss: 9.1096e-04 - acc: 1.000 - ETA: 2s - loss: 0.0012 - acc: 1.0000    - ETA: 1s - loss: 0.0015 - acc: 1.000 - ETA: 2s - loss: 0.0014 - acc: 1.000 - ETA: 1s - loss: 0.0013 - acc: 1.000 - ETA: 1s - loss: 0.0038 - acc: 0.999 - ETA: 1s - loss: 0.0040 - acc: 0.998 - ETA: 1s - loss: 0.0040 - acc: 0.998 - ETA: 1s - loss: 0.0040 - acc: 0.998 - ETA: 1s - loss: 0.0066 - acc: 0.997 - ETA: 1s - loss: 0.0073 - acc: 0.997 - ETA: 1s - loss: 0.0068 - acc: 0.997 - ETA: 1s - loss: 0.0063 - acc: 0.998 - ETA: 1s - loss: 0.0074 - acc: 0.997 - ETA: 1s - loss: 0.0070 - acc: 0.997 - ETA: 1s - loss: 0.0065 - acc: 0.998 - ETA: 0s - loss: 0.0063 - acc: 0.998 - ETA: 0s - loss: 0.0062 - acc: 0.998 - ETA: 0s - loss: 0.0061 - acc: 0.998 - ETA: 0s - loss: 0.0060 - acc: 0.998 - ETA: 0s - loss: 0.0059 - acc: 0.998 - ETA: 0s - loss: 0.0063 - acc: 0.998 - ETA: 0s - loss: 0.0063 - acc: 0.998 - ETA: 0s - loss: 0.0061 - acc: 0.998 - ETA: 0s - loss: 0.0060 - acc: 0.998 - ETA: 0s - loss: 0.0060 - acc: 0.998 - ETA: 0s - loss: 0.0058 - acc: 0.998 - ETA: 0s - loss: 0.0057 - acc: 0.998 - ETA: 0s - loss: 0.0063 - acc: 0.998 - ETA: 0s - loss: 0.0064 - acc: 0.998 - ETA: 0s - loss: 0.0063 - acc: 0.998 - ETA: 0s - loss: 0.0063 - acc: 0.998 - ETA: 0s - loss: 0.0062 - acc: 0.998 - ETA: 0s - loss: 0.0062 - acc: 0.998 - ETA: 0s - loss: 0.0062 - acc: 0.998 - ETA: 0s - loss: 0.0061 - acc: 0.998 - ETA: 0s - loss: 0.0061 - acc: 0.998 - ETA: 0s - loss: 0.0061 - acc: 0.998 - ETA: 0s - loss: 0.0061 - acc: 0.998 - ETA: 0s - loss: 0.0061 - acc: 0.998 - ETA: 0s - loss: 0.0060 - acc: 0.998 - ETA: 0s - loss: 0.0060 - acc: 0.998 - ETA: 0s - loss: 0.0060 - acc: 0.998 - ETA: 0s - loss: 0.0059 - acc: 0.998 - ETA: 0s - loss: 0.0059 - acc: 0.998 - ETA: 0s - loss: 0.0078 - acc: 0.998 - ETA: 0s - loss: 0.0078 - acc: 0.998 - ETA: 0s - loss: 0.0078 - acc: 0.998 - 3s 410us/step - loss: 0.0077 - acc: 0.9984 - val_loss: 0.8594 - val_acc: 0.8228
#
# Epoch 00017: val_loss did not improve from 0.62551
# Epoch 18/20
# 6680/6680 [==============================] - ETA: 1s - loss: 5.1152e-04 - acc: 1.000 - ETA: 1s - loss: 3.1877e-04 - acc: 1.000 - ETA: 1s - loss: 4.5982e-04 - acc: 1.000 - ETA: 1s - loss: 5.1481e-04 - acc: 1.000 - ETA: 1s - loss: 4.6343e-04 - acc: 1.000 - ETA: 1s - loss: 0.0041 - acc: 0.9989    - ETA: 1s - loss: 0.0037 - acc: 0.999 - ETA: 1s - loss: 0.0032 - acc: 0.999 - ETA: 1s - loss: 0.0029 - acc: 0.999 - ETA: 1s - loss: 0.0029 - acc: 0.999 - ETA: 1s - loss: 0.0028 - acc: 0.999 - ETA: 1s - loss: 0.0029 - acc: 0.999 - ETA: 1s - loss: 0.0028 - acc: 0.999 - ETA: 1s - loss: 0.0026 - acc: 0.999 - ETA: 1s - loss: 0.0026 - acc: 0.999 - ETA: 1s - loss: 0.0025 - acc: 0.999 - ETA: 1s - loss: 0.0026 - acc: 0.999 - ETA: 1s - loss: 0.0028 - acc: 0.999 - ETA: 1s - loss: 0.0033 - acc: 0.999 - ETA: 0s - loss: 0.0040 - acc: 0.998 - ETA: 0s - loss: 0.0039 - acc: 0.998 - ETA: 0s - loss: 0.0049 - acc: 0.998 - ETA: 0s - loss: 0.0054 - acc: 0.998 - ETA: 0s - loss: 0.0052 - acc: 0.998 - ETA: 0s - loss: 0.0052 - acc: 0.998 - ETA: 0s - loss: 0.0062 - acc: 0.998 - ETA: 0s - loss: 0.0060 - acc: 0.998 - ETA: 0s - loss: 0.0058 - acc: 0.998 - ETA: 0s - loss: 0.0062 - acc: 0.998 - ETA: 0s - loss: 0.0062 - acc: 0.998 - ETA: 0s - loss: 0.0066 - acc: 0.998 - ETA: 0s - loss: 0.0063 - acc: 0.998 - ETA: 0s - loss: 0.0062 - acc: 0.998 - ETA: 0s - loss: 0.0061 - acc: 0.998 - ETA: 0s - loss: 0.0060 - acc: 0.998 - ETA: 0s - loss: 0.0060 - acc: 0.998 - ETA: 0s - loss: 0.0060 - acc: 0.998 - ETA: 0s - loss: 0.0060 - acc: 0.998 - ETA: 0s - loss: 0.0059 - acc: 0.998 - ETA: 0s - loss: 0.0059 - acc: 0.998 - ETA: 0s - loss: 0.0059 - acc: 0.998 - ETA: 0s - loss: 0.0058 - acc: 0.998 - ETA: 0s - loss: 0.0058 - acc: 0.998 - ETA: 0s - loss: 0.0058 - acc: 0.998 - ETA: 0s - loss: 0.0058 - acc: 0.998 - ETA: 0s - loss: 0.0058 - acc: 0.998 - ETA: 0s - loss: 0.0057 - acc: 0.998 - ETA: 0s - loss: 0.0058 - acc: 0.998 - ETA: 0s - loss: 0.0058 - acc: 0.998 - ETA: 0s - loss: 0.0057 - acc: 0.998 - ETA: 0s - loss: 0.0073 - acc: 0.998 - ETA: 0s - loss: 0.0076 - acc: 0.998 - 3s 429us/step - loss: 0.0076 - acc: 0.9982 - val_loss: 0.9238 - val_acc: 0.8323
#
# Epoch 00018: val_loss did not improve from 0.62551
# Epoch 19/20
# 6680/6680 [==============================] - ETA: 2s - loss: 3.3188e-04 - acc: 1.000 - ETA: 1s - loss: 6.2408e-04 - acc: 1.000 - ETA: 1s - loss: 8.4881e-04 - acc: 1.000 - ETA: 1s - loss: 0.0032 - acc: 0.9984    - ETA: 1s - loss: 0.0028 - acc: 0.998 - ETA: 1s - loss: 0.0038 - acc: 0.997 - ETA: 1s - loss: 0.0034 - acc: 0.998 - ETA: 1s - loss: 0.0032 - acc: 0.998 - ETA: 1s - loss: 0.0059 - acc: 0.997 - ETA: 1s - loss: 0.0053 - acc: 0.998 - ETA: 1s - loss: 0.0049 - acc: 0.998 - ETA: 1s - loss: 0.0044 - acc: 0.998 - ETA: 1s - loss: 0.0042 - acc: 0.998 - ETA: 1s - loss: 0.0040 - acc: 0.998 - ETA: 1s - loss: 0.0040 - acc: 0.998 - ETA: 1s - loss: 0.0039 - acc: 0.998 - ETA: 1s - loss: 0.0037 - acc: 0.998 - ETA: 1s - loss: 0.0035 - acc: 0.998 - ETA: 1s - loss: 0.0034 - acc: 0.999 - ETA: 1s - loss: 0.0033 - acc: 0.999 - ETA: 1s - loss: 0.0032 - acc: 0.999 - ETA: 1s - loss: 0.0032 - acc: 0.999 - ETA: 0s - loss: 0.0032 - acc: 0.999 - ETA: 0s - loss: 0.0031 - acc: 0.999 - ETA: 0s - loss: 0.0030 - acc: 0.999 - ETA: 0s - loss: 0.0036 - acc: 0.998 - ETA: 0s - loss: 0.0036 - acc: 0.998 - ETA: 0s - loss: 0.0034 - acc: 0.998 - ETA: 0s - loss: 0.0040 - acc: 0.998 - ETA: 0s - loss: 0.0046 - acc: 0.998 - ETA: 0s - loss: 0.0045 - acc: 0.998 - ETA: 0s - loss: 0.0064 - acc: 0.998 - ETA: 0s - loss: 0.0063 - acc: 0.998 - ETA: 0s - loss: 0.0062 - acc: 0.998 - ETA: 0s - loss: 0.0060 - acc: 0.998 - ETA: 0s - loss: 0.0062 - acc: 0.998 - ETA: 0s - loss: 0.0061 - acc: 0.998 - ETA: 0s - loss: 0.0062 - acc: 0.998 - ETA: 0s - loss: 0.0061 - acc: 0.998 - 2s 327us/step - loss: 0.0060 - acc: 0.9984 - val_loss: 0.8831 - val_acc: 0.8263
#
# Epoch 00019: val_loss did not improve from 0.62551
# Epoch 20/20
# 6680/6680 [==============================] - ETA: 3s - loss: 0.0036 - acc: 1.000 - ETA: 2s - loss: 0.0026 - acc: 1.000 - ETA: 2s - loss: 0.0018 - acc: 1.000 - ETA: 2s - loss: 0.0053 - acc: 0.997 - ETA: 1s - loss: 0.0039 - acc: 0.998 - ETA: 1s - loss: 0.0032 - acc: 0.998 - ETA: 1s - loss: 0.0058 - acc: 0.998 - ETA: 1s - loss: 0.0052 - acc: 0.998 - ETA: 1s - loss: 0.0045 - acc: 0.998 - ETA: 1s - loss: 0.0042 - acc: 0.998 - ETA: 1s - loss: 0.0039 - acc: 0.998 - ETA: 1s - loss: 0.0035 - acc: 0.998 - ETA: 1s - loss: 0.0034 - acc: 0.998 - ETA: 1s - loss: 0.0032 - acc: 0.999 - ETA: 1s - loss: 0.0030 - acc: 0.999 - ETA: 1s - loss: 0.0028 - acc: 0.999 - ETA: 1s - loss: 0.0027 - acc: 0.999 - ETA: 1s - loss: 0.0028 - acc: 0.999 - ETA: 1s - loss: 0.0027 - acc: 0.999 - ETA: 1s - loss: 0.0026 - acc: 0.999 - ETA: 1s - loss: 0.0025 - acc: 0.999 - ETA: 1s - loss: 0.0024 - acc: 0.999 - ETA: 1s - loss: 0.0023 - acc: 0.999 - ETA: 1s - loss: 0.0023 - acc: 0.999 - ETA: 1s - loss: 0.0024 - acc: 0.999 - ETA: 1s - loss: 0.0024 - acc: 0.999 - ETA: 0s - loss: 0.0025 - acc: 0.999 - ETA: 0s - loss: 0.0024 - acc: 0.999 - ETA: 0s - loss: 0.0024 - acc: 0.999 - ETA: 0s - loss: 0.0025 - acc: 0.999 - ETA: 0s - loss: 0.0024 - acc: 0.999 - ETA: 0s - loss: 0.0024 - acc: 0.999 - ETA: 0s - loss: 0.0023 - acc: 0.999 - ETA: 0s - loss: 0.0022 - acc: 0.999 - ETA: 0s - loss: 0.0026 - acc: 0.999 - ETA: 0s - loss: 0.0026 - acc: 0.999 - ETA: 0s - loss: 0.0025 - acc: 0.999 - ETA: 0s - loss: 0.0045 - acc: 0.999 - ETA: 0s - loss: 0.0044 - acc: 0.999 - ETA: 0s - loss: 0.0044 - acc: 0.999 - ETA: 0s - loss: 0.0049 - acc: 0.998 - ETA: 0s - loss: 0.0050 - acc: 0.998 - ETA: 0s - loss: 0.0049 - acc: 0.998 - ETA: 0s - loss: 0.0048 - acc: 0.998 - 2s 363us/step - loss: 0.0047 - acc: 0.9988 - val_loss: 0.8910 - val_acc: 0.8347
#
# Epoch 00020: val_loss did not improve from 0.62551

# %%
# save the model architecture, so I can load the model later
from keras.models import model_from_json

with open('saved_models/resnet50.json', 'w') as f:
    f.write(Resnet50_model.to_json())

# %% [markdown]
# ### (IMPLEMENTATION) Load the Model with the Best Validation Loss

# %%
### TODO: Load the model weights with the best validation loss.
Resnet50_model.load_weights('saved_models/weights.best.Resnet50.hdf5')

# %% [markdown]
# ### (IMPLEMENTATION) Test the Model
#
# Try out your model on the test dataset of dog images. Ensure that your test accuracy is greater than 60%.

# %%
### TODO: Calculate classification accuracy on the test dataset.
Resnet50_predictions = [np.argmax(Resnet50_model.predict(np.expand_dims(feature, axis=0))) for feature in test_Resnet50]

# report test accuracy
test_accuracy = 100*np.sum(np.array(Resnet50_predictions)==np.argmax(test_targets, axis=1))/len(Resnet50_predictions)
print('Test accuracy: %.4f%%' % test_accuracy)
# Out:
# Test accuracy: 80.6220%

# %% [markdown]
# ### (IMPLEMENTATION) Predict Dog Breed with the Model
#
# Write a function that takes an image path as input and returns the dog breed (`Affenpinscher`, `Afghan_hound`, etc) that is predicted by your model.
#
# Similar to the analogous function in Step 5, your function should have three steps:
# 1. Extract the bottleneck features corresponding to the chosen CNN model.
# 2. Supply the bottleneck features as input to the model to return the predicted vector.  Note that the argmax of this prediction vector gives the index of the predicted dog breed.
# 3. Use the `dog_names` array defined in Step 0 of this notebook to return the corresponding breed.
#
# The functions to extract the bottleneck features can be found in `extract_bottleneck_features.py`, and they have been imported in an earlier code cell.  To obtain the bottleneck features corresponding to your chosen CNN architecture, you need to use the function
#
#     extract_{network}
#
# where `{network}`, in the above filename, should be one of `VGG19`, `Resnet50`, `InceptionV3`, or `Xception`.

# %%
from extract_bottleneck_features import *

### TODO: Write a function that takes a path to an image as input
### and returns the dog breed that is predicted by the model.

# Thanks to this answer which helped me with the latest version of keras 
# https://stackoverflow.com/questions/51231576/tensorflow-keras-expected-global-average-pooling2d-1-input-to-have-shape-1-1

def Resnet50_predict_breed(img_path):
    # extract bottleneck features
    bottleneck_feature = extract_Resnet50(path_to_tensor(img_path))
    bottleneck_feature = np.expand_dims(bottleneck_feature, axis=0)
    bottleneck_feature = np.expand_dims(bottleneck_feature, axis=0)
    print(bottleneck_feature.shape)
    # obtain predicted vector
    predicted_vector = Resnet50_model.predict(bottleneck_feature)
    # return dog breed that is predicted by the model
    return dog_names[np.argmax(predicted_vector)]


#dog_names
print(Resnet50_predict_breed('images/sample_human_2.png'))
# Out:
# (1, 1, 1, 2048)
# n\064.English_toy_spaniel

# %% [markdown]
# ---
# <a id='step6'></a>
# ## Step 6: Write your Algorithm
#
# Write an algorithm that accepts a file path to an image and first determines whether the image contains a human, dog, or neither.  Then,
# - if a __dog__ is detected in the image, return the predicted breed.
# - if a __human__ is detected in the image, return the resembling dog breed.
# - if __neither__ is detected in the image, provide output that indicates an error.
#
# You are welcome to write your own functions for detecting humans and dogs in images, but feel free to use the `face_detector` and `dog_detector` functions developed above.  You are __required__ to use your CNN from Step 5 to predict dog breed.
#
# A sample image and output for our algorithm is provided below, but feel free to design your own user experience!
#
# ![Sample Human Output](images/sample_human_2.png)
#
# This photo looks like an Afghan Hound.
# ### (IMPLEMENTATION) Write your Algorithm

# %%
### TODO: Write your algorithm.
### Feel free to use as many code cells as needed.
def dog_name(dog_name_path):
    return dog_name_path.split('.')[-1].replace('_', ' ')
    

def classify_dog_breed(image_path):
    img = image.load_img(image_path)
    plt.imshow(img)
    if dog_detector(image_path):
        print('This is a dog')
        print('This photo looks like a ',dog_name(Resnet50_predict_breed(image_path)))
    elif face_detector(image_path):
        print('This is a human')
        print('This photo looks like a ',dog_name(Resnet50_predict_breed(image_path)))
    else:
        print('Error: not a dog')

# %% [markdown]
# ---
# <a id='step7'></a>
# ## Step 7: Test Your Algorithm
#
# In this section, you will take your new algorithm for a spin!  What kind of dog does the algorithm think that __you__ look like?  If you have a dog, does it predict your dog's breed accurately?  If you have a cat, does it mistakenly think that your cat is a dog?
#
# ### (IMPLEMENTATION) Test Your Algorithm on Sample Images!
#
# Test your algorithm at least six images on your computer.  Feel free to use any images you like.  Use at least two human and two dog images.
#
# __Question 6:__ Is the output better than you expected :) ?  Or worse :( ?  Provide at least three possible points of improvement for your algorithm.
#
# __Answer:__

# %%
## TODO: Execute your algorithm from Step 6 on
## at least 6 images on your computer.
## Feel free to use as many code cells as needed.

# Does Garth identity as dog breed
classify_dog_breed('images/sample_human_2.png')
# Out:
# This is a human
# (1, 1, 1, 2048)
# This photo looks like a  English toy spaniel

# %%
# does this look like a chihuahua
classify_dog_breed('images/Blueberry-Muffins.jpg')
# Out:
# Error: not a dog

# %%
# does this look like a chihuahua
classify_dog_breed('images/blueberrymuffin.jpg')
# Out:
# Error: not a dog

# %%
#tesla
classify_dog_breed('images/tesla.jpg')
# Out:
# Error: not a dog

# %%
#actor
classify_dog_breed('images/tomselleck.jpg')
# Out:
# This is a human
# (1, 1, 1, 2048)
# This photo looks like a  Brussels griffon

# %%
classify_dog_breed('images/blackwidow.jpg')
# Out:
# This is a human
# (1, 1, 1, 2048)
# This photo looks like a  Cane corso

# %%
#cat
classify_dog_breed('images/cat1.jpg')
# Out:
# Error: not a dog

# %%
classify_dog_breed('images/American_water_spaniel_00648.jpg')
# Out:
# This is a dog
# (1, 1, 1, 2048)
# This photo looks like a  Irish water spaniel

# %%
classify_dog_breed('images/puppy-dog.jpg')
# Out:
# This is a dog
# (1, 1, 1, 2048)
# This photo looks like a  Golden retriever
